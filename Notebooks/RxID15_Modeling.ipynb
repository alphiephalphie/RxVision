# %% [markdown]
# # Setup

# %% [markdown]
# ## Environment Prep

# %% [markdown]
# ### Package Import

# %%
! pip install keras_metrics

import imageio
import imgaug as ia

import pandas as pd
import numpy as np
import pickle
import seaborn as sns

import os
import sys
import warnings
warnings.filterwarnings('ignore')
#!{sys.executable} -m pip install opencv-python

import time
import itertools

import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf
from tensorflow import keras

import scipy
from PIL import Image
from scipy import ndimage

import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras import models
from keras import optimizers
from keras import models
from keras import layers
import keras_metrics
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.models import Model
from keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

from keras.applications.resnet import ResNet50

from sklearn.model_selection import RandomizedSearchCV, cross_val_score, GridSearchCV, validation_curve 
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.metrics import confusion_matrix, r2_score, recall_score, precision_score, f1_score, accuracy_score
from sklearn.model_selection import cross_val_score, GridSearchCV, validation_curve
from sklearn.pipeline import make_pipeline
#from tensorflow.keras import get_default_graph

from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
import urllib.request, json
import os
import numpy as np

from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# This code has been tested with TensorFlow 1.6
import tensorflow as tf
#from tensorflow.examples.tutorials.mnist import input_data
np.random.seed(123)

# Transfer learning with VGG16
# from tensorflow.keras.applications.vgg16 import VGG16
# from tensorflow.keras.preprocessing import image
# from tensorflow.keras.applications.vgg16 import preprocess_input

from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input

from keras.callbacks import ModelCheckpoint, EarlyStopping



from google.colab import drive
drive.mount('/content/drive')
# Out:
# Requirement already satisfied: keras_metrics in /usr/local/lib/python3.6/dist-packages (1.1.0)
# Requirement already satisfied: Keras>=2.1.5 in /usr/local/lib/python3.6/dist-packages (from keras_metrics) (2.3.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras_metrics) (1.12.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras_metrics) (3.13)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras_metrics) (1.18.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras_metrics) (2.10.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras_metrics) (1.1.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras_metrics) (1.4.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras_metrics) (1.0.8)
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Using TensorFlow backend.

# %% [markdown]
# ### Functions

# %%
# This function will plot images in the form of a grid with 1 row and 5 columns where images are placed in each column.
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(40,40))
    axes = axes.flatten()
    for img, ax in zip(images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %%
# This function will plot images in the form of a grid with 1 row and 5 columns where images are placed in each column.
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip(images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %%
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
def plot_conf_matrix(df_confusion, title='Confusion matrix', cmap=plt.cm.gray_r):
  plt.matshow(df_confusion, cmap=cmap) 
  # imshow
  #plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(df_confusion.columns))
  plt.xticks(tick_marks, df_confusion.columns, rotation=45)
  plt.yticks(tick_marks, df_confusion.index)
  #plt.tight_layout()
  plt.ylabel(df_confusion.index.name)
  plt.xlabel(df_confusion.columns.name)
  plot_confusion_matrix(df_confusion)

# %%
def plot_conf_matrix(df_confusion, title='Confusion matrix', cmap=plt.cm.gray_r):
  plt.matshow(df_confusion, cmap=cmap) # imshow
  #plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(df_confusion.columns))
  plt.xticks(tick_marks, df_confusion.columns, rotation=45)
  plt.yticks(tick_marks, df_confusion.index)
  #plt.tight_layout()
  plt.ylabel(df_confusion.index.name)
  plt.xlabel(df_confusion.columns.name)
  plot_confusion_matrix(df_confusion)
  
#df_confusion = pd.crosstab(y_actu, y_pred)

# %% [markdown]
# ## Data Prep

# %% [markdown]
# ### Data import

# %%
data ='/content/drive/My Drive/RxID/RxID15/modeldata'
test_folder = '/content/drive/My Drive/RxID/RxID15/modeldata/test'
train_folder = '/content/drive/My Drive/RxID/RxID15/modeldata/train'
val_folder = '/content/drive/My Drive/RxID/RxID15/modeldata/validation'
rw_folder = '/content/drive/My Drive/RxID/RxID15/Realworld images'

# %% [markdown]
# ### Preprocessing

# %%
# train_generator.allowed_class_modes,
# test_generator.white_list_formats,
# train_generator.directory,
train_generator.class_indices
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c3fcc18dadb1> in <module>()
#       2 # test_generator.white_list_formats,
#       3 # train_generator.directory,
# ----> 4 train_generator.class_indices
#
# NameError: name 'train_generator' is not defined

# %%
# plt.hist(list(train_generator.classes))

# %% [markdown]
# # Modeling

# %% [markdown]
# ## model1 - Acc: 0.47

# %%
BATCH_SIZE = 32
IMG_SHAPE  = 64 
EPOCHS = 15
plottrain = True


test_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(test_folder,
                                                                        shuffle=True,
                                                                        target_size=(IMG_SHAPE,IMG_SHAPE),
                                                                        batch_size = BATCH_SIZE) 

val_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(val_folder,
                                                                       shuffle=False,
                                                                       #class_mode='binary',
                                                                       target_size=(IMG_SHAPE,IMG_SHAPE),
                                                                       batch_size = BATCH_SIZE)

train_generator = ImageDataGenerator(rescale=1./255,
                                     brightness_range=(.2,1),
                                     shear_range=0.2,
                                     channel_shift_range=128,
                                     rotation_range=45,
                                     vertical_flip=True,
                                     zoom_range=0.5,).flow_from_directory(train_folder,
                                                                          shuffle=True,
                                                                          #class_mode='binary',
                                                                          target_size=(IMG_SHAPE,IMG_SHAPE),
                                                                          batch_size=BATCH_SIZE)
# Out:
# Found 74 images belonging to 15 classes.
# Found 150 images belonging to 15 classes.
# Found 525 images belonging to 15 classes.

# %%
model1 = models.Sequential(name='CNN 1')

model1.add(layers.Conv2D(768, (3,3), activation='relu',input_shape=(IMG_SHAPE ,IMG_SHAPE,  3)))
model1.add(layers.MaxPooling2D((3, 3)))

model1.add(layers.Conv2D(1024, (3,3), activation='relu', padding="same"))
model1.add(layers.MaxPooling2D((3, 3)))

model1.add(layers.Conv2D(512, (3,3), activation='relu', padding="same"))
model1.add(layers.MaxPooling2D((3, 3)))

model1.add(layers.Conv2D(256, (3,3), activation='relu', padding="same"))
#model1.add(layers.MaxPooling2D((3, 3))) 

model1.add(layers.Flatten())
model1.add(layers.Dense(15, activation='softmax'))

model1.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['acc'])
model1.summary()

history = model1.fit(train_generator,
                    epochs=EPOCHS,
                    #batch_size=32,
                    #validation_split= 0.1,
                    validation_data=val_generator,
                    verbose=1)

results_train1 = model1.evaluate(train_generator)
model1_val_results = model1.evaluate(val_generator)
model1_val_results
#model.predict_classes(val_images)

if plottrain == True:
  acc = history.history['acc']
  val_acc = history.history['val_acc']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs_range = range(EPOCHS)

  plt.figure(figsize=(16, 8))
  plt.subplot(1, 2, 1)
  plt.plot(epochs_range, acc, label='Training Accuracy')
  plt.plot(epochs_range, val_acc, label='Validation Accuracy')
  plt.legend(loc='lower right')
  plt.title('Training and Validation Accuracy')

  plt.subplot(1, 3, 3)
  plt.plot(epochs_range, loss, label='Training Loss')
  plt.plot(epochs_range, val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Training and Validation Loss')
  plt.savefig('./foo.png')
  plt.show()
model1_val_results
# Out:
# Model: "CNN 1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 62, 62, 768)       21504
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 20, 20, 768)       0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 20, 20, 1024)      7078912
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 6, 6, 1024)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 6, 6, 512)         4719104
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 2, 2, 256)         1179904
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 15)                15375
# =================================================================
# Total params: 13,014,799
# Trainable params: 13,014,799
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 17/17 [==============================] - 72s 4s/step - loss: 2.7497 - acc: 0.0476 - val_loss: 2.7078 - val_acc: 0.1000
# Epoch 2/15
# 17/17 [==============================] - 71s 4s/step - loss: 2.6642 - acc: 0.0819 - val_loss: 1.1496 - val_acc: 0.1333
# Epoch 3/15
# 17/17 [==============================] - 71s 4s/step - loss: 2.5048 - acc: 0.1352 - val_loss: 1.7169 - val_acc: 0.2000
# Epoch 4/15
# 17/17 [==============================] - 71s 4s/step - loss: 2.2607 - acc: 0.2248 - val_loss: 0.9289 - val_acc: 0.2600
# Epoch 5/15
# 17/17 [==============================] - 71s 4s/step - loss: 2.2576 - acc: 0.2267 - val_loss: 0.9040 - val_acc: 0.2867
# Epoch 6/15
# 17/17 [==============================] - 72s 4s/step - loss: 2.0189 - acc: 0.3010 - val_loss: 1.2787 - val_acc: 0.3133
# Epoch 7/15
# 17/17 [==============================] - 71s 4s/step - loss: 1.9752 - acc: 0.3048 - val_loss: 1.0575 - val_acc: 0.3800
# Epoch 8/15
# 17/17 [==============================] - 71s 4s/step - loss: 1.8793 - acc: 0.3105 - val_loss: 0.4623 - val_acc: 0.3867
# Epoch 9/15
# 17/17 [==============================] - 71s 4s/step - loss: 1.7175 - acc: 0.3657 - val_loss: 0.3356 - val_acc: 0.4200
# Epoch 10/15
# 17/17 [==============================] - 71s 4s/step - loss: 1.7161 - acc: 0.3371 - val_loss: 1.0446 - val_acc: 0.4467
# Epoch 11/15
# 17/17 [==============================] - 71s 4s/step - loss: 1.6535 - acc: 0.4076 - val_loss: 2.2795 - val_acc: 0.3800
# Epoch 12/15
# 17/17 [==============================] - 71s 4s/step - loss: 1.7953 - acc: 0.3562 - val_loss: 0.6963 - val_acc: 0.3867
# Epoch 13/15
# 17/17 [==============================] - 71s 4s/step - loss: 1.6207 - acc: 0.3905 - val_loss: 0.5010 - val_acc: 0.4000
# Epoch 14/15
# 17/17 [==============================] - 71s 4s/step - loss: 1.5606 - acc: 0.4190 - val_loss: 0.4516 - val_acc: 0.4733
# Epoch 15/15
# 17/17 [==============================] - 71s 4s/step - loss: 1.5813 - acc: 0.4171 - val_loss: 0.6687 - val_acc: 0.4733
# 17/17 [==============================] - 66s 4s/step
# 5/5 [==============================] - 17s 3s/step
# [0.6687304973602295, 0.47333332896232605]

# %% [markdown]
# ## model2 - Acc: 0.44

# %%
BATCH_SIZE = 32
IMG_SHAPE  = 48 
EPOCHS = 25
plottrain = True


test_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(test_folder,
                                                                        shuffle=True,
                                                                        target_size=(IMG_SHAPE,IMG_SHAPE),
                                                                        batch_size = BATCH_SIZE) 

val_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(val_folder,
                                                                       shuffle=False,
                                                                       #class_mode='binary',
                                                                       target_size=(IMG_SHAPE,IMG_SHAPE),
                                                                       batch_size = BATCH_SIZE)

train_generator = ImageDataGenerator(rescale=1./255,
                                     brightness_range=(.2,1),
                                     shear_range=0.2,
                                     channel_shift_range=128,
                                     rotation_range=45,
                                     vertical_flip=True,
                                     zoom_range=0.5,).flow_from_directory(train_folder,
                                                                          shuffle=True,
                                                                          #class_mode='binary',
                                                                          target_size=(IMG_SHAPE,IMG_SHAPE),
                                                                          batch_size=BATCH_SIZE)

model2 = models.Sequential(name='CNN 1')

model2.add(layers.Conv2D(768, (3,3), activation='relu',input_shape=(IMG_SHAPE ,IMG_SHAPE,  3)))
model2.add(layers.MaxPooling2D((3, 3)))

model2.add(layers.Conv2D(1024, (3,3), activation='relu', padding="same"))
model2.add(layers.MaxPooling2D((3, 3)))
#model2.add(layers.Dropout(0.05)

model2.add(layers.Conv2D(512, (3,3), activation='relu', padding="same"))
model2.add(layers.MaxPooling2D((3, 3)))

model2.add(layers.Conv2D(256, (3,3), activation='relu', padding="same"))
#model2.add(layers.MaxPooling2D((3, 3))) 

model2.add(layers.Flatten())
model2.add(layers.Dense(15, activation='softmax'))

model2.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['acc'])
model2.summary()

history = model2.fit(train_generator,
                    epochs=EPOCHS,
                    #batch_size=32,
                    #validation_split= 0.1,
                    validation_data=val_generator,
                    verbose=1)

results_train1 = model2.evaluate(train_generator)
model2_val_results = model2.evaluate(val_generator)
model2_val_results
#model.predict_classes(val_images)

if plottrain == True:
  acc = history.history['acc']
  val_acc = history.history['val_acc']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs_range = range(EPOCHS)

  plt.figure(figsize=(16, 8))
  plt.subplot(1, 2, 1)
  plt.plot(epochs_range, acc, label='Training Accuracy')
  plt.plot(epochs_range, val_acc, label='Validation Accuracy')
  plt.legend(loc='lower right')
  plt.title('Training and Validation Accuracy')

  plt.subplot(1, 3, 3)
  plt.plot(epochs_range, loss, label='Training Loss')
  plt.plot(epochs_range, val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Training and Validation Loss')
  plt.savefig('./foo.png')
  plt.show()
model2_val_results
# Out:
# Found 74 images belonging to 15 classes.
# Found 150 images belonging to 15 classes.
# Found 525 images belonging to 15 classes.
# Model: "CNN 1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_37 (Conv2D)           (None, 46, 46, 768)       21504
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 15, 15, 768)       0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 15, 15, 1024)      7078912
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 5, 5, 1024)        0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 5, 5, 512)         4719104
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 1, 1, 256)         1179904
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 15)                3855
# =================================================================
# Total params: 13,003,279
# Trainable params: 13,003,279
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 17/17 [==============================] - 70s 4s/step - loss: 2.7206 - acc: 0.0590 - val_loss: 2.7055 - val_acc: 0.0667
# Epoch 2/25
# 17/17 [==============================] - 68s 4s/step - loss: 2.7083 - acc: 0.0667 - val_loss: 2.7079 - val_acc: 0.0667
# Epoch 3/25
# 17/17 [==============================] - 68s 4s/step - loss: 2.6953 - acc: 0.0762 - val_loss: 2.7435 - val_acc: 0.1400
# Epoch 4/25
# 17/17 [==============================] - 68s 4s/step - loss: 2.5975 - acc: 0.1086 - val_loss: 2.4787 - val_acc: 0.1400
# Epoch 5/25
# 17/17 [==============================] - 68s 4s/step - loss: 2.5289 - acc: 0.1333 - val_loss: 2.6818 - val_acc: 0.1533
# Epoch 6/25
# 17/17 [==============================] - 68s 4s/step - loss: 2.4418 - acc: 0.1429 - val_loss: 1.9588 - val_acc: 0.2133
# Epoch 7/25
# 17/17 [==============================] - 68s 4s/step - loss: 2.3123 - acc: 0.1790 - val_loss: 1.6559 - val_acc: 0.3067
# Epoch 8/25
# 17/17 [==============================] - 68s 4s/step - loss: 2.1372 - acc: 0.2514 - val_loss: 1.9879 - val_acc: 0.3133
# Epoch 9/25
# 17/17 [==============================] - 68s 4s/step - loss: 2.0810 - acc: 0.2438 - val_loss: 1.2292 - val_acc: 0.2667
# Epoch 10/25
# 17/17 [==============================] - 68s 4s/step - loss: 1.9799 - acc: 0.2876 - val_loss: 0.9044 - val_acc: 0.3133
# Epoch 11/25
# 17/17 [==============================] - 68s 4s/step - loss: 1.8784 - acc: 0.3181 - val_loss: 1.2306 - val_acc: 0.3867
# Epoch 12/25
# 17/17 [==============================] - 68s 4s/step - loss: 1.8666 - acc: 0.3086 - val_loss: 0.6039 - val_acc: 0.4067
# Epoch 13/25
# 17/17 [==============================] - 68s 4s/step - loss: 1.7754 - acc: 0.3448 - val_loss: 0.8444 - val_acc: 0.4133
# Epoch 14/25
# 17/17 [==============================] - 68s 4s/step - loss: 1.7581 - acc: 0.3429 - val_loss: 0.6292 - val_acc: 0.3867
# Epoch 15/25
# 17/17 [==============================] - 68s 4s/step - loss: 1.7174 - acc: 0.3676 - val_loss: 0.7509 - val_acc: 0.3333
# Epoch 16/25
# 17/17 [==============================] - 68s 4s/step - loss: 1.7262 - acc: 0.3410 - val_loss: 0.7003 - val_acc: 0.3867
# Epoch 17/25
# 17/17 [==============================] - 68s 4s/step - loss: 1.5988 - acc: 0.4133 - val_loss: 1.0948 - val_acc: 0.4400
# Epoch 18/25
# 17/17 [==============================] - 68s 4s/step - loss: 1.6657 - acc: 0.3733 - val_loss: 0.9969 - val_acc: 0.4600
# Epoch 19/25
# 17/17 [==============================] - 68s 4s/step - loss: 1.5766 - acc: 0.4286 - val_loss: 0.9816 - val_acc: 0.4400
# Epoch 20/25
# 17/17 [==============================] - 68s 4s/step - loss: 1.5184 - acc: 0.4419 - val_loss: 0.7601 - val_acc: 0.4467
# Epoch 21/25
# 17/17 [==============================] - 68s 4s/step - loss: 1.6053 - acc: 0.4171 - val_loss: 0.6646 - val_acc: 0.4000
# Epoch 22/25
# 17/17 [==============================] - 68s 4s/step - loss: 1.4921 - acc: 0.4381 - val_loss: 1.2665 - val_acc: 0.4067
# Epoch 23/25
# 17/17 [==============================] - 68s 4s/step - loss: 1.4789 - acc: 0.4381 - val_loss: 1.0431 - val_acc: 0.4467
# Epoch 24/25
# 17/17 [==============================] - 68s 4s/step - loss: 1.4351 - acc: 0.4610 - val_loss: 0.8374 - val_acc: 0.4667
# Epoch 25/25
# 17/17 [==============================] - 68s 4s/step - loss: 1.4144 - acc: 0.5010 - val_loss: 0.6941 - val_acc: 0.4467
# 17/17 [==============================] - 64s 4s/step
# 5/5 [==============================] - 17s 3s/step
# [0.6940851211547852, 0.4466666579246521]

# %%
model2.predict(test_images[:1])
# Out:
# array([[8.9223413e-08, 9.9975592e-01, 1.5309214e-06, 2.2928591e-04,
#         1.3173030e-05, 9.1070079e-10, 2.4662183e-10, 1.4682051e-08]],
#       dtype=float32)

# %%
model2.predict_classes(test_images[:5])
# Out:
# array([1, 4, 5, 5, 0, 0, 4, 6, 0, 0, 0, 0, 3, 1, 5, 1, 0, 4, 1, 5, 1, 2,
#        0, 6, 7, 3, 5, 2, 4, 5, 2, 0, 1, 7, 1, 5, 0, 5, 1, 5, 7, 2, 6, 5,
#        7, 6, 6, 3, 6, 2, 3, 6, 6, 7, 7, 2, 2, 7])

# %%
test_labels[0]
# Out:
# array([0., 1., 0., 0., 0., 0., 0., 0.], dtype=float32)

# %%
plt.imshow(test_images[:1][0])

# %% [markdown]
# ## model3 - Acc: 0.58

# %%
BATCH_SIZE = 32
IMG_SHAPE  = 32 
EPOCHS = 50
plottrain = True


test_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(test_folder,
                                                                        shuffle=True,
                                                                        target_size=(IMG_SHAPE,IMG_SHAPE),
                                                                        batch_size = BATCH_SIZE) 

val_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(val_folder,
                                                                       shuffle=False,
                                                                       #class_mode='binary',
                                                                       target_size=(IMG_SHAPE,IMG_SHAPE),
                                                                       batch_size = BATCH_SIZE)

train_generator = ImageDataGenerator(rescale=1./255,
                                     brightness_range=(.2,1),
                                     shear_range=0.2,
                                     channel_shift_range=128,
                                     rotation_range=45,
                                     vertical_flip=True,
                                     zoom_range=0.5,).flow_from_directory(train_folder,
                                                                          shuffle=True,
                                                                          #class_mode='binary',
                                                                          target_size=(IMG_SHAPE,IMG_SHAPE),
                                                                          batch_size=BATCH_SIZE)
# model3 = VGG16(weights='imagenet', include_top=False,input_shape=(IMG_SHAPE ,IMG_SHAPE,  3))
# model3.layers.pop()
# model3 = Model(inputs=model3.inputs, outputs=model3.layers[-1].output)

model3 = models.Sequential(name='CNN 4')

model3.add(layers.Conv2D(768, (3,3), activation='relu',input_shape=(IMG_SHAPE ,IMG_SHAPE,  3)))
model3.add(layers.MaxPooling2D((3, 3)))


model3.add(layers.Conv2D(1024, (3,3), activation='relu', padding="same"))
model3.add(layers.MaxPooling2D((3, 3)))
model3.add(layers.Dropout(0.05))

model3.add(layers.Conv2D(512, (3,3), activation='relu', padding="same"))
model3.add(layers.MaxPooling2D((3, 3)))

model3.add(layers.Conv2D(256, (3,3), activation='relu', padding="same"))
#model3.add(layers.MaxPooling2D((3, 3))) 

model3.add(layers.Flatten())
model3.add(layers.Dense(15, activation='softmax'))

# learning

model3.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['acc'])
model3.summary()

checkpoint = ModelCheckpoint("/content/drive/My Drive/RxID/RxID15/Models/RxID15{}".format(model3.name), monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_acc', min_delta=0, patience=20, verbose=1, mode='auto')


history = model3.fit(train_generator,
                    epochs=EPOCHS,
                    #batch_size=32,
                    #validation_split= 0.1,
                    validation_data=val_generator,
                     callbacks=[checkpoint,early],
                    verbose=1)

results_train1 = model3.evaluate(train_generator)
model3_val_results = model3.evaluate(val_generator)
model3_val_results
#model.predict_classes(val_images)

if plottrain == True:
  acc = history.history['acc']
  val_acc = history.history['val_acc']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs_range = range(EPOCHS)

  plt.figure(figsize=(16, 8))
  plt.subplot(1, 2, 1)
  plt.plot(epochs_range, acc, label='Training Accuracy')
  plt.plot(epochs_range, val_acc, label='Validation Accuracy')
  plt.legend(loc='lower right')
  plt.title('Training and Validation Accuracy')

  plt.subplot(1, 3, 3)
  plt.plot(epochs_range, loss, label='Training Loss')
  plt.plot(epochs_range, val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Training and Validation Loss')
  plt.savefig('/content/drive/My Drive/RxID/RxID15/Model Images/{}-Acc_Loss.png'.format(model3.name))
  plt.show()
model3_val_results
# Out:
# Found 74 images belonging to 15 classes.
# Found 150 images belonging to 15 classes.
# Found 525 images belonging to 15 classes.
# Model: "CNN 1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 30, 30, 768)       21504
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 10, 10, 768)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 10, 10, 1024)      7078912
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 3, 3, 1024)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 3, 3, 1024)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 3, 3, 512)         4719104
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 1, 1, 256)         1179904
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 15)                3855
# =================================================================
# Total params: 13,003,279
# Trainable params: 13,003,279
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
#  6/17 [=========>....................] - ETA: 1:41 - loss: 2.7388 - acc: 0.0677
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-87986b7c552f> in <module>()
#      58                     #validation_split= 0.1,
#      59                     validation_data=val_generator,
# ---> 60                     verbose=1)
#      61
#      62 results_train1 = model3.evaluate(train_generator)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1145                 use_multiprocessing=use_multiprocessing,
#    1146                 shuffle=shuffle,
# -> 1147                 initial_epoch=initial_epoch)
#    1148
#    1149         # Case 2: Symbolic tensors or Numpy array-like.
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     183             batch_index = 0
#     184             while steps_done < steps_per_epoch:
# --> 185                 generator_output = next(output_generator)
#     186
#     187                 if not hasattr(generator_output, '__len__'):
#
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py in get(self)
#     608                 try:
#     609                     future = self.queue.get(block=True)
# --> 610                     inputs = future.get(timeout=30)
#     611                 except mp.TimeoutError:
#     612                     idx = future.idx
#
# /usr/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# /usr/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     297             else:
#     298                 if timeout > 0:
# --> 299                     gotit = waiter.acquire(True, timeout)
#     300                 else:
#     301                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# ---

# %% [markdown]
# ## model4 - Acc: 0.65
#
# - dropout
# - 100 epochs

# %%
BATCH_SIZE = 32
IMG_SHAPE  = 32 
EPOCHS = 100
plottrain = True


test_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(test_folder,
                                                                        shuffle=True,
                                                                        target_size=(IMG_SHAPE,IMG_SHAPE),
                                                                        batch_size = BATCH_SIZE) 

val_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(val_folder,
                                                                       shuffle=False,
                                                                       #class_mode='binary',
                                                                       target_size=(IMG_SHAPE,IMG_SHAPE),
                                                                       batch_size = BATCH_SIZE)

train_generator = ImageDataGenerator(rescale=1./255,
                                     brightness_range=(.2,1),
                                     shear_range=0.2,
                                     channel_shift_range=128,
                                     rotation_range=45,
                                     vertical_flip=True,
                                     zoom_range=0.5,).flow_from_directory(train_folder,
                                                                          shuffle=True,
                                                                          #class_mode='binary',
                                                                          target_size=(IMG_SHAPE,IMG_SHAPE),
                                                                          batch_size=BATCH_SIZE)
# model4 = VGG16(weights='imagenet', include_top=False,input_shape=(IMG_SHAPE ,IMG_SHAPE,  3))
# model4.layers.pop()
# model4 = Model(inputs=model4.inputs, outputs=model4.layers[-1].output)

model4 = models.Sequential(name='CNN 4')

model4.add(layers.Conv2D(768, (3,3), activation='relu',input_shape=(IMG_SHAPE ,IMG_SHAPE,  3)))
model4.add(layers.MaxPooling2D((3, 3)))


model4.add(layers.Conv2D(1024, (3,3), activation='relu', padding="same"))
model4.add(layers.MaxPooling2D((3, 3)))
model4.add(layers.Dropout(0.05))

model4.add(layers.Conv2D(512, (3,3), activation='relu', padding="same"))
model4.add(layers.MaxPooling2D((3, 3)))

model4.add(layers.Conv2D(256, (3,3), activation='relu', padding="same"))
#model4.add(layers.MaxPooling2D((3, 3))) 

model4.add(layers.Flatten())
model4.add(layers.Dense(15, activation='softmax'))

# learning

model4.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['acc'])
model4.summary()

checkpoint = ModelCheckpoint("/content/drive/My Drive/RxID/RxID15/Models/RxID15{}".format(model4.name), monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_acc', min_delta=0, patience=20, verbose=1, mode='auto')


history = model4.fit(train_generator,
                    epochs=EPOCHS,
                    #batch_size=32,
                    #validation_split= 0.1,
                    validation_data=val_generator,
                     callbacks=[checkpoint,early],
                    verbose=1)

results_train1 = model4.evaluate(train_generator)
model4_val_results = model4.evaluate(val_generator)
model4_val_results
#model.predict_classes(val_images)

if plottrain == True:
  acc = history.history['acc']
  val_acc = history.history['val_acc']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs_range = range(EPOCHS)

  plt.figure(figsize=(16, 8))
  plt.subplot(1, 2, 1)
  plt.plot(epochs_range, acc, label='Training Accuracy')
  plt.plot(epochs_range, val_acc, label='Validation Accuracy')
  plt.legend(loc='lower right')
  plt.title('Training and Validation Accuracy')

  plt.subplot(1, 3, 3)
  plt.plot(epochs_range, loss, label='Training Loss')
  plt.plot(epochs_range, val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Training and Validation Loss')
  plt.savefig('/content/drive/My Drive/RxID/RxID15/Model Images/{}-Acc_Loss.png'.format(model4.name))
  plt.show()
model4_val_results
# Out:
# Found 74 images belonging to 15 classes.
# Found 150 images belonging to 15 classes.
# Found 525 images belonging to 15 classes.
# Model: "CNN 4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 30, 30, 768)       21504
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 10, 10, 768)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 10, 10, 1024)      7078912
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 3, 3, 1024)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 3, 3, 1024)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 3, 3, 512)         4719104
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 1, 1, 256)         1179904
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                3855
# =================================================================
# Total params: 13,003,279
# Trainable params: 13,003,279
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 17/17 [==============================] - 175s 10s/step - loss: 2.7187 - acc: 0.0457 - val_loss: 2.7215 - val_acc: 0.1133
#
# Epoch 00001: val_acc improved from -inf to 0.11333, saving model to vgg16_1.h5
# Epoch 2/100
# 17/17 [==============================] - 66s 4s/step - loss: 2.7095 - acc: 0.0724 - val_loss: 2.6854 - val_acc: 0.0533
#
# Epoch 00002: val_acc did not improve from 0.11333
# Epoch 3/100
# 17/17 [==============================] - 66s 4s/step - loss: 2.6736 - acc: 0.0933 - val_loss: 2.2427 - val_acc: 0.1000
#
# Epoch 00003: val_acc did not improve from 0.11333
# Epoch 4/100
# 17/17 [==============================] - 66s 4s/step - loss: 2.6022 - acc: 0.1124 - val_loss: 1.9244 - val_acc: 0.1467
#
# Epoch 00004: val_acc improved from 0.11333 to 0.14667, saving model to vgg16_1.h5
# Epoch 5/100
# 17/17 [==============================] - 66s 4s/step - loss: 2.5222 - acc: 0.1543 - val_loss: 2.0535 - val_acc: 0.2000
#
# Epoch 00005: val_acc improved from 0.14667 to 0.20000, saving model to vgg16_1.h5
# Epoch 6/100
# 17/17 [==============================] - 66s 4s/step - loss: 2.3912 - acc: 0.1486 - val_loss: 1.6379 - val_acc: 0.2467
#
# Epoch 00006: val_acc improved from 0.20000 to 0.24667, saving model to vgg16_1.h5
# Epoch 7/100
# 17/17 [==============================] - 66s 4s/step - loss: 2.2443 - acc: 0.2000 - val_loss: 1.6127 - val_acc: 0.2733
#
# Epoch 00007: val_acc improved from 0.24667 to 0.27333, saving model to vgg16_1.h5
# Epoch 8/100
# 17/17 [==============================] - 66s 4s/step - loss: 2.1585 - acc: 0.2038 - val_loss: 1.1886 - val_acc: 0.2333
#
# Epoch 00008: val_acc did not improve from 0.27333
# Epoch 9/100
# 17/17 [==============================] - 67s 4s/step - loss: 2.0942 - acc: 0.2362 - val_loss: 1.4982 - val_acc: 0.3400
#
# Epoch 00009: val_acc improved from 0.27333 to 0.34000, saving model to vgg16_1.h5
# Epoch 10/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.9692 - acc: 0.2781 - val_loss: 0.9404 - val_acc: 0.3267
#
# Epoch 00010: val_acc did not improve from 0.34000
# Epoch 11/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.9311 - acc: 0.2819 - val_loss: 1.2228 - val_acc: 0.2800
#
# Epoch 00011: val_acc did not improve from 0.34000
# Epoch 12/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.8859 - acc: 0.3257 - val_loss: 0.9933 - val_acc: 0.3867
#
# Epoch 00012: val_acc improved from 0.34000 to 0.38667, saving model to vgg16_1.h5
# Epoch 13/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.8473 - acc: 0.3048 - val_loss: 1.5438 - val_acc: 0.3867
#
# Epoch 00013: val_acc did not improve from 0.38667
# Epoch 14/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.8897 - acc: 0.3048 - val_loss: 0.6166 - val_acc: 0.3467
#
# Epoch 00014: val_acc did not improve from 0.38667
# Epoch 15/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.8235 - acc: 0.3238 - val_loss: 0.6288 - val_acc: 0.4133
#
# Epoch 00015: val_acc improved from 0.38667 to 0.41333, saving model to vgg16_1.h5
# Epoch 16/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.7250 - acc: 0.3543 - val_loss: 0.5480 - val_acc: 0.4267
#
# Epoch 00016: val_acc improved from 0.41333 to 0.42667, saving model to vgg16_1.h5
# Epoch 17/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.7566 - acc: 0.3505 - val_loss: 1.9592 - val_acc: 0.4200
#
# Epoch 00017: val_acc did not improve from 0.42667
# Epoch 18/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.7403 - acc: 0.3771 - val_loss: 0.7673 - val_acc: 0.4600
#
# Epoch 00018: val_acc improved from 0.42667 to 0.46000, saving model to vgg16_1.h5
# Epoch 19/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.6149 - acc: 0.3848 - val_loss: 1.2215 - val_acc: 0.3867
#
# Epoch 00019: val_acc did not improve from 0.46000
# Epoch 20/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.6902 - acc: 0.3810 - val_loss: 1.2952 - val_acc: 0.4067
#
# Epoch 00020: val_acc did not improve from 0.46000
# Epoch 21/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.6694 - acc: 0.3600 - val_loss: 1.0482 - val_acc: 0.4067
#
# Epoch 00021: val_acc did not improve from 0.46000
# Epoch 22/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.6058 - acc: 0.3962 - val_loss: 0.8821 - val_acc: 0.4200
#
# Epoch 00022: val_acc did not improve from 0.46000
# Epoch 23/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.6372 - acc: 0.3867 - val_loss: 0.8296 - val_acc: 0.4133
#
# Epoch 00023: val_acc did not improve from 0.46000
# Epoch 24/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.5865 - acc: 0.4324 - val_loss: 0.8336 - val_acc: 0.4067
#
# Epoch 00024: val_acc did not improve from 0.46000
# Epoch 25/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.4722 - acc: 0.4533 - val_loss: 0.5429 - val_acc: 0.4333
#
# Epoch 00025: val_acc did not improve from 0.46000
# Epoch 26/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.5381 - acc: 0.4362 - val_loss: 0.8887 - val_acc: 0.3867
#
# Epoch 00026: val_acc did not improve from 0.46000
# Epoch 27/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.5815 - acc: 0.4019 - val_loss: 0.7605 - val_acc: 0.4600
#
# Epoch 00027: val_acc did not improve from 0.46000
# Epoch 28/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.5496 - acc: 0.4248 - val_loss: 0.4966 - val_acc: 0.4933
#
# Epoch 00028: val_acc improved from 0.46000 to 0.49333, saving model to vgg16_1.h5
# Epoch 29/100
# 17/17 [==============================] - 68s 4s/step - loss: 1.5284 - acc: 0.4210 - val_loss: 0.5641 - val_acc: 0.4400
#
# Epoch 00029: val_acc did not improve from 0.49333
# Epoch 30/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.4696 - acc: 0.4610 - val_loss: 0.8995 - val_acc: 0.5200
#
# Epoch 00030: val_acc improved from 0.49333 to 0.52000, saving model to vgg16_1.h5
# Epoch 31/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.4534 - acc: 0.4781 - val_loss: 0.4184 - val_acc: 0.5200
#
# Epoch 00031: val_acc did not improve from 0.52000
# Epoch 32/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.3804 - acc: 0.4781 - val_loss: 0.4868 - val_acc: 0.4667
#
# Epoch 00032: val_acc did not improve from 0.52000
# Epoch 33/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.4238 - acc: 0.4686 - val_loss: 0.5250 - val_acc: 0.5200
#
# Epoch 00033: val_acc did not improve from 0.52000
# Epoch 34/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.4652 - acc: 0.4571 - val_loss: 0.3060 - val_acc: 0.4867
#
# Epoch 00034: val_acc did not improve from 0.52000
# Epoch 35/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.4492 - acc: 0.4762 - val_loss: 0.7006 - val_acc: 0.4733
#
# Epoch 00035: val_acc did not improve from 0.52000
# Epoch 36/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.3761 - acc: 0.5029 - val_loss: 0.5869 - val_acc: 0.4933
#
# Epoch 00036: val_acc did not improve from 0.52000
# Epoch 37/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.5592 - acc: 0.4571 - val_loss: 0.6877 - val_acc: 0.4333
#
# Epoch 00037: val_acc did not improve from 0.52000
# Epoch 38/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.4303 - acc: 0.4743 - val_loss: 0.8209 - val_acc: 0.4667
#
# Epoch 00038: val_acc did not improve from 0.52000
# Epoch 39/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.4490 - acc: 0.4629 - val_loss: 0.5494 - val_acc: 0.4933
#
# Epoch 00039: val_acc did not improve from 0.52000
# Epoch 40/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.4698 - acc: 0.4552 - val_loss: 0.7244 - val_acc: 0.5000
#
# Epoch 00040: val_acc did not improve from 0.52000
# Epoch 41/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.3764 - acc: 0.4876 - val_loss: 0.6666 - val_acc: 0.4333
#
# Epoch 00041: val_acc did not improve from 0.52000
# Epoch 42/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.4797 - acc: 0.4762 - val_loss: 0.5224 - val_acc: 0.5067
#
# Epoch 00042: val_acc did not improve from 0.52000
# Epoch 43/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.3796 - acc: 0.4971 - val_loss: 0.6445 - val_acc: 0.5467
#
# Epoch 00043: val_acc improved from 0.52000 to 0.54667, saving model to vgg16_1.h5
# Epoch 44/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.2665 - acc: 0.5238 - val_loss: 0.5879 - val_acc: 0.5333
#
# Epoch 00044: val_acc did not improve from 0.54667
# Epoch 45/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.3494 - acc: 0.5086 - val_loss: 1.2179 - val_acc: 0.4333
#
# Epoch 00045: val_acc did not improve from 0.54667
# Epoch 46/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.3380 - acc: 0.4781 - val_loss: 0.2652 - val_acc: 0.5067
#
# Epoch 00046: val_acc did not improve from 0.54667
# Epoch 47/100
# 17/17 [==============================] - 68s 4s/step - loss: 1.3220 - acc: 0.5238 - val_loss: 0.3284 - val_acc: 0.5133
#
# Epoch 00047: val_acc did not improve from 0.54667
# Epoch 48/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.2763 - acc: 0.5162 - val_loss: 0.7418 - val_acc: 0.5267
#
# Epoch 00048: val_acc did not improve from 0.54667
# Epoch 49/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.2429 - acc: 0.5276 - val_loss: 0.3357 - val_acc: 0.5467
#
# Epoch 00049: val_acc did not improve from 0.54667
# Epoch 50/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.2536 - acc: 0.5314 - val_loss: 0.7201 - val_acc: 0.4800
#
# Epoch 00050: val_acc did not improve from 0.54667
# Epoch 51/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.2053 - acc: 0.5257 - val_loss: 0.4879 - val_acc: 0.5467
#
# Epoch 00051: val_acc did not improve from 0.54667
# Epoch 52/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.3389 - acc: 0.4914 - val_loss: 1.3395 - val_acc: 0.4000
#
# Epoch 00052: val_acc did not improve from 0.54667
# Epoch 53/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.3594 - acc: 0.4990 - val_loss: 0.3201 - val_acc: 0.5000
#
# Epoch 00053: val_acc did not improve from 0.54667
# Epoch 54/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.3287 - acc: 0.5238 - val_loss: 1.3583 - val_acc: 0.4800
#
# Epoch 00054: val_acc did not improve from 0.54667
# Epoch 55/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.2279 - acc: 0.5486 - val_loss: 0.3866 - val_acc: 0.4933
#
# Epoch 00055: val_acc did not improve from 0.54667
# Epoch 56/100
# 17/17 [==============================] - 68s 4s/step - loss: 1.3090 - acc: 0.5029 - val_loss: 0.5344 - val_acc: 0.5400
#
# Epoch 00056: val_acc did not improve from 0.54667
# Epoch 57/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.3049 - acc: 0.5029 - val_loss: 0.4298 - val_acc: 0.5267
#
# Epoch 00057: val_acc did not improve from 0.54667
# Epoch 58/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.2389 - acc: 0.5467 - val_loss: 0.1931 - val_acc: 0.6067
#
# Epoch 00058: val_acc improved from 0.54667 to 0.60667, saving model to vgg16_1.h5
# Epoch 59/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.2011 - acc: 0.5752 - val_loss: 0.2375 - val_acc: 0.5533
#
# Epoch 00059: val_acc did not improve from 0.60667
# Epoch 60/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.2443 - acc: 0.5238 - val_loss: 0.6974 - val_acc: 0.5600
#
# Epoch 00060: val_acc did not improve from 0.60667
# Epoch 61/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.1177 - acc: 0.5943 - val_loss: 0.2116 - val_acc: 0.5867
#
# Epoch 00061: val_acc did not improve from 0.60667
# Epoch 62/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.1672 - acc: 0.5924 - val_loss: 0.0767 - val_acc: 0.5467
#
# Epoch 00062: val_acc did not improve from 0.60667
# Epoch 63/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.2211 - acc: 0.5524 - val_loss: 0.3996 - val_acc: 0.5400
#
# Epoch 00063: val_acc did not improve from 0.60667
# Epoch 64/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.1633 - acc: 0.5657 - val_loss: 0.3263 - val_acc: 0.5200
#
# Epoch 00064: val_acc did not improve from 0.60667
# Epoch 65/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.1898 - acc: 0.5790 - val_loss: 0.1026 - val_acc: 0.5933
#
# Epoch 00065: val_acc did not improve from 0.60667
# Epoch 66/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.2360 - acc: 0.5295 - val_loss: 0.0979 - val_acc: 0.5000
#
# Epoch 00066: val_acc did not improve from 0.60667
# Epoch 67/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.2510 - acc: 0.5105 - val_loss: 0.1495 - val_acc: 0.5800
#
# Epoch 00067: val_acc did not improve from 0.60667
# Epoch 68/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.1818 - acc: 0.5448 - val_loss: 0.3710 - val_acc: 0.5533
#
# Epoch 00068: val_acc did not improve from 0.60667
# Epoch 69/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.1725 - acc: 0.5829 - val_loss: 0.1850 - val_acc: 0.5533
#
# Epoch 00069: val_acc did not improve from 0.60667
# Epoch 70/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.1542 - acc: 0.6019 - val_loss: 0.4626 - val_acc: 0.5200
#
# Epoch 00070: val_acc did not improve from 0.60667
# Epoch 71/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.0967 - acc: 0.6057 - val_loss: 0.4418 - val_acc: 0.4933
#
# Epoch 00071: val_acc did not improve from 0.60667
# Epoch 72/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.0800 - acc: 0.5695 - val_loss: 0.3350 - val_acc: 0.5467
#
# Epoch 00072: val_acc did not improve from 0.60667
# Epoch 73/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.1280 - acc: 0.5695 - val_loss: 0.4967 - val_acc: 0.6000
#
# Epoch 00073: val_acc did not improve from 0.60667
# Epoch 74/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.0904 - acc: 0.5676 - val_loss: 0.4283 - val_acc: 0.5667
#
# Epoch 00074: val_acc did not improve from 0.60667
# Epoch 75/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.1491 - acc: 0.6019 - val_loss: 0.1726 - val_acc: 0.6400
#
# Epoch 00075: val_acc improved from 0.60667 to 0.64000, saving model to vgg16_1.h5
# Epoch 76/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.0995 - acc: 0.6076 - val_loss: 0.4068 - val_acc: 0.6267
#
# Epoch 00076: val_acc did not improve from 0.64000
# Epoch 77/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.0957 - acc: 0.5867 - val_loss: 0.7149 - val_acc: 0.6467
#
# Epoch 00077: val_acc improved from 0.64000 to 0.64667, saving model to vgg16_1.h5
# Epoch 78/100
# 17/17 [==============================] - 68s 4s/step - loss: 1.1493 - acc: 0.5886 - val_loss: 0.5418 - val_acc: 0.6000
#
# Epoch 00078: val_acc did not improve from 0.64667
# Epoch 79/100
# 17/17 [==============================] - 68s 4s/step - loss: 1.1448 - acc: 0.5695 - val_loss: 0.1890 - val_acc: 0.6400
#
# Epoch 00079: val_acc did not improve from 0.64667
# Epoch 80/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.1030 - acc: 0.6057 - val_loss: 0.2771 - val_acc: 0.6000
#
# Epoch 00080: val_acc did not improve from 0.64667
# Epoch 81/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.0695 - acc: 0.5962 - val_loss: 0.3055 - val_acc: 0.6267
#
# Epoch 00081: val_acc did not improve from 0.64667
# Epoch 82/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.0807 - acc: 0.5981 - val_loss: 0.3161 - val_acc: 0.6400
#
# Epoch 00082: val_acc did not improve from 0.64667
# Epoch 83/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.0739 - acc: 0.6095 - val_loss: 0.1803 - val_acc: 0.6000
#
# Epoch 00083: val_acc did not improve from 0.64667
# Epoch 84/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.0498 - acc: 0.6190 - val_loss: 0.1292 - val_acc: 0.6400
#
# Epoch 00084: val_acc did not improve from 0.64667
# Epoch 85/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.0352 - acc: 0.6190 - val_loss: 0.6183 - val_acc: 0.6733
#
# Epoch 00085: val_acc improved from 0.64667 to 0.67333, saving model to vgg16_1.h5
# Epoch 86/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.0411 - acc: 0.6190 - val_loss: 0.1614 - val_acc: 0.5867
#
# Epoch 00086: val_acc did not improve from 0.67333
# Epoch 87/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.0238 - acc: 0.6171 - val_loss: 0.1068 - val_acc: 0.6133
#
# Epoch 00087: val_acc did not improve from 0.67333
# Epoch 88/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.0478 - acc: 0.6248 - val_loss: 1.1316 - val_acc: 0.5333
#
# Epoch 00088: val_acc did not improve from 0.67333
# Epoch 89/100
# 17/17 [==============================] - 67s 4s/step - loss: 0.9900 - acc: 0.6476 - val_loss: 0.3048 - val_acc: 0.5733
#
# Epoch 00089: val_acc did not improve from 0.67333
# Epoch 90/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.0855 - acc: 0.6362 - val_loss: 0.1853 - val_acc: 0.5733
#
# Epoch 00090: val_acc did not improve from 0.67333
# Epoch 91/100
# 17/17 [==============================] - 67s 4s/step - loss: 0.9910 - acc: 0.6667 - val_loss: 0.1124 - val_acc: 0.6600
#
# Epoch 00091: val_acc did not improve from 0.67333
# Epoch 92/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.0246 - acc: 0.6248 - val_loss: 0.0505 - val_acc: 0.6667
#
# Epoch 00092: val_acc did not improve from 0.67333
# Epoch 93/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.0017 - acc: 0.6305 - val_loss: 0.2757 - val_acc: 0.6133
#
# Epoch 00093: val_acc did not improve from 0.67333
# Epoch 94/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.0258 - acc: 0.6133 - val_loss: 0.5165 - val_acc: 0.6000
#
# Epoch 00094: val_acc did not improve from 0.67333
# Epoch 95/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.0316 - acc: 0.6190 - val_loss: 0.2200 - val_acc: 0.6400
#
# Epoch 00095: val_acc did not improve from 0.67333
# Epoch 96/100
# 17/17 [==============================] - 67s 4s/step - loss: 0.9920 - acc: 0.6152 - val_loss: 0.2302 - val_acc: 0.6000
#
# Epoch 00096: val_acc did not improve from 0.67333
# Epoch 97/100
# 17/17 [==============================] - 67s 4s/step - loss: 0.9973 - acc: 0.6400 - val_loss: 0.3604 - val_acc: 0.5800
#
# Epoch 00097: val_acc did not improve from 0.67333
# Epoch 98/100
# 17/17 [==============================] - 67s 4s/step - loss: 0.8949 - acc: 0.6667 - val_loss: 0.3846 - val_acc: 0.6733
#
# Epoch 00098: val_acc did not improve from 0.67333
# Epoch 99/100
# 17/17 [==============================] - 67s 4s/step - loss: 0.9118 - acc: 0.6705 - val_loss: 0.0703 - val_acc: 0.6467
#
# Epoch 00099: val_acc did not improve from 0.67333
# Epoch 100/100
# 17/17 [==============================] - 67s 4s/step - loss: 0.9373 - acc: 0.6590 - val_loss: 0.1646 - val_acc: 0.6467
#
# Epoch 00100: val_acc did not improve from 0.67333
# 17/17 [==============================] - 64s 4s/step
# 5/5 [==============================] - 17s 3s/step
# [0.1645990014076233, 0.6466666460037231]

# %% [markdown]
# ## model5 -
#
#
# - dropout
# - 150 epochs

# %%
BATCH_SIZE = 32
IMG_SHAPE  = 32 
EPOCHS = 100
plottrain = True


test_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(test_folder,
                                                                        shuffle=True,
                                                                        target_size=(IMG_SHAPE,IMG_SHAPE),
                                                                        batch_size = BATCH_SIZE) 

val_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(val_folder,
                                                                       shuffle=False,
                                                                       #class_mode='binary',
                                                                       target_size=(IMG_SHAPE,IMG_SHAPE),
                                                                       batch_size = BATCH_SIZE)

train_generator = ImageDataGenerator(rescale=1./255,
                                     brightness_range=(.2,1),
                                     shear_range=0.2,
                                     channel_shift_range=128,
                                     rotation_range=45,
                                     vertical_flip=True,
                                     zoom_range=0.5,).flow_from_directory(train_folder,
                                                                          shuffle=True,
                                                                          #class_mode='binary',
                                                                          target_size=(IMG_SHAPE,IMG_SHAPE),
                                                                          batch_size=BATCH_SIZE)
# model5 = VGG16(weights='imagenet', include_top=False,input_shape=(IMG_SHAPE ,IMG_SHAPE,  3))
# model5.layers.pop()
# model5 = Model(inputs=model5.inputs, outputs=model5.layers[-1].output)

model5 = models.Sequential(name='CNN 4')

model5.add(layers.Conv2D(768, (3,3), activation='relu',input_shape=(IMG_SHAPE ,IMG_SHAPE,  3)))
model5.add(layers.MaxPooling2D((3, 3)))


model5.add(layers.Conv2D(1024, (3,3), activation='relu', padding="same"))
model5.add(layers.MaxPooling2D((3, 3)))
model5.add(layers.Dropout(0.05))

model5.add(layers.Conv2D(512, (3,3), activation='relu', padding="same"))
model5.add(layers.MaxPooling2D((3, 3)))

model5.add(layers.Conv2D(256, (3,3), activation='relu', padding="same"))
#model5.add(layers.MaxPooling2D((3, 3))) 

model5.add(layers.Flatten())
model5.add(layers.Dense(15, activation='softmax'))

# learning

model5.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['acc'])
model5.summary()

checkpoint = ModelCheckpoint("/content/drive/My Drive/RxID/RxID15/Models/RxID15{}".format(model5.name), monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_acc', min_delta=0, patience=20, verbose=1, mode='auto')


history = model5.fit(train_generator,
                    epochs=EPOCHS,
                    #batch_size=32,
                    #validation_split= 0.1,
                    validation_data=val_generator,
                     callbacks=[checkpoint,early],
                    verbose=1)

results_train1 = model5.evaluate(train_generator)
model5_val_results = model5.evaluate(val_generator)
model5_val_results
#model.predict_classes(val_images)

if plottrain == True:
  acc = history.history['acc']
  val_acc = history.history['val_acc']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs_range = range(EPOCHS)

  plt.figure(figsize=(16, 8))
  plt.subplot(1, 2, 1)
  plt.plot(epochs_range, acc, label='Training Accuracy')
  plt.plot(epochs_range, val_acc, label='Validation Accuracy')
  plt.legend(loc='lower right')
  plt.title('Training and Validation Accuracy')

  plt.subplot(1, 3, 3)
  plt.plot(epochs_range, loss, label='Training Loss')
  plt.plot(epochs_range, val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Training and Validation Loss')
  plt.savefig('/content/drive/My Drive/RxID/RxID15/Model Images/{}-Acc_Loss.png'.format(model5.name))
  plt.show()
model5_val_results
# Out:
# Found 74 images belonging to 15 classes.
# Found 150 images belonging to 15 classes.
# Found 525 images belonging to 15 classes.
# Model: "CNN 4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 30, 30, 768)       21504
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 768)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 1024)      7078912
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 1024)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 3, 1024)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 512)         4719104
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 1, 1, 256)         1179904
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                3855
# =================================================================
# Total params: 13,003,279
# Trainable params: 13,003,279
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 17/17 [==============================] - 197s 12s/step - loss: 2.7125 - acc: 0.0571 - val_loss: 2.7349 - val_acc: 0.1133
#
# Epoch 00001: val_acc improved from -inf to 0.11333, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 2/100
# 17/17 [==============================] - 65s 4s/step - loss: 2.6283 - acc: 0.0724 - val_loss: 2.7608 - val_acc: 0.1267
#
# Epoch 00002: val_acc improved from 0.11333 to 0.12667, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 3/100
# 17/17 [==============================] - 65s 4s/step - loss: 2.5747 - acc: 0.0895 - val_loss: 2.8220 - val_acc: 0.1733
#
# Epoch 00003: val_acc improved from 0.12667 to 0.17333, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 4/100
# 17/17 [==============================] - 65s 4s/step - loss: 2.4507 - acc: 0.1257 - val_loss: 2.0791 - val_acc: 0.1600
#
# Epoch 00004: val_acc did not improve from 0.17333
# Epoch 5/100
# 17/17 [==============================] - 65s 4s/step - loss: 2.3613 - acc: 0.1733 - val_loss: 2.4450 - val_acc: 0.1867
#
# Epoch 00005: val_acc improved from 0.17333 to 0.18667, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 6/100
# 17/17 [==============================] - 65s 4s/step - loss: 2.3912 - acc: 0.1638 - val_loss: 2.6141 - val_acc: 0.1467
#
# Epoch 00006: val_acc did not improve from 0.18667
# Epoch 7/100
# 17/17 [==============================] - 65s 4s/step - loss: 2.2609 - acc: 0.1829 - val_loss: 2.0372 - val_acc: 0.2600
#
# Epoch 00007: val_acc improved from 0.18667 to 0.26000, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 8/100
# 17/17 [==============================] - 65s 4s/step - loss: 2.1746 - acc: 0.2076 - val_loss: 1.7533 - val_acc: 0.2800
#
# Epoch 00008: val_acc improved from 0.26000 to 0.28000, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 9/100
# 17/17 [==============================] - 65s 4s/step - loss: 2.1448 - acc: 0.2190 - val_loss: 1.5518 - val_acc: 0.2800
#
# Epoch 00009: val_acc did not improve from 0.28000
# Epoch 10/100
# 17/17 [==============================] - 65s 4s/step - loss: 2.0956 - acc: 0.2476 - val_loss: 2.1126 - val_acc: 0.2733
#
# Epoch 00010: val_acc did not improve from 0.28000
# Epoch 11/100
# 17/17 [==============================] - 65s 4s/step - loss: 2.1180 - acc: 0.2495 - val_loss: 1.4380 - val_acc: 0.3133
#
# Epoch 00011: val_acc improved from 0.28000 to 0.31333, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 12/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.9826 - acc: 0.2800 - val_loss: 1.1687 - val_acc: 0.3200
#
# Epoch 00012: val_acc improved from 0.31333 to 0.32000, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 13/100
# 17/17 [==============================] - 67s 4s/step - loss: 1.9621 - acc: 0.2933 - val_loss: 1.3697 - val_acc: 0.3267
#
# Epoch 00013: val_acc improved from 0.32000 to 0.32667, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 14/100
# 17/17 [==============================] - 65s 4s/step - loss: 1.8653 - acc: 0.3143 - val_loss: 0.6514 - val_acc: 0.3867
#
# Epoch 00014: val_acc improved from 0.32667 to 0.38667, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 15/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.9651 - acc: 0.2952 - val_loss: 0.8198 - val_acc: 0.3333
#
# Epoch 00015: val_acc did not improve from 0.38667
# Epoch 16/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.7785 - acc: 0.3181 - val_loss: 1.0327 - val_acc: 0.4133
#
# Epoch 00016: val_acc improved from 0.38667 to 0.41333, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 17/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.7006 - acc: 0.3829 - val_loss: 0.5710 - val_acc: 0.4067
#
# Epoch 00017: val_acc did not improve from 0.41333
# Epoch 18/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.7204 - acc: 0.3543 - val_loss: 0.7503 - val_acc: 0.3667
#
# Epoch 00018: val_acc did not improve from 0.41333
# Epoch 19/100
# 17/17 [==============================] - 65s 4s/step - loss: 1.7292 - acc: 0.3619 - val_loss: 1.1410 - val_acc: 0.3867
#
# Epoch 00019: val_acc did not improve from 0.41333
# Epoch 20/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.7320 - acc: 0.3467 - val_loss: 0.9567 - val_acc: 0.4067
#
# Epoch 00020: val_acc did not improve from 0.41333
# Epoch 21/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.6425 - acc: 0.4019 - val_loss: 0.5866 - val_acc: 0.4467
#
# Epoch 00021: val_acc improved from 0.41333 to 0.44667, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 22/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.7150 - acc: 0.3790 - val_loss: 1.0634 - val_acc: 0.3400
#
# Epoch 00022: val_acc did not improve from 0.44667
# Epoch 23/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.7117 - acc: 0.3771 - val_loss: 0.9086 - val_acc: 0.4133
#
# Epoch 00023: val_acc did not improve from 0.44667
# Epoch 24/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.6655 - acc: 0.4171 - val_loss: 1.1169 - val_acc: 0.4000
#
# Epoch 00024: val_acc did not improve from 0.44667
# Epoch 25/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.6384 - acc: 0.4114 - val_loss: 1.1777 - val_acc: 0.4333
#
# Epoch 00025: val_acc did not improve from 0.44667
# Epoch 26/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.6062 - acc: 0.4286 - val_loss: 1.1082 - val_acc: 0.4267
#
# Epoch 00026: val_acc did not improve from 0.44667
# Epoch 27/100
# 17/17 [==============================] - 65s 4s/step - loss: 1.5569 - acc: 0.4362 - val_loss: 0.5922 - val_acc: 0.4067
#
# Epoch 00027: val_acc did not improve from 0.44667
# Epoch 28/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.5764 - acc: 0.4076 - val_loss: 0.8807 - val_acc: 0.4067
#
# Epoch 00028: val_acc did not improve from 0.44667
# Epoch 29/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.5255 - acc: 0.4495 - val_loss: 0.6822 - val_acc: 0.4000
#
# Epoch 00029: val_acc did not improve from 0.44667
# Epoch 30/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.4635 - acc: 0.4743 - val_loss: 0.8939 - val_acc: 0.4533
#
# Epoch 00030: val_acc improved from 0.44667 to 0.45333, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 31/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.4991 - acc: 0.4610 - val_loss: 0.7226 - val_acc: 0.4667
#
# Epoch 00031: val_acc improved from 0.45333 to 0.46667, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 32/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.5449 - acc: 0.4057 - val_loss: 1.2752 - val_acc: 0.4600
#
# Epoch 00032: val_acc did not improve from 0.46667
# Epoch 33/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.4918 - acc: 0.4400 - val_loss: 0.5373 - val_acc: 0.4400
#
# Epoch 00033: val_acc did not improve from 0.46667
# Epoch 34/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.5199 - acc: 0.4381 - val_loss: 0.7097 - val_acc: 0.4067
#
# Epoch 00034: val_acc did not improve from 0.46667
# Epoch 35/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.4507 - acc: 0.4514 - val_loss: 0.8547 - val_acc: 0.4733
#
# Epoch 00035: val_acc improved from 0.46667 to 0.47333, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 36/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.4291 - acc: 0.4819 - val_loss: 1.5654 - val_acc: 0.4467
#
# Epoch 00036: val_acc did not improve from 0.47333
# Epoch 37/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.3907 - acc: 0.5105 - val_loss: 0.4489 - val_acc: 0.4400
#
# Epoch 00037: val_acc did not improve from 0.47333
# Epoch 38/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.4783 - acc: 0.4590 - val_loss: 0.5662 - val_acc: 0.4467
#
# Epoch 00038: val_acc did not improve from 0.47333
# Epoch 39/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.4836 - acc: 0.4400 - val_loss: 0.6489 - val_acc: 0.4667
#
# Epoch 00039: val_acc did not improve from 0.47333
# Epoch 40/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.4805 - acc: 0.4971 - val_loss: 1.1306 - val_acc: 0.4267
#
# Epoch 00040: val_acc did not improve from 0.47333
# Epoch 41/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.3720 - acc: 0.4895 - val_loss: 0.8374 - val_acc: 0.4667
#
# Epoch 00041: val_acc did not improve from 0.47333
# Epoch 42/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.4330 - acc: 0.4533 - val_loss: 0.8304 - val_acc: 0.4533
#
# Epoch 00042: val_acc did not improve from 0.47333
# Epoch 43/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.3556 - acc: 0.4762 - val_loss: 1.1282 - val_acc: 0.4933
#
# Epoch 00043: val_acc improved from 0.47333 to 0.49333, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 44/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.4501 - acc: 0.4514 - val_loss: 1.2945 - val_acc: 0.4733
#
# Epoch 00044: val_acc did not improve from 0.49333
# Epoch 45/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.4089 - acc: 0.4610 - val_loss: 0.7893 - val_acc: 0.4600
#
# Epoch 00045: val_acc did not improve from 0.49333
# Epoch 46/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.4422 - acc: 0.5029 - val_loss: 0.7269 - val_acc: 0.4467
#
# Epoch 00046: val_acc did not improve from 0.49333
# Epoch 47/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.4010 - acc: 0.4495 - val_loss: 0.7699 - val_acc: 0.4933
#
# Epoch 00047: val_acc did not improve from 0.49333
# Epoch 48/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.3278 - acc: 0.5238 - val_loss: 0.7239 - val_acc: 0.4667
#
# Epoch 00048: val_acc did not improve from 0.49333
# Epoch 49/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.3120 - acc: 0.4857 - val_loss: 0.8040 - val_acc: 0.5000
#
# Epoch 00049: val_acc improved from 0.49333 to 0.50000, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 50/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.2788 - acc: 0.5067 - val_loss: 0.6598 - val_acc: 0.4867
#
# Epoch 00050: val_acc did not improve from 0.50000
# Epoch 51/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.2922 - acc: 0.4933 - val_loss: 1.3942 - val_acc: 0.5000
#
# Epoch 00051: val_acc did not improve from 0.50000
# Epoch 52/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.4034 - acc: 0.4724 - val_loss: 0.8763 - val_acc: 0.5000
#
# Epoch 00052: val_acc did not improve from 0.50000
# Epoch 53/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.3413 - acc: 0.5067 - val_loss: 0.8242 - val_acc: 0.4800
#
# Epoch 00053: val_acc did not improve from 0.50000
# Epoch 54/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.3915 - acc: 0.4990 - val_loss: 1.0921 - val_acc: 0.4867
#
# Epoch 00054: val_acc did not improve from 0.50000
# Epoch 55/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.3479 - acc: 0.5238 - val_loss: 0.9523 - val_acc: 0.5000
#
# Epoch 00055: val_acc did not improve from 0.50000
# Epoch 56/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.3246 - acc: 0.4914 - val_loss: 0.9943 - val_acc: 0.5267
#
# Epoch 00056: val_acc improved from 0.50000 to 0.52667, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 57/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.3238 - acc: 0.4952 - val_loss: 0.9693 - val_acc: 0.4867
#
# Epoch 00057: val_acc did not improve from 0.52667
# Epoch 58/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.2675 - acc: 0.5352 - val_loss: 1.6286 - val_acc: 0.4733
#
# Epoch 00058: val_acc did not improve from 0.52667
# Epoch 59/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.3306 - acc: 0.5086 - val_loss: 0.2763 - val_acc: 0.5133
#
# Epoch 00059: val_acc did not improve from 0.52667
# Epoch 60/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.2202 - acc: 0.5257 - val_loss: 0.6622 - val_acc: 0.5667
#
# Epoch 00060: val_acc improved from 0.52667 to 0.56667, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 61/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.1649 - acc: 0.5886 - val_loss: 1.0608 - val_acc: 0.4600
#
# Epoch 00061: val_acc did not improve from 0.56667
# Epoch 62/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.2578 - acc: 0.5257 - val_loss: 0.6489 - val_acc: 0.4667
#
# Epoch 00062: val_acc did not improve from 0.56667
# Epoch 63/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.4096 - acc: 0.4971 - val_loss: 0.5475 - val_acc: 0.4600
#
# Epoch 00063: val_acc did not improve from 0.56667
# Epoch 64/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.3307 - acc: 0.5048 - val_loss: 0.6353 - val_acc: 0.5467
#
# Epoch 00064: val_acc did not improve from 0.56667
# Epoch 65/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.3119 - acc: 0.5238 - val_loss: 0.7724 - val_acc: 0.5200
#
# Epoch 00065: val_acc did not improve from 0.56667
# Epoch 66/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.1694 - acc: 0.5619 - val_loss: 0.2875 - val_acc: 0.5667
#
# Epoch 00066: val_acc did not improve from 0.56667
# Epoch 67/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.1865 - acc: 0.5486 - val_loss: 0.7333 - val_acc: 0.5200
#
# Epoch 00067: val_acc did not improve from 0.56667
# Epoch 68/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.1987 - acc: 0.5638 - val_loss: 0.5967 - val_acc: 0.4933
#
# Epoch 00068: val_acc did not improve from 0.56667
# Epoch 69/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.1922 - acc: 0.5714 - val_loss: 0.2687 - val_acc: 0.5667
#
# Epoch 00069: val_acc did not improve from 0.56667
# Epoch 70/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.2860 - acc: 0.5238 - val_loss: 0.4063 - val_acc: 0.5800
#
# Epoch 00070: val_acc improved from 0.56667 to 0.58000, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 71/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.1959 - acc: 0.5524 - val_loss: 0.7538 - val_acc: 0.4867
#
# Epoch 00071: val_acc did not improve from 0.58000
# Epoch 72/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.1494 - acc: 0.5848 - val_loss: 0.8175 - val_acc: 0.4933
#
# Epoch 00072: val_acc did not improve from 0.58000
# Epoch 73/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.1101 - acc: 0.5810 - val_loss: 0.4618 - val_acc: 0.5267
#
# Epoch 00073: val_acc did not improve from 0.58000
# Epoch 74/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.1149 - acc: 0.5981 - val_loss: 0.3843 - val_acc: 0.5733
#
# Epoch 00074: val_acc did not improve from 0.58000
# Epoch 75/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.1765 - acc: 0.6000 - val_loss: 0.3305 - val_acc: 0.5733
#
# Epoch 00075: val_acc did not improve from 0.58000
# Epoch 76/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.0692 - acc: 0.6133 - val_loss: 0.7995 - val_acc: 0.5400
#
# Epoch 00076: val_acc did not improve from 0.58000
# Epoch 77/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.1216 - acc: 0.5733 - val_loss: 0.7975 - val_acc: 0.5667
#
# Epoch 00077: val_acc did not improve from 0.58000
# Epoch 78/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.1669 - acc: 0.5771 - val_loss: 0.1556 - val_acc: 0.6133
#
# Epoch 00078: val_acc improved from 0.58000 to 0.61333, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 79/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.1095 - acc: 0.5962 - val_loss: 0.1606 - val_acc: 0.5667
#
# Epoch 00079: val_acc did not improve from 0.61333
# Epoch 80/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.1446 - acc: 0.5905 - val_loss: 0.1717 - val_acc: 0.6067
#
# Epoch 00080: val_acc did not improve from 0.61333
# Epoch 81/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.0772 - acc: 0.6095 - val_loss: 0.7351 - val_acc: 0.5267
#
# Epoch 00081: val_acc did not improve from 0.61333
# Epoch 82/100
# 17/17 [==============================] - 65s 4s/step - loss: 1.1086 - acc: 0.5943 - val_loss: 0.1882 - val_acc: 0.6267
#
# Epoch 00082: val_acc improved from 0.61333 to 0.62667, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 83/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.1020 - acc: 0.5905 - val_loss: 0.0927 - val_acc: 0.6200
#
# Epoch 00083: val_acc did not improve from 0.62667
# Epoch 84/100
# 17/17 [==============================] - 66s 4s/step - loss: 1.0924 - acc: 0.5752 - val_loss: 0.0910 - val_acc: 0.5600
#
# Epoch 00084: val_acc did not improve from 0.62667
# Epoch 85/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.1351 - acc: 0.5619 - val_loss: 0.0675 - val_acc: 0.5800
#
# Epoch 00085: val_acc did not improve from 0.62667
# Epoch 86/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.0299 - acc: 0.6095 - val_loss: 0.0428 - val_acc: 0.6333
#
# Epoch 00086: val_acc improved from 0.62667 to 0.63333, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 87/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.1092 - acc: 0.5943 - val_loss: 0.7682 - val_acc: 0.5733
#
# Epoch 00087: val_acc did not improve from 0.63333
# Epoch 88/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.1365 - acc: 0.5619 - val_loss: 0.1698 - val_acc: 0.6333
#
# Epoch 00088: val_acc did not improve from 0.63333
# Epoch 89/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.0632 - acc: 0.6267 - val_loss: 0.0888 - val_acc: 0.6000
#
# Epoch 00089: val_acc did not improve from 0.63333
# Epoch 90/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.0724 - acc: 0.6057 - val_loss: 0.2515 - val_acc: 0.6400
#
# Epoch 00090: val_acc improved from 0.63333 to 0.64000, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# Epoch 91/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.1728 - acc: 0.5581 - val_loss: 0.6722 - val_acc: 0.5133
#
# Epoch 00091: val_acc did not improve from 0.64000
# Epoch 92/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.1455 - acc: 0.5867 - val_loss: 0.1976 - val_acc: 0.6267
#
# Epoch 00092: val_acc did not improve from 0.64000
# Epoch 93/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.0765 - acc: 0.5981 - val_loss: 0.0495 - val_acc: 0.6267
#
# Epoch 00093: val_acc did not improve from 0.64000
# Epoch 94/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.0621 - acc: 0.5962 - val_loss: 0.7176 - val_acc: 0.5533
#
# Epoch 00094: val_acc did not improve from 0.64000
# Epoch 95/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.0739 - acc: 0.6190 - val_loss: 0.2186 - val_acc: 0.5933
#
# Epoch 00095: val_acc did not improve from 0.64000
# Epoch 96/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.0657 - acc: 0.6152 - val_loss: 0.1842 - val_acc: 0.5467
#
# Epoch 00096: val_acc did not improve from 0.64000
# Epoch 97/100
# 17/17 [==============================] - 64s 4s/step - loss: 0.9878 - acc: 0.6381 - val_loss: 0.4768 - val_acc: 0.6333
#
# Epoch 00097: val_acc did not improve from 0.64000
# Epoch 98/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.0302 - acc: 0.6286 - val_loss: 0.1185 - val_acc: 0.6400
#
# Epoch 00098: val_acc did not improve from 0.64000
# Epoch 99/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.0463 - acc: 0.6381 - val_loss: 0.1662 - val_acc: 0.6067
#
# Epoch 00099: val_acc did not improve from 0.64000
# Epoch 100/100
# 17/17 [==============================] - 64s 4s/step - loss: 1.0450 - acc: 0.6114 - val_loss: 0.1257 - val_acc: 0.6600
#
# Epoch 00100: val_acc improved from 0.64000 to 0.66000, saving model to /content/drive/My Drive/RxID/RxID15/Models/RxID15CNN 4
# 17/17 [==============================] - 62s 4s/step
# 5/5 [==============================] - 16s 3s/step
# [0.1257256716489792, 0.6600000262260437]

# %% [markdown]
# ## model6 -

# %%
test_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(test_folder,
                                                                        shuffle=True,
                                                                        target_size=(IMG_SHAPE,IMG_SHAPE))
# Out:
# Found 74 images belonging to 15 classes.

# %%
BATCH_SIZE = 32
IMG_SHAPE  = 36 
EPOCHS = 100
plottrain = True


test_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(test_folder,
                                                                        shuffle=True,
                                                                        target_size=(IMG_SHAPE,IMG_SHAPE),
                                                                        #batch_size = BATCH_SIZE) 

val_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(val_folder,
                                                                       shuffle=False,
                                                                       #class_mode='binary',
                                                                       target_size=(IMG_SHAPE,IMG_SHAPE),
                                                                       batch_size = BATCH_SIZE)

train_generator = ImageDataGenerator(rescale=1./255,
                                     brightness_range=(.2,1),
                                     shear_range=0.2,
                                     channel_shift_range=128,
                                     rotation_range=45,
                                     vertical_flip=True,
                                     zoom_range=0.5,).flow_from_directory(train_folder,
                                                                          shuffle=True,
                                                                          #class_mode='binary',
                                                                          target_size=(IMG_SHAPE,IMG_SHAPE),
                                                                          batch_size=BATCH_SIZE)
# model6 = VGG16(weights='imagenet', include_top=False,input_shape=(IMG_SHAPE ,IMG_SHAPE,  3))
# model6.layers.pop()
# model6 = Model(inputs=model6.inputs, outputs=model6.layers[-1].output)

model6 = models.Sequential(name='model6')

model6.add(layers.Conv2D(768, (3,3), activation='relu',input_shape=(IMG_SHAPE ,IMG_SHAPE,  3)))
model6.add(layers.MaxPooling2D((3, 3)))

model6.add(layers.Conv2D(1024, (3,3), activation='relu', padding="same"))
model6.add(layers.MaxPooling2D((3, 3)))
model6.add(layers.Dropout(0.05))

model6.add(layers.Conv2D(512, (3,3), activation='relu', padding="same"))
model6.add(layers.MaxPooling2D((3, 3)))

model6.add(layers.Conv2D(256, (3,3), activation='relu', padding="same"))
#model6.add(layers.MaxPooling2D((3, 3))) 

model6.add(layers.Flatten())
model6.add(layers.Dense(15, activation='softmax'))

model6.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['acc'])
model6.summary()

checkpoint = ModelCheckpoint("{}-{}".format(model6.name), monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_acc', min_delta=0, patience=20, verbose=1, mode='auto')


history = model6.fit(train_generator,
                    epochs=EPOCHS,
                    #batch_size=32,
                    #validation_split= 0.1,
                    validation_data=val_generator,
                     callbacks=[checkpoint,early],
                    verbose=1)

results_train1 = model6.evaluate(train_generator)
model6_val_results = model6.evaluate(val_generator)
model6_val_results
#model.predict_classes(val_images)

if plottrain == True:
  acc = history.history['acc']
  val_acc = history.history['val_acc']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs_range = range(EPOCHS)

  plt.figure(figsize=(16, 8))
  plt.subplot(1, 2, 1)
  plt.plot(epochs_range, acc, label='Training Accuracy')
  plt.plot(epochs_range, val_acc, label='Validation Accuracy')
  plt.legend(loc='lower right')
  plt.title('Training and Validation Accuracy')

  plt.subplot(1, 3, 3)
  plt.plot(epochs_range, loss, label='Training Loss')
  plt.plot(epochs_range, val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Training and Validation Loss')
  #plt.savefig('./foo.png')
  plt.show()
model6_val_results
# Out:
# Found 74 images belonging to 15 classes.
# Found 150 images belonging to 15 classes.
# Found 525 images belonging to 15 classes.
# Model: "CNN 4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 34, 34, 768)       21504
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 11, 11, 768)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 11, 11, 1024)      7078912
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 1024)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 3, 1024)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 512)         4719104
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 1, 1, 256)         1179904
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                3855
# =================================================================
# Total params: 13,003,279
# Trainable params: 13,003,279
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 17/17 [==============================] - 201s 12s/step - loss: 2.7158 - acc: 0.0495 - val_loss: 2.7106 - val_acc: 0.1133
#
# Epoch 00001: val_acc improved from -inf to 0.11333, saving model to vgg16_1.h5
# Epoch 2/50
# 17/17 [==============================] - 64s 4s/step - loss: 2.7013 - acc: 0.0876 - val_loss: 2.2212 - val_acc: 0.1200
#
# Epoch 00002: val_acc improved from 0.11333 to 0.12000, saving model to vgg16_1.h5
# Epoch 3/50
# 17/17 [==============================] - 64s 4s/step - loss: 2.6345 - acc: 0.1048 - val_loss: 2.3902 - val_acc: 0.1467
#
# Epoch 00003: val_acc improved from 0.12000 to 0.14667, saving model to vgg16_1.h5
# Epoch 4/50
# 17/17 [==============================] - 64s 4s/step - loss: 2.5200 - acc: 0.1333 - val_loss: 2.3514 - val_acc: 0.2067
#
# Epoch 00004: val_acc improved from 0.14667 to 0.20667, saving model to vgg16_1.h5
# Epoch 5/50
# 17/17 [==============================] - 65s 4s/step - loss: 2.3505 - acc: 0.1924 - val_loss: 1.3907 - val_acc: 0.3400
#
# Epoch 00005: val_acc improved from 0.20667 to 0.34000, saving model to vgg16_1.h5
# Epoch 6/50
# 17/17 [==============================] - 65s 4s/step - loss: 2.2105 - acc: 0.2438 - val_loss: 1.1538 - val_acc: 0.3267
#
# Epoch 00006: val_acc did not improve from 0.34000
# Epoch 7/50
# 17/17 [==============================] - 64s 4s/step - loss: 2.1092 - acc: 0.2819 - val_loss: 1.3704 - val_acc: 0.3333
#
# Epoch 00007: val_acc did not improve from 0.34000
# Epoch 8/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.9884 - acc: 0.2762 - val_loss: 2.5301 - val_acc: 0.3333
#
# Epoch 00008: val_acc did not improve from 0.34000
# Epoch 9/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.9269 - acc: 0.2952 - val_loss: 1.3323 - val_acc: 0.3733
#
# Epoch 00009: val_acc improved from 0.34000 to 0.37333, saving model to vgg16_1.h5
# Epoch 10/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.8237 - acc: 0.3352 - val_loss: 0.9630 - val_acc: 0.4200
#
# Epoch 00010: val_acc improved from 0.37333 to 0.42000, saving model to vgg16_1.h5
# Epoch 11/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.7745 - acc: 0.3543 - val_loss: 1.2884 - val_acc: 0.3400
#
# Epoch 00011: val_acc did not improve from 0.42000
# Epoch 12/50
# 17/17 [==============================] - 65s 4s/step - loss: 1.7281 - acc: 0.3619 - val_loss: 1.3990 - val_acc: 0.4133
#
# Epoch 00012: val_acc did not improve from 0.42000
# Epoch 13/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.7428 - acc: 0.3714 - val_loss: 0.8592 - val_acc: 0.3733
#
# Epoch 00013: val_acc did not improve from 0.42000
# Epoch 14/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.7743 - acc: 0.3486 - val_loss: 1.0669 - val_acc: 0.3533
#
# Epoch 00014: val_acc did not improve from 0.42000
# Epoch 15/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.7202 - acc: 0.3619 - val_loss: 1.0584 - val_acc: 0.4133
#
# Epoch 00015: val_acc did not improve from 0.42000
# Epoch 16/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.6702 - acc: 0.3981 - val_loss: 0.8625 - val_acc: 0.4000
#
# Epoch 00016: val_acc did not improve from 0.42000
# Epoch 17/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.6901 - acc: 0.3905 - val_loss: 0.6338 - val_acc: 0.3800
#
# Epoch 00017: val_acc did not improve from 0.42000
# Epoch 18/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.6164 - acc: 0.3962 - val_loss: 0.9483 - val_acc: 0.4133
#
# Epoch 00018: val_acc did not improve from 0.42000
# Epoch 19/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.6533 - acc: 0.4190 - val_loss: 0.6406 - val_acc: 0.3867
#
# Epoch 00019: val_acc did not improve from 0.42000
# Epoch 20/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.5557 - acc: 0.4324 - val_loss: 1.6483 - val_acc: 0.3800
#
# Epoch 00020: val_acc did not improve from 0.42000
# Epoch 21/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.5786 - acc: 0.4229 - val_loss: 0.8729 - val_acc: 0.4733
#
# Epoch 00021: val_acc improved from 0.42000 to 0.47333, saving model to vgg16_1.h5
# Epoch 22/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.5608 - acc: 0.4133 - val_loss: 0.8842 - val_acc: 0.4533
#
# Epoch 00022: val_acc did not improve from 0.47333
# Epoch 23/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.5302 - acc: 0.4400 - val_loss: 0.4199 - val_acc: 0.4533
#
# Epoch 00023: val_acc did not improve from 0.47333
# Epoch 24/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.4966 - acc: 0.4438 - val_loss: 0.5085 - val_acc: 0.5067
#
# Epoch 00024: val_acc improved from 0.47333 to 0.50667, saving model to vgg16_1.h5
# Epoch 25/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.5009 - acc: 0.4400 - val_loss: 0.5271 - val_acc: 0.5133
#
# Epoch 00025: val_acc improved from 0.50667 to 0.51333, saving model to vgg16_1.h5
# Epoch 26/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.5581 - acc: 0.4324 - val_loss: 0.6378 - val_acc: 0.4333
#
# Epoch 00026: val_acc did not improve from 0.51333
# Epoch 27/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.4705 - acc: 0.4648 - val_loss: 0.6178 - val_acc: 0.5067
#
# Epoch 00027: val_acc did not improve from 0.51333
# Epoch 28/50
# 17/17 [==============================] - 63s 4s/step - loss: 1.4094 - acc: 0.4590 - val_loss: 0.5787 - val_acc: 0.4333
#
# Epoch 00028: val_acc did not improve from 0.51333
# Epoch 29/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.4085 - acc: 0.4686 - val_loss: 0.2454 - val_acc: 0.5267
#
# Epoch 00029: val_acc improved from 0.51333 to 0.52667, saving model to vgg16_1.h5
# Epoch 30/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.5238 - acc: 0.4419 - val_loss: 1.1094 - val_acc: 0.4200
#
# Epoch 00030: val_acc did not improve from 0.52667
# Epoch 31/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.4347 - acc: 0.4724 - val_loss: 0.6036 - val_acc: 0.5133
#
# Epoch 00031: val_acc did not improve from 0.52667
# Epoch 32/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.4330 - acc: 0.4781 - val_loss: 0.6811 - val_acc: 0.4267
#
# Epoch 00032: val_acc did not improve from 0.52667
# Epoch 33/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.3816 - acc: 0.4743 - val_loss: 1.0003 - val_acc: 0.4867
#
# Epoch 00033: val_acc did not improve from 0.52667
# Epoch 34/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.4975 - acc: 0.4648 - val_loss: 0.6879 - val_acc: 0.4200
#
# Epoch 00034: val_acc did not improve from 0.52667
# Epoch 35/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.4214 - acc: 0.4686 - val_loss: 1.2324 - val_acc: 0.4867
#
# Epoch 00035: val_acc did not improve from 0.52667
# Epoch 36/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.3842 - acc: 0.4933 - val_loss: 0.4107 - val_acc: 0.4800
#
# Epoch 00036: val_acc did not improve from 0.52667
# Epoch 37/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.2948 - acc: 0.4990 - val_loss: 0.1190 - val_acc: 0.5667
#
# Epoch 00037: val_acc improved from 0.52667 to 0.56667, saving model to vgg16_1.h5
# Epoch 38/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.3574 - acc: 0.5162 - val_loss: 0.7310 - val_acc: 0.5533
#
# Epoch 00038: val_acc did not improve from 0.56667
# Epoch 39/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.3966 - acc: 0.4838 - val_loss: 0.3639 - val_acc: 0.5400
#
# Epoch 00039: val_acc did not improve from 0.56667
# Epoch 40/50
# 17/17 [==============================] - 65s 4s/step - loss: 1.3591 - acc: 0.4990 - val_loss: 0.1684 - val_acc: 0.5733
#
# Epoch 00040: val_acc improved from 0.56667 to 0.57333, saving model to vgg16_1.h5
# Epoch 41/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.3168 - acc: 0.5124 - val_loss: 0.5497 - val_acc: 0.5067
#
# Epoch 00041: val_acc did not improve from 0.57333
# Epoch 42/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.2935 - acc: 0.5467 - val_loss: 0.2487 - val_acc: 0.5267
#
# Epoch 00042: val_acc did not improve from 0.57333
# Epoch 43/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.3176 - acc: 0.5276 - val_loss: 0.2537 - val_acc: 0.5467
#
# Epoch 00043: val_acc did not improve from 0.57333
# Epoch 44/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.2772 - acc: 0.5448 - val_loss: 0.3024 - val_acc: 0.6067
#
# Epoch 00044: val_acc improved from 0.57333 to 0.60667, saving model to vgg16_1.h5
# Epoch 45/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.2055 - acc: 0.5505 - val_loss: 0.1063 - val_acc: 0.5800
#
# Epoch 00045: val_acc did not improve from 0.60667
# Epoch 46/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.1991 - acc: 0.5486 - val_loss: 0.3812 - val_acc: 0.5333
#
# Epoch 00046: val_acc did not improve from 0.60667
# Epoch 47/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.2727 - acc: 0.5181 - val_loss: 0.3416 - val_acc: 0.5400
#
# Epoch 00047: val_acc did not improve from 0.60667
# Epoch 48/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.3031 - acc: 0.5086 - val_loss: 0.5345 - val_acc: 0.5333
#
# Epoch 00048: val_acc did not improve from 0.60667
# Epoch 49/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.3207 - acc: 0.5181 - val_loss: 0.6639 - val_acc: 0.5400
#
# Epoch 00049: val_acc did not improve from 0.60667
# Epoch 50/50
# 17/17 [==============================] - 64s 4s/step - loss: 1.2362 - acc: 0.5352 - val_loss: 0.2651 - val_acc: 0.5733
#
# Epoch 00050: val_acc did not improve from 0.60667
# 17/17 [==============================] - 61s 4s/step
# 5/5 [==============================] - 16s 3s/step
# [0.26507696509361267, 0.5733333230018616]

# %%
model4.predict_generator(test_generator,10)[:5]
# Out:
# array([[1.5603587e-01, 1.3551349e-04, 9.0713213e-05, 8.9450151e-02,
#         3.3724788e-04, 1.9175600e-01, 9.2876321e-03, 3.6157876e-01,
#         1.1475331e-04, 7.0058599e-02, 9.2301272e-02, 5.1353173e-04,
#         2.7433937e-02, 3.9138136e-05, 8.6686132e-04],
#        [1.2499259e-09, 3.4617544e-05, 5.2671645e-09, 4.4543671e-05,
#         4.2752055e-07, 7.1680397e-01, 2.1699364e-01, 4.9954217e-08,
#         6.4434238e-02, 1.9503043e-04, 2.0082622e-10, 1.2558334e-03,
#         8.7603396e-05, 1.3863835e-10, 1.4999064e-04],
#        [1.0535298e-11, 9.8759544e-19, 8.3027976e-17, 5.8028089e-11,
#         8.6178517e-01, 5.6092631e-12, 1.1231292e-11, 2.2120450e-12,
#         1.7435057e-15, 1.3620343e-09, 1.5526190e-10, 7.7676678e-11,
#         1.3388103e-08, 1.2064401e-09, 1.3821489e-01],
#        [1.1483950e-06, 5.3155227e-11, 4.7285376e-10, 1.6375064e-09,
#         4.0813600e-05, 4.1771662e-09, 6.3269066e-09, 1.9558092e-07,
#         3.3644291e-08, 2.8014643e-10, 3.6251902e-05, 2.3909703e-09,
#         1.6596490e-05, 9.9893409e-01, 9.7093423e-04],
#        [1.0942648e-03, 1.4457896e-10, 4.3438684e-09, 5.4860353e-01,
#         6.3001671e-09, 1.6735020e-01, 4.7668000e-03, 8.8961028e-02,
#         7.5857737e-11, 1.8517938e-01, 9.6072274e-04, 3.0186015e-05,
#         3.0538591e-03, 5.1469591e-14, 8.9179872e-09]], dtype=float32)

# %%
model4.

# %%
model4.predict_classes(test_generator)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-dd2f2b6d5bb4> in <module>()
# ----> 1 model4.predict_classes(test_generator)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/sequential.py in predict_classes(self, x, batch_size, verbose)
#     266             A numpy array of class predictions.
#     267         """
# --> 268         proba = self.predict(x, batch_size=batch_size, verbose=verbose)
#     269         if proba.shape[-1] > 1:
#     270             return proba.argmax(axis=-1)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1420         """
#    1421
# -> 1422         batch_size = self._validate_or_infer_batch_size(batch_size, steps, x)
#    1423
#    1424         # Case 1: generator-like. Input is Python generator, or Sequence object.
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in _validate_or_infer_batch_size(self, batch_size, steps, x)
#     910         """
#     911         if batch_size is not None and training_utils.is_generator_or_sequence(x):
# --> 912             raise ValueError('The `batch_size` argument must not be specified when'
#     913                              ' using a generator or Sequence as an input.')
#     914
#
# ValueError: The `batch_size` argument must not be specified when using a generator or Sequence as an input.

# %%
test_labels[0]
# Out:
# array([0., 1., 0., 0., 0., 0., 0., 0.], dtype=float32)

# %%
plt.imshow(test_images[:1][0])

# %%
tf.keras.applications.VGG19(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
)

# %%
tf.math.confusion_matrix(
    val_labels[:5][1], 
    model2.predict_classes(test_images[:5]), 
    num_classes=8, weights=None, dtype=tf.dtypes.int32,
    #name=None
)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-28-83b973ddb48b> in <module>()
#       2     val_labels[:5][1],
#       3     model2.predict_classes(test_images[:5]),
# ----> 4     num_classes=8, weights=None, dtype=tf.dtypes.int32,
#       5     #name=None
#       6 )
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/confusion_matrix.py in confusion_matrix(labels, predictions, num_classes, weights, dtype, name)
#     190
#     191     shape = array_ops.stack([num_classes, num_classes])
# --> 192     indices = array_ops.stack([labels, predictions], axis=1)
#     193     values = (array_ops.ones_like(predictions, dtype)
#     194               if weights is None else weights)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py in stack(values, axis, name)
#    1340                        (axis, -expanded_num_dims, expanded_num_dims))
#    1341
# -> 1342   return gen_array_ops.pack(values, axis=axis, name=name)
#    1343
#    1344
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_array_ops.py in pack(values, axis, name)
#    6335         pass  # Add nodes to the TensorFlow graph.
#    6336     except _core._NotOkStatusException as e:
# -> 6337       _ops.raise_from_not_ok_status(e, name)
#    6338   # Add nodes to the TensorFlow graph.
#    6339   if not isinstance(values, (list, tuple)):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6651   message = e.message + (" name: " + name if name is not None else "")
#    6652   # pylint: disable=protected-access
# -> 6653   six.raise_from(core._status_to_exception(e.code, message), None)
#    6654   # pylint: enable=protected-access
#    6655
#
# /usr/local/lib/python3.6/dist-packages/six.py in raise_from(value, from_value)
#
# InvalidArgumentError: Shapes of all inputs must match: values[0].shape = [8] != values[1].shape = [5] [Op:Pack] name: stack

# %% [markdown]
# ## model5

# %%
model3 = models.Sequential(name='CNN 3HL(1024/512/256/512)-5Ep-TL=False')

model3.add(layers.Conv2D(2048, (3, 3), activation='relu',input_shape=(256 ,256,  3)))
model3.add(layers.MaxPooling2D((2,2)))

model3.add(layers.Conv2D(1024, (3, 3), activation='relu', padding="same"))
model3.add(layers.MaxPooling2D((2,2)))

model3.add(layers.Conv2D(512, (3, 3), activation='relu', padding="same"))
model3.add(layers.MaxPooling2D((2, 2)))

model3.add(layers.Conv2D(512, (3, 3), activation='relu', padding="same"))
model3.add(layers.MaxPooling2D((2, 2))) 

model3.add(layers.Conv2D(256, (3, 3), activation='relu', padding="same"))
model3.add(layers.MaxPooling2D((2, 2))) 


model3.add(layers.Flatten())
model3.add(layers.Dense(11, activation='softmax'))

model3.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['acc'])
model3.summary()

history = model3.fit(train_images,
                    train_labels,
                    epochs=5,
                    batch_size=32,
                    validation_split= 0.1,
                    #validation_data=(val_images, val_y)
                    verbose=1)

results_train = model3.evaluate(train_images, train_labels)
model3_val_results = model3.evaluate(val_images, val_labels)

results_train

model3_val_results

#model.predict_classes(val_images)

# %% [markdown]
# ## model6

# %%
model4 = models.Sequential(name='CNN 3HL(1024/512/256/512)-5Ep-TL=False')

model4.add(layers.Conv2D(1024, (3, 3), activation='relu',input_shape=(64 ,64,  3)))
model4.add(layers.MaxPooling2D((2,2)))

model4.add(layers.Conv2D(2048, (3, 3), activation='relu', padding="same"))
model4.add(layers.MaxPooling2D((2,2)))

model4.add(layers.Conv2D(256, (3, 3), activation='relu', padding="same"))
model4.add(layers.MaxPooling2D((2, 2)))

model4.add(layers.Conv2D(512, (3, 3), activation='relu', padding="same"))
model4.add(layers.MaxPooling2D((2, 2))) 


model4.add(layers.Flatten())
model4.add(layers.Dense(11, activation='softmax'))

model4.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['acc'])
model4.summary()

history = model4.fit(train_images,
                    train_labels,
                    epochs=5,
                    batch_size=32,
                    validation_split= 0.1,
                    #validation_data=(val_images, val_y)
                    verbose=1)

results_train4 = model4.evaluate(train_images, train_labels)
results_test4 = model4.evaluate(val_images, val_labels)

results_train

results_test

#model.predict_classes(val_images)
# Out:
# Model: "CNN 3HL(1024/512/256/512)-5Ep-TL=False"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_25 (Conv2D)           (None, 62, 62, 1024)      28672
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 31, 31, 1024)      0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 31, 31, 2048)      18876416
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 15, 15, 2048)      0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 15, 15, 256)       4718848
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 7, 7, 512)         1180160
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 11)                50699
# =================================================================
# Total params: 24,854,795
# Trainable params: 24,854,795
# Non-trainable params: 0
# _________________________________________________________________
# Train on 783 samples, validate on 88 samples
# Epoch 1/5
#  96/783 [==>...........................] - ETA: 1:31 - loss: 3.2600 - acc: 0.0833

# %% [markdown]
# ---
