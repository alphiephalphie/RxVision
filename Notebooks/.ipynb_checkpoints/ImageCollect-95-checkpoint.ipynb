# %%
import pandas as pd
import requests
from IPython.display import Image
import time
from ftplib import FTP

from PIL import Image
from PIL import ImageFile
import rawpy
import imageio
ImageFile.LOAD_TRUNCATED_IMAGES = True


import os, shutil

import os
import sys

# %%
imagecount = 95

# %%
typdict = {'NDC':'str'}
df = pd.read_csv('../data/directory_of_images.txt',sep='|', dtype=typdict, names=['NDC','IDK','FILE','TYPE','DRUG'])
df = df.dropna()
df.DRUG = df.DRUG.str.upper()
df[['ORIG_FOLDER','IMAGES','FILENAME']] = df.FILE.str.split('/', expand=True)
df['FILETYPE'] = df.FILENAME.str[-4:]
df = df[df.FILETYPE != '.WMV']

# %%
ndcs = df.NDC.value_counts()
n = ndcs[ndcs == imagecount].index
# #n100 = ndcs[ndcs <= 100].index
# ndcs50100 = list(set(n50) & set(n100))
dfn = df[df.NDC.isin(n)]
dfn
# Out:
#                NDC  IDK                                               FILE  \
# 26852  00093725401    1  PillProjectDisc67/images/CJH8_95CTK13Q5T739ORS...
# 26853  00093725401    1  PillProjectDisc79/images/CUF2F_2_PEY!-WPZN5A_T...
# 26854  00093725401    1  PillProjectDisc82/images/CXMI3WSYHY0KB4T-X_P!V...
# 26855  00093725401    1  PillProjectDisc8/images/5CEDGLAOHO_MZXCBRD1!L4...
# 26856  00093725401    1  PillProjectDisc101/images/RWM2HZ054W9X2TD7XY55...
# ...            ...  ...                                                ...
# 92460  50419010510    1  PillProjectDisc62/images/CESGSG0GFMZZL1IHAB09O...
# 92461  50419010510    1  PillProjectDisc85/images/DHNVMVC1KAUEOYEHZ34B4...
# 92462  50419010510    1  PillProjectDisc96/images/M_N!3YQS2L1PE-THOV7DC...
# 92463  50419010510    1  PillProjectDisc97/images/OFOWX68GQ9S4W9R_K-67V...
# 92464  50419010510    1  PillProjectDisc44/images/BR3GJ1WDL_IW35NL65DMH...
#
#                             TYPE                     DRUG         ORIG_FOLDER  \
# 26852             C3PI_Reference      GLIMEPIRIDE 1MG TAB   PillProjectDisc67
# 26853             C3PI_Reference  GLIMEPIRIDE TABLETS USP   PillProjectDisc79
# 26854             C3PI_Reference      GLIMEPIRIDE 1MG TAB   PillProjectDisc82
# 26855             C3PI_Reference  GLIMEPIRIDE TABLETS USP    PillProjectDisc8
# 26856                  C3PI_Test      GLIMEPIRIDE 1MG TAB  PillProjectDisc101
# ...                          ...                      ...                 ...
# 92460  MC_COOKED_CALIBRATED_V1.2                 BETAPACE   PillProjectDisc62
# 92461  MC_COOKED_CALIBRATED_V1.2        BETAPACE 80MG TAB   PillProjectDisc85
# 92462  MC_COOKED_CALIBRATED_V1.2        BETAPACE 80MG TAB   PillProjectDisc96
# 92463  MC_COOKED_CALIBRATED_V1.2                 BETAPACE   PillProjectDisc97
# 92464       MC_SPL_SPLIMAGE_V3.0                 BETAPACE   PillProjectDisc44
#
#        IMAGES                             FILENAME FILETYPE
# 26852  images  CJH8_95CTK13Q5T739ORSM4OE1HMJY2.CR2     .CR2
# 26853  images  CUF2F_2_PEY!-WPZN5A_T9J-!67O1LK.CR2     .CR2
# 26854  images  CXMI3WSYHY0KB4T-X_P!VFVUVQNLL06.CR2     .CR2
# 26855  images   5CEDGLAOHO_MZXCBRD1!L48FU0C4XD.CR2     .CR2
# 26856  images   RWM2HZ054W9X2TD7XY55I5JPD3LIH5.JPG     .JPG
# ...       ...                                  ...      ...
# 92460  images  CESGSG0GFMZZL1IHAB09OIRO-IKEMIE.PNG     .PNG
# 92461  images   DHNVMVC1KAUEOYEHZ34B4NZ-TX!7OC.PNG     .PNG
# 92462  images   M_N!3YQS2L1PE-THOV7DCF3LW3GN70.PNG     .PNG
# 92463  images   OFOWX68GQ9S4W9R_K-67VQT1NODN65.PNG     .PNG
# 92464  images  BR3GJ1WDL_IW35NL65DMHU2E1K3O9SS.JPG     .JPG
#
# [475 rows x 9 columns]

# %%
dfn.DRUG.value_counts()
# Out:
# ALLOPURINOL 300MG TABS        95
# GLIMEPIRIDE 1MG TAB           64
# COMBIVIR                      53
# BETAPACE                      53
# LANOXIN TABLETS, USP          53
# COMBIVIR 150/300MG TABLETS    42
# BETAPACE 80MG TAB             42
# LANOXIN 0.125MG TABLETS       42
# GLIMEPIRIDE TABLETS USP       31
# Name: DRUG, dtype: int64

# %%
drugs = dfn.NDC.value_counts()
drugslist = drugs.index.tolist()
len(dfn.NDC.value_counts()),drugs
# Out:
# (5,
#  50419010510    95
#  49702020218    95
#  00591554405    95
#  00173024255    95
#  00093725401    95
#  Name: NDC, dtype: int64)

# %%
df_a = dfn.groupby(['DRUG','NDC']).count()
df_a.reset_index(inplace=True)
drug_ndc = df_a[['DRUG','NDC']]
drug_ndc
# Out:
#                          DRUG          NDC
# 0      ALLOPURINOL 300MG TABS  00591554405
# 1                    BETAPACE  50419010510
# 2           BETAPACE 80MG TAB  50419010510
# 3                    COMBIVIR  49702020218
# 4  COMBIVIR 150/300MG TABLETS  49702020218
# 5         GLIMEPIRIDE 1MG TAB  00093725401
# 6     GLIMEPIRIDE TABLETS USP  00093725401
# 7     LANOXIN 0.125MG TABLETS  00173024255
# 8        LANOXIN TABLETS, USP  00173024255

# %%
droplist = []

df = dfn[~dfn.NDC.isin(droplist)]

# %%
df.DRUG[df.NDC == '00591554405'] = 'ALLOPURINOL 300MG'
df.DRUG[df.NDC == '50419010510'] = 'BETAPACE 80MG'
df.DRUG[df.NDC == '49702020218'] = 'COMBIVIR 150/300MG'
df.DRUG[df.NDC == '00093725401'] = 'GLIMEPIRIDE 1MG'
df.DRUG[df.NDC == '00173024255'] = 'LANOXIN 0.125MG'
# Out:
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df
# Out:
#                NDC  IDK                                               FILE  \
# 26852  00093725401    1  PillProjectDisc67/images/CJH8_95CTK13Q5T739ORS...
# 26853  00093725401    1  PillProjectDisc79/images/CUF2F_2_PEY!-WPZN5A_T...
# 26854  00093725401    1  PillProjectDisc82/images/CXMI3WSYHY0KB4T-X_P!V...
# 26855  00093725401    1  PillProjectDisc8/images/5CEDGLAOHO_MZXCBRD1!L4...
# 26856  00093725401    1  PillProjectDisc101/images/RWM2HZ054W9X2TD7XY55...
# ...            ...  ...                                                ...
# 92460  50419010510    1  PillProjectDisc62/images/CESGSG0GFMZZL1IHAB09O...
# 92461  50419010510    1  PillProjectDisc85/images/DHNVMVC1KAUEOYEHZ34B4...
# 92462  50419010510    1  PillProjectDisc96/images/M_N!3YQS2L1PE-THOV7DC...
# 92463  50419010510    1  PillProjectDisc97/images/OFOWX68GQ9S4W9R_K-67V...
# 92464  50419010510    1  PillProjectDisc44/images/BR3GJ1WDL_IW35NL65DMH...
#
#                             TYPE             DRUG         ORIG_FOLDER  IMAGES  \
# 26852             C3PI_Reference  GLIMEPIRIDE 1MG   PillProjectDisc67  images
# 26853             C3PI_Reference  GLIMEPIRIDE 1MG   PillProjectDisc79  images
# 26854             C3PI_Reference  GLIMEPIRIDE 1MG   PillProjectDisc82  images
# 26855             C3PI_Reference  GLIMEPIRIDE 1MG    PillProjectDisc8  images
# 26856                  C3PI_Test  GLIMEPIRIDE 1MG  PillProjectDisc101  images
# ...                          ...              ...                 ...     ...
# 92460  MC_COOKED_CALIBRATED_V1.2    BETAPACE 80MG   PillProjectDisc62  images
# 92461  MC_COOKED_CALIBRATED_V1.2    BETAPACE 80MG   PillProjectDisc85  images
# 92462  MC_COOKED_CALIBRATED_V1.2    BETAPACE 80MG   PillProjectDisc96  images
# 92463  MC_COOKED_CALIBRATED_V1.2    BETAPACE 80MG   PillProjectDisc97  images
# 92464       MC_SPL_SPLIMAGE_V3.0    BETAPACE 80MG   PillProjectDisc44  images
#
#                                   FILENAME FILETYPE
# 26852  CJH8_95CTK13Q5T739ORSM4OE1HMJY2.CR2     .CR2
# 26853  CUF2F_2_PEY!-WPZN5A_T9J-!67O1LK.CR2     .CR2
# 26854  CXMI3WSYHY0KB4T-X_P!VFVUVQNLL06.CR2     .CR2
# 26855   5CEDGLAOHO_MZXCBRD1!L48FU0C4XD.CR2     .CR2
# 26856   RWM2HZ054W9X2TD7XY55I5JPD3LIH5.JPG     .JPG
# ...                                    ...      ...
# 92460  CESGSG0GFMZZL1IHAB09OIRO-IKEMIE.PNG     .PNG
# 92461   DHNVMVC1KAUEOYEHZ34B4NZ-TX!7OC.PNG     .PNG
# 92462   M_N!3YQS2L1PE-THOV7DCF3LW3GN70.PNG     .PNG
# 92463   OFOWX68GQ9S4W9R_K-67VQT1NODN65.PNG     .PNG
# 92464  BR3GJ1WDL_IW35NL65DMHU2E1K3O9SS.JPG     .JPG
#
# [475 rows x 9 columns]

# %%
df.DRUG.value_counts()
# Out:
# GLIMEPIRIDE 1MG       95
# COMBIVIR 150/300MG    95
# BETAPACE 80MG         95
# LANOXIN 0.125MG       95
# ALLOPURINOL 300MG     95
# Name: DRUG, dtype: int64

# %%
df_a = df.groupby(['DRUG','NDC']).count()
df_a.reset_index(inplace=True)
drug_ndc = df_a[['DRUG','NDC']]
drug_ndc
# Out:
#                  DRUG          NDC
# 0   ALLOPURINOL 300MG  00591554405
# 1       BETAPACE 80MG  50419010510
# 2  COMBIVIR 150/300MG  49702020218
# 3     GLIMEPIRIDE 1MG  00093725401
# 4     LANOXIN 0.125MG  00173024255

# %% [markdown]
# ## Sample Batch

# %%
samplesdf = df.groupby(['NDC']).min().reset_index()
samplesdf
# Out:
#            NDC  IDK                                               FILE  \
# 0  00093725401    1  PillProjectDisc1/images/!7WF161YS_R5ET9Y!26E6U...
# 1  00173024255    1  PillProjectDisc10/images/6_6!XJ73P9O12E6LVGBAI...
# 2  00591554405    1  PillProjectDisc1/images/!WT4Y657!VOLO3YRBJ5HS9...
# 3  49702020218    1  PillProjectDisc101/images/S!Y8UKL4UF_V-BESBWG-...
# 4  50419010510    1  PillProjectDisc1/images/!56HENXQPITL7C!4A52GSM...
#
#              TYPE                DRUG         ORIG_FOLDER  IMAGES  \
# 0  C3PI_Reference     GLIMEPIRIDE 1MG    PillProjectDisc1  images
# 1  C3PI_Reference     LANOXIN 0.125MG   PillProjectDisc10  images
# 2  C3PI_Reference   ALLOPURINOL 300MG    PillProjectDisc1  images
# 3  C3PI_Reference  COMBIVIR 150/300MG  PillProjectDisc101  images
# 4  C3PI_Reference       BETAPACE 80MG    PillProjectDisc1  images
#
#                              FILENAME FILETYPE
# 0  !7WF161YS_R5ET9Y!26E6UHXF9HXDU.JPG     .CR2
# 1  08_IJPXWRE5_8!_W4CPEQWRB4S21B!.JPG     .CR2
# 2  !WT4Y657!VOLO3YRBJ5HS9MSRVMZKE.JPG     .CR2
# 3  -WT_RX0KVFC9BH0ZFM643W5SJMZL!1.JPG     .CR2
# 4  !56HENXQPITL7C!4A52GSM0YNF5KKA.PNG     .CR2

# %%
sampleslist = samplesdf.FILE.tolist()
sampleslist.sort()
sampleslist
# Out:
# ['PillProjectDisc1/images/!56HENXQPITL7C!4A52GSM0YNF5KKA.PNG',
#  'PillProjectDisc1/images/!7WF161YS_R5ET9Y!26E6UHXF9HXDU.JPG',
#  'PillProjectDisc1/images/!WT4Y657!VOLO3YRBJ5HS9MSRVMZKE.JPG',
#  'PillProjectDisc10/images/6_6!XJ73P9O12E6LVGBAIIGMNO252A.JPG',
#  'PillProjectDisc101/images/S!Y8UKL4UF_V-BESBWG-YDTW0ZHOY2.PNG']

# %%
ftpdir = {}
for i in range(0,len(sampleslist)):
    ftpcall = sampleslist[i].split('/')
    ftppath = ftpcall[0]+'/'+ftpcall[1]+ '/'
    ftpfile = ftpcall[-1]
    ftpdir.setdefault(ftppath,[])
    ftpdir[ftppath].append(ftpfile)
len(ftpdir)
# Out:
# 3

# %%
# %pwd
# Out:
# '/Users/alphonsowoodbury/Projects/Computer_Vision-Medication_Identification/Notebooks'

# %%
# %cd ../Data
for key in ftpdir.keys():
    #%cd /content/drive/My Drive/Project: Pill ID/Data
    folder = 'img'+str(imagecount)
    try:
        os.makedirs(folder)
    except:
        print('Folder present')
    ftp = FTP('lhcftp.nlm.nih.gov')
    ftp.login()
    ftp.cwd('Open-Access-Datasets/Pills//')
    ftp.cwd(key)
    dloaded = os.listdir(folder)
    print(key)
    # %cd Data/$folder
    for value in ftpdir[key]:
        if value not in dloaded:
            with open(value, 'wb') as fp:
                ftp.retrbinary('RETR '+ value, fp.write)
    ftp.cwd('..')
    ftp.cwd('..')
# Out:
# /Users/alphonsowoodbury/Projects/Computer_Vision-Medication_Identification/Data
# Folder present
# PillProjectDisc1/images/
# [Errno 2] No such file or directory: 'Data/img95'
# /Users/alphonsowoodbury/Projects/Computer_Vision-Medication_Identification/Data
# Folder present
# PillProjectDisc10/images/
# [Errno 2] No such file or directory: 'Data/img95'
# /Users/alphonsowoodbury/Projects/Computer_Vision-Medication_Identification/Data
# Folder present
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-0d8cf9574527> in <module>
#       7     except:
#       8         print('Folder present')
# ----> 9     ftp = FTP('lhcftp.nlm.nih.gov')
#      10     ftp.login()
#      11     ftp.cwd('Open-Access-Datasets/Pills//')
#
# ~/.conda/envs/aw0520/lib/python3.7/ftplib.py in __init__(self, host, user, passwd, acct, timeout, source_address)
#     115         self.timeout = timeout
#     116         if host:
# --> 117             self.connect(host)
#     118             if user:
#     119                 self.login(user, passwd, acct)
#
# ~/.conda/envs/aw0520/lib/python3.7/ftplib.py in connect(self, host, port, timeout, source_address)
#     150             self.source_address = source_address
#     151         self.sock = socket.create_connection((self.host, self.port), self.timeout,
# --> 152                                              source_address=self.source_address)
#     153         self.af = self.sock.family
#     154         self.file = self.sock.makefile('r', encoding=self.encoding)
#
# ~/.conda/envs/aw0520/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     714             if source_address:
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#     718             err = None
#
# KeyboardInterrupt:

# %% [markdown]
# ## Get Batch

# %%
drugsftp = df.FILE.tolist()
drugsftp.sort()
drugsftp[:10]
# Out:
# ['PillProjectDisc1/images/!56HENXQPITL7C!4A52GSM0YNF5KKA.PNG',
#  'PillProjectDisc1/images/!7WF161YS_R5ET9Y!26E6UHXF9HXDU.JPG',
#  'PillProjectDisc1/images/!G_6-MR6ALJIVSJV_FG81XV_T76S5C.JPG',
#  'PillProjectDisc1/images/!KIVP9GRT_9CCE7MKA2-!EUSBJK44B.PNG',
#  'PillProjectDisc1/images/!WT4Y657!VOLO3YRBJ5HS9MSRVMZKE.JPG',
#  'PillProjectDisc10/images/6_6!XJ73P9O12E6LVGBAIIGMNO252A.JPG',
#  'PillProjectDisc10/images/6_6!XJ73P9O12E6LVGBAIIGMNO252A.JPG',
#  'PillProjectDisc10/images/71F0PADPK6212-1HT3-IBI-Y!KK!1B.JPG',
#  'PillProjectDisc10/images/71QVB659EJF7J2UOJAR9107P-CC6GM.JPG',
#  'PillProjectDisc10/images/71QVB659EJF7J2UOJAR9107P-CC6GM.JPG']

# %%
ftpdir = {}
for i in range(0,len(drugsftp)):
    ftpcall = drugsftp[i].split('/')
    ftppath = ftpcall[0]+'/'+ftpcall[1]+ '/'
    ftpfile = ftpcall[-1]
    ftpdir.setdefault(ftppath,[])
    ftpdir[ftppath].append(ftpfile)
len(ftpdir)
# Out:
# 102

# %%
# %cd /content/drive/My Drive/Project: Pill ID/Data
for key in ftpdir.keys():
    #%cd /content/drive/My Drive/Project: Pill ID/Data
    ftp = FTP('lhcftp.nlm.nih.gov')
    ftp.login()
    ftp.cwd('Open-Access-Datasets/Pills//')
    ftp.cwd(key)
    dloaded = os.listdir('/content/drive/My Drive/Project: Pill ID/Data')
    print(key)
    for value in ftpdir[key]:
      if value not in dloaded:
        with open(value, 'wb') as fp:
            ftp.retrbinary('RETR '+ value, fp.write)
    ftp.cwd('..')
    ftp.cwd('..')
