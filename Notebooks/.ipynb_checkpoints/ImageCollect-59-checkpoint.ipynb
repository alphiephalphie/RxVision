# %%
import pandas as pd
import requests
from IPython.display import Image
import time
from ftplib import FTP

from PIL import Image
from PIL import ImageFile
import rawpy
import imageio
ImageFile.LOAD_TRUNCATED_IMAGES = True


import os, shutil

import os
import sys

# %%
typdict = {'NDC':'str'}
df = pd.read_csv('../data/directory_of_images.txt',sep='|', dtype=typdict, names=['NDC','IDK','FILE','TYPE','DRUG'])
df = df.dropna()
df.DRUG = df.DRUG.str.upper()
df[['ORIG_FOLDER','IMAGES','FILENAME']] = df.FILE.str.split('/', expand=True)
df['FILETYPE'] = df.FILENAME.str[-4:]
df = df[df.FILETYPE != '.WMV']

# %%
imagecount = 59

ndcs = df.NDC.value_counts()
n = ndcs[ndcs == imagecount].index
# #n100 = ndcs[ndcs <= 100].index
# ndcs50100 = list(set(n50) & set(n100))
dfn = df[df.NDC.isin(n)]
dfn
# Out:
#                 NDC  IDK                                               FILE  \
# 12612   00093030801    1  PillProjectDisc10/images/6J5VWHI0KM5RH90DSQEK_...
# 12613   00093030801    1  PillProjectDisc59/images/CC1B4LSFBV2B9FV23E7V_...
# 12614   00093030801    1  PillProjectDisc8/images/4WO7OJ!T8D6_XN2TRBR49-...
# 12615   00093030801    1  PillProjectDisc92/images/JE5O7WUL29CF8GED5CUJ4...
# 12616   00093030801    1  PillProjectDisc106/images/WR8_Q0__VOFVZQI44H6J...
# ...             ...  ...                                                ...
# 132650  68546014256    1  PillProjectDisc4/images/1B8T6-P5RIL!RNHR0-JFVY...
# 132651  68546014256    1  PillProjectDisc53/images/BZELDHLT14PJE3DN1RR!7...
# 132652  68546014256    1  PillProjectDisc59/images/CCHQJ433ZPEKU_8J5U-10...
# 132653  68546014256    1  PillProjectDisc81/images/CWZF8VC1Z1GQ1U3GRXMDG...
# 132654  68546014256    1  PillProjectDisc20/images/B3W3PIMNZ2_HUA58NMTJ2...
#
#                              TYPE                              DRUG  \
# 12612              C3PI_Reference       CLEMASTINE FUMARATE 2.68 MG
# 12613              C3PI_Reference       CLEMASTINE FUMARATE 2.68 MG
# 12614              C3PI_Reference  CLEMASTINE FUMARATE TABLETS, USP
# 12615              C3PI_Reference  CLEMASTINE FUMARATE TABLETS, USP
# 12616                   C3PI_Test       CLEMASTINE FUMARATE 2.68 MG
# ...                           ...                               ...
# 132650  MC_COOKED_CALIBRATED_V1.2                 AZILECT TAB 0.5MG
# 132651  MC_COOKED_CALIBRATED_V1.2                           AZILECT
# 132652  MC_COOKED_CALIBRATED_V1.2                           AZILECT
# 132653  MC_COOKED_CALIBRATED_V1.2                           AZILECT
# 132654       MC_SPL_SPLIMAGE_V3.0                 AZILECT TAB 0.5MG
#
#                ORIG_FOLDER  IMAGES                             FILENAME  \
# 12612    PillProjectDisc10  images   6J5VWHI0KM5RH90DSQEK_NMZW-WDSR.CR2
# 12613    PillProjectDisc59  images  CC1B4LSFBV2B9FV23E7V_0-5EJAFHOY.CR2
# 12614     PillProjectDisc8  images   4WO7OJ!T8D6_XN2TRBR49-EVB-XAJ4.CR2
# 12615    PillProjectDisc92  images   JE5O7WUL29CF8GED5CUJ44!QBJWAB5.CR2
# 12616   PillProjectDisc106  images   WR8_Q0__VOFVZQI44H6JFR5_EKN9JZ.JPG
# ...                    ...     ...                                  ...
# 132650    PillProjectDisc4  images   1B8T6-P5RIL!RNHR0-JFVY57BSJZCN.PNG
# 132651   PillProjectDisc53  images  BZELDHLT14PJE3DN1RR!7FJUH8-PF3J.PNG
# 132652   PillProjectDisc59  images  CCHQJ433ZPEKU_8J5U-10X!W2K7PC50.PNG
# 132653   PillProjectDisc81  images  CWZF8VC1Z1GQ1U3GRXMDGW!-5AZX_X1.PNG
# 132654   PillProjectDisc20  images  B3W3PIMNZ2_HUA58NMTJ2NR0DZ2H_JJ.JPG
#
#        FILETYPE
# 12612      .CR2
# 12613      .CR2
# 12614      .CR2
# 12615      .CR2
# 12616      .JPG
# ...         ...
# 132650     .PNG
# 132651     .PNG
# 132652     .PNG
# 132653     .PNG
# 132654     .JPG
#
# [885 rows x 9 columns]

# %%
dfn.DRUG.value_counts()
# Out:
# DILTIAZEM HYDROCHLORIDE EXTENDED-RELEASE CAPSULES USP    66
# HYDRALAZINE 25MG TAB                                     59
# GABAPENTIN 800MG TABLETS                                 59
# GLIMEPIRIDE 1MG TAB                                      59
# HALOPERIDOL 0.5MG TAB                                    59
# DICLOXACILLIN SODIUM CAPSULES USP                        34
# AMOXICILLIN AND CLAVULANATE POTASSIUM TABLETS USP        32
# BUMETANIDE TABLETS USP                                   32
# CLEMASTINE FUMARATE TABLETS, USP                         32
# KETOROLAC TROMETHAMINE TABLETS USP                       32
# AZILECT TAB 0.5MG                                        30
# LOSARTAN POT 25MG TAB                                    30
# MEDROXYPR AC 10MG TAB                                    30
# DANAZOL CAP 100MG                                        30
# DANAZOL CAPSULES, USP                                    29
# MEDROXYPROGESTERONE ACETATE TABLETS USP                  29
# LOSARTAN POTASSIUM TABLETS USP                           29
# AZILECT                                                  29
# AMOXICIL/CLAVULANATE 500/125MG                           27
# BUMETANIDE TAB 2MG                                       27
# CLEMASTINE FUMARATE 2.68 MG                              27
# DILTIAZEM CAP XR 240MG                                   27
# KETOROLAC 10MG                                           27
# DICLOXACILLIN SOD 500MG CAPS                             25
# DILTIAZEM ER 180MG CAPSULES                              25
# Name: DRUG, dtype: int64

# %%
dfn.NDC.value_counts()
# Out:
# 00093511798    59
# 00093312501    59
# 55111032001    59
# 00555063402    59
# 00555077902    59
# 68546014256    59
# 00093227434    59
# 00093030801    59
# 00093736498    59
# 00781139101    59
# 68462012705    59
# 31722052010    59
# 00093511898    59
# 00093031401    59
# 00093423401    59
# Name: NDC, dtype: int64

# %%
df_a = dfn.groupby(['DRUG','NDC']).count()
df_a.reset_index(inplace=True)
drug_ndc = df_a[['DRUG','NDC']]
drug_ndc
# Out:
#                                                  DRUG          NDC
# 0                      AMOXICIL/CLAVULANATE 500/125MG  00093227434
# 1   AMOXICILLIN AND CLAVULANATE POTASSIUM TABLETS USP  00093227434
# 2                                             AZILECT  68546014256
# 3                                   AZILECT TAB 0.5MG  68546014256
# 4                                  BUMETANIDE TAB 2MG  00093423401
# 5                              BUMETANIDE TABLETS USP  00093423401
# 6                         CLEMASTINE FUMARATE 2.68 MG  00093030801
# 7                    CLEMASTINE FUMARATE TABLETS, USP  00093030801
# 8                                   DANAZOL CAP 100MG  00555063402
# 9                               DANAZOL CAPSULES, USP  00555063402
# 10                       DICLOXACILLIN SOD 500MG CAPS  00093312501
# 11                  DICLOXACILLIN SODIUM CAPSULES USP  00093312501
# 12                             DILTIAZEM CAP XR 240MG  00093511898
# 13                        DILTIAZEM ER 180MG CAPSULES  00093511798
# 14  DILTIAZEM HYDROCHLORIDE EXTENDED-RELEASE CAPSU...  00093511798
# 15  DILTIAZEM HYDROCHLORIDE EXTENDED-RELEASE CAPSU...  00093511898
# 16                           GABAPENTIN 800MG TABLETS  68462012705
# 17                                GLIMEPIRIDE 1MG TAB  55111032001
# 18                              HALOPERIDOL 0.5MG TAB  00781139101
# 19                               HYDRALAZINE 25MG TAB  31722052010
# 20                                     KETOROLAC 10MG  00093031401
# 21                 KETOROLAC TROMETHAMINE TABLETS USP  00093031401
# 22                              LOSARTAN POT 25MG TAB  00093736498
# 23                     LOSARTAN POTASSIUM TABLETS USP  00093736498
# 24                              MEDROXYPR AC 10MG TAB  00555077902
# 25            MEDROXYPROGESTERONE ACETATE TABLETS USP  00555077902

# %%
drugs = ['00006074554','00555188302','65862019430','24090047988','00781196160','24486060490','00093402901','00093576756','24486060310','64125013010','55111068305','65862019905','23155010501','00009033102','00591084510']

# %%
df = df[df.NDC.isin(drugs)]
df
# Out:
#                 NDC  IDK                                               FILE  \
# 1226    00006074554    1  PillProjectDisc24/images/B7VF6YKZAKU7R6RH9PJC6...
# 1227    00006074554    1  PillProjectDisc53/images/BZRBET5WWF01MHM0TS8UA...
# 1228    00006074554    1  PillProjectDisc106/images/W7_68M2JGM2VVC-5BAJU...
# 1229    00006074554    1  PillProjectDisc109/images/ZSLAKUF3PNEZFLJIRVSV...
# 1230    00006074554    1  PillProjectDisc11/images/7RPWFG3ZF3E0LL1L!4TBA...
# ...             ...  ...                                                ...
# 124244  65862019905    1  PillProjectDisc20/images/B48ZJ0_NS_D9U78ON7-GM...
# 124245  65862019905    1  PillProjectDisc53/images/BZ1FSXTOE4T22MSGJXFRT...
# 124246  65862019905    1  PillProjectDisc5/images/1XUYSB3P6Q36KO510FS9BW...
# 124247  65862019905    1  PillProjectDisc66/images/CIHOS-4VFVZT8UTQZ00OY...
# 124248  65862019905    1  PillProjectDisc2/images/-C9U9YVLUDE71T0KQE16CX...
#
#                              TYPE                  DRUG         ORIG_FOLDER  \
# 1226               C3PI_Reference   HYZAAR TAB 100-12.5   PillProjectDisc24
# 1227               C3PI_Reference   HYZAAR TAB 100-12.5   PillProjectDisc53
# 1228                    C3PI_Test   HYZAAR TAB 100-12.5  PillProjectDisc106
# 1229                    C3PI_Test   HYZAAR TAB 100-12.5  PillProjectDisc109
# 1230                    C3PI_Test   HYZAAR TAB 100-12.5   PillProjectDisc11
# ...                           ...                   ...                 ...
# 124244  MC_COOKED_CALIBRATED_V1.2  GABAPENTIN 300MG CAP   PillProjectDisc20
# 124245  MC_COOKED_CALIBRATED_V1.2  GABAPENTIN 300MG CAP   PillProjectDisc53
# 124246  MC_COOKED_CALIBRATED_V1.2  GABAPENTIN 300MG CAP    PillProjectDisc5
# 124247  MC_COOKED_CALIBRATED_V1.2  GABAPENTIN 300MG CAP   PillProjectDisc66
# 124248       MC_SPL_SPLIMAGE_V3.0  GABAPENTIN 300MG CAP    PillProjectDisc2
#
#         IMAGES                             FILENAME FILETYPE
# 1226    images  B7VF6YKZAKU7R6RH9PJC6-Q3QNJYYO4.CR2     .CR2
# 1227    images  BZRBET5WWF01MHM0TS8UAJE_XKVUZV8.CR2     .CR2
# 1228    images   W7_68M2JGM2VVC-5BAJURW0-MELXXR.JPG     .JPG
# 1229    images   ZSLAKUF3PNEZFLJIRVSV6-ZS7V7-QL.JPG     .JPG
# 1230    images   7RPWFG3ZF3E0LL1L!4TBAD7BD_WGWY.JPG     .JPG
# ...        ...                                  ...      ...
# 124244  images  B48ZJ0_NS_D9U78ON7-GM3UGB26UI1W.PNG     .PNG
# 124245  images  BZ1FSXTOE4T22MSGJXFRTL16HYT8GXR.PNG     .PNG
# 124246  images   1XUYSB3P6Q36KO510FS9BWMK5GW_AQ.PNG     .PNG
# 124247  images  CIHOS-4VFVZT8UTQZ00OYFI-M!HB4OW.PNG     .PNG
# 124248  images   -C9U9YVLUDE71T0KQE16CXA5Z1YA39.JPG     .JPG
#
# [750 rows x 9 columns]

# %%
df.DRUG[df.NDC == '00093576756'] = 'OLANZAPINE 2.5MG TAB'

df.DRUG[df.NDC == '00093402901'] = 'INDOMETHACIN CAPSULES'
# Out:
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.DRUG.value_counts()
# Out:
# BENZONATATE CAPSULES, USP     50
# GLIPIZIDE ER 10MG TAB         50
# INDERAL LA CAP 160MG          50
# HYDROXYZINE  HCL 10MG TABS    50
# HYZAAR TAB 100-12.5           50
# HYOMAX-FT 0.125MG TAB         50
# GABAPENTIN 300MG CAP          50
# HYOMAX-DT 0.375MG TABLET      50
# CLEOCIN 75MG CAPS             50
# OLANZAPINE 2.5MG TAB          50
# HCTZ 50MG TABS                50
# FLUOXETINE 40MG CAP           50
# INDOMETHACIN CAPSULES         50
# IBUPROFEN 600MG TAB           50
# CLARITHROMYCIN 250            50
# Name: DRUG, dtype: int64

# %%
df_a = df.groupby(['DRUG','NDC']).count()
df_a.reset_index(inplace=True)
drug_ndc = df_a[['DRUG','NDC']]
drug_ndc
# Out:
#                           DRUG          NDC
# 0    BENZONATATE CAPSULES, USP  00555188302
# 1           CLARITHROMYCIN 250  00781196160
# 2            CLEOCIN 75MG CAPS  00009033102
# 3          FLUOXETINE 40MG CAP  65862019430
# 4         GABAPENTIN 300MG CAP  65862019905
# 5        GLIPIZIDE ER 10MG TAB  00591084510
# 6               HCTZ 50MG TABS  64125013010
# 7   HYDROXYZINE  HCL 10MG TABS  23155010501
# 8     HYOMAX-DT 0.375MG TABLET  24486060490
# 9        HYOMAX-FT 0.125MG TAB  24486060310
# 10         HYZAAR TAB 100-12.5  00006074554
# 11         IBUPROFEN 600MG TAB  55111068305
# 12        INDERAL LA CAP 160MG  24090047988
# 13       INDOMETHACIN CAPSULES  00093402901
# 14        OLANZAPINE 2.5MG TAB  00093576756

# %%
drugsftp = df.FILE.tolist()
drugsftp.sort()
drugsftp[:10]
# Out:
# ['PillProjectDisc1/images/!1ECEZFCQZ5I6S0RP6IZ-T!_6Y2RXW.PNG',
#  'PillProjectDisc1/images/!AOKWIRBTDVYLX41JNYGUE1OPO6-15.JPG',
#  'PillProjectDisc1/images/!ER_L-9UW4J0KP5FQTJ2-LQKM!FKUK.JPG',
#  'PillProjectDisc1/images/!GAGH9SEMPWXKDD0B79O2WDHDYV_3.JPG',
#  'PillProjectDisc1/images/!J0N020HAC1N9IDCYU3QJJN!5YA2A!.PNG',
#  'PillProjectDisc1/images/!Y7FKLUPG3TK-OZ7A5EVQCVF420-VJ.PNG',
#  'PillProjectDisc10/images/6MBF88872OTKN19TLJH!0QLNOED708.JPG',
#  'PillProjectDisc10/images/6MN99VY2IAUCLJKPCED_JG-ZAGUAPO.PNG',
#  'PillProjectDisc10/images/6R55YN3L0OOT3RFCFHZNUMSETXTC22.JPG',
#  'PillProjectDisc10/images/6R66C0USAMBP_!SWRIXWYLZ15G9RL.PNG']

# %%
ftpdir = {}
for i in range(0,len(drugsftp)):
    ftpcall = drugsftp[i].split('/')
    ftppath = ftpcall[0]+'/'+ftpcall[1]+ '/'
    ftpfile = ftpcall[-1]
    ftpdir.setdefault(ftppath,[])
    ftpdir[ftppath].append(ftpfile)
#ftpdir

# %%
for key in ftpdir.keys():
    # %cd /content/drive/My Drive/Project: Pill ID/Data
    ftp = FTP('lhcftp.nlm.nih.gov')
    ftp.login()
    ftp.cwd('Open-Access-Datasets/Pills//')
    ftp.cwd(key)
    dloaded = os.listdir('/content/drive/My Drive/Project: Pill ID/Data')
    for value in ftpdir[key]:
      if value not in dloaded:
        with open(value, 'wb') as fp:
            ftp.retrbinary('RETR '+ value, fp.write)
    ftp.cwd('..')
    ftp.cwd('..')
