# %%
import pandas as pd
import requests
from IPython.display import Image
import time
from ftplib import FTP

from PIL import Image
from PIL import ImageFile
import rawpy
import imageio
ImageFile.LOAD_TRUNCATED_IMAGES = True


import os, shutil

import os
import sys

# %%
imagecount = 69

# %%
typdict = {'NDC':'str'}
df = pd.read_csv('../data/directory_of_images.txt',sep='|', dtype=typdict, names=['NDC','IDK','FILE','TYPE','DRUG'])
df = df.dropna()
df.DRUG = df.DRUG.str.upper()
df[['ORIG_FOLDER','IMAGES','FILENAME']] = df.FILE.str.split('/', expand=True)
df['FILETYPE'] = df.FILENAME.str[-4:]
df = df[df.FILETYPE != '.WMV']

# %%
ndcs = df.NDC.value_counts()
n = ndcs[ndcs == imagecount].index
# #n100 = ndcs[ndcs <= 100].index
# ndcs50100 = list(set(n50) & set(n100))
dfn = df[df.NDC.isin(n)]
dfn
# Out:
#                NDC  IDK                                               FILE  \
# 13491  00093073301    1  PillProjectDisc41/images/BNKJ2ZFS-6P83HH77DMR2...
# 13492  00093073301    1  PillProjectDisc57/images/CAA-RYCU0FPFITZFZ!IM6...
# 13493  00093073301    1  PillProjectDisc69/images/CL4IFYKHKRSB0!O_SV5GS...
# 13494  00093073301    1  PillProjectDisc94/images/M-SZSJZO92GLQRMR-QHBN...
# 13495  00093073301    1  PillProjectDisc100/images/RPG75XXI2E6XU6LE!6SI...
# ...            ...  ...                                                ...
# 96070  51285008070    2  PillProjectDisc6/images/2TTGM5BXEE-17KI5YBUFV5...
# 96071  51285008070    2  PillProjectDisc88/images/FYOINRH5KOURSKKRUTCJ2...
# 96072  51285008070    2  PillProjectDisc97/images/OGFUCUF16O20G130SNH!5...
# 96073  51285008070    1  PillProjectDisc66/images/CI9G95K0PUFZ97DMLL04!...
# 96074  51285008070    2  PillProjectDisc74/images/CQ2-Z-411MRHU2TZT_KXM...
#
#                             TYPE                             DRUG  \
# 13491             C3PI_Reference  METOPROLOL TARTRATE TABLETS USP
# 13492             C3PI_Reference              METOPROLOL TARTRATE
# 13493             C3PI_Reference  METOPROLOL TARTRATE TABLETS USP
# 13494             C3PI_Reference              METOPROLOL TARTRATE
# 13495                  C3PI_Test  METOPROLOL TARTRATE TABLETS USP
# ...                          ...                              ...
# 96070  MC_COOKED_CALIBRATED_V1.2               LOESTRIN FE 1 / 20
# 96071  MC_COOKED_CALIBRATED_V1.2               LOESTRIN FE 1 / 20
# 96072  MC_COOKED_CALIBRATED_V1.2               LOESTRIN FE 1 / 20
# 96073       MC_SPL_SPLIMAGE_V3.0               LOESTRIN FE 1 / 20
# 96074       MC_SPL_SPLIMAGE_V3.0               LOESTRIN FE 1 / 20
#
#               ORIG_FOLDER  IMAGES                             FILENAME  \
# 13491   PillProjectDisc41  images  BNKJ2ZFS-6P83HH77DMR2Y7OY0E-TIK.CR2
# 13492   PillProjectDisc57  images  CAA-RYCU0FPFITZFZ!IM6JNWX15WWGC.CR2
# 13493   PillProjectDisc69  images  CL4IFYKHKRSB0!O_SV5GS!Y14E08F6B.CR2
# 13494   PillProjectDisc94  images   M-SZSJZO92GLQRMR-QHBNN0QK3EGCE.CR2
# 13495  PillProjectDisc100  images   RPG75XXI2E6XU6LE!6SIANAZ-R__KI.JPG
# ...                   ...     ...                                  ...
# 96070    PillProjectDisc6  images   2TTGM5BXEE-17KI5YBUFV5WA9M2_FZ.PNG
# 96071   PillProjectDisc88  images   FYOINRH5KOURSKKRUTCJ2ZIGSUHF-0.PNG
# 96072   PillProjectDisc97  images   OGFUCUF16O20G130SNH!5!BCCGY4XY.PNG
# 96073   PillProjectDisc66  images  CI9G95K0PUFZ97DMLL04!UIKNCCJUE9.JPG
# 96074   PillProjectDisc74  images  CQ2-Z-411MRHU2TZT_KXMPWCJ0BQ779.JPG
#
#       FILETYPE
# 13491     .CR2
# 13492     .CR2
# 13493     .CR2
# 13494     .CR2
# 13495     .JPG
# ...        ...
# 96070     .PNG
# 96071     .PNG
# 96072     .PNG
# 96073     .JPG
# 96074     .JPG
#
# [759 rows x 9 columns]

# %%
dfn.DRUG.value_counts()
# Out:
# WARFARIN SODIUM                          74
# LOESTRIN FE 1 / 20                       69
# GLIP/METFORM 5-500MG TAB                 69
# WARFARIN SODIUM TABLETS, USP             64
# PIROXICAM                                36
# GLIMEPIRIDE                              36
# VENLAFAXINE HYDROCHLORIDE TABLETS        36
# PAROXETINE TABLETS USP                   36
# HYDROXYZINE HYDROCHLORIDE TABLETS USP    36
# LISINOPRIL TABLETS USP                   36
# METOPROLOL TARTRATE                      35
# METOPROLOL TARTRATE TABLETS USP          34
# HYDROXYZINE HYDROCHLORIDE                33
# LISINOPRIL                               33
# VENLAFAXINE HYDROCHLORIDE                33
# GLIMEPIRIDE TABLETS USP                  33
# PIROXICAM CAPSULES USP                   33
# PAROXETINE                               33
# Name: DRUG, dtype: int64

# %%
drugs = dfn.NDC.value_counts()
drugslist = drugs.index.tolist()
len(dfn.NDC.value_counts()),drugs
# Out:
# (11,
#  00093075601    69
#  00093073301    69
#  00093725601    69
#  50111030801    69
#  00093711598    69
#  00555083102    69
#  00172376160    69
#  00591397301    69
#  51285008070    69
#  00555092502    69
#  00093738001    69
#  Name: NDC, dtype: int64)

# %%
df_a = dfn.groupby(['DRUG','NDC']).count()
df_a.reset_index(inplace=True)
drug_ndc = df_a[['DRUG','NDC']]
drug_ndc
# Out:
#                                      DRUG          NDC
# 0                             GLIMEPIRIDE  00093725601
# 1                 GLIMEPIRIDE TABLETS USP  00093725601
# 2                GLIP/METFORM 5-500MG TAB  00591397301
# 3               HYDROXYZINE HYDROCHLORIDE  50111030801
# 4   HYDROXYZINE HYDROCHLORIDE TABLETS USP  50111030801
# 5                              LISINOPRIL  00172376160
# 6                  LISINOPRIL TABLETS USP  00172376160
# 7                      LOESTRIN FE 1 / 20  51285008070
# 8                     METOPROLOL TARTRATE  00093073301
# 9         METOPROLOL TARTRATE TABLETS USP  00093073301
# 10                             PAROXETINE  00093711598
# 11                 PAROXETINE TABLETS USP  00093711598
# 12                              PIROXICAM  00093075601
# 13                 PIROXICAM CAPSULES USP  00093075601
# 14              VENLAFAXINE HYDROCHLORIDE  00093738001
# 15      VENLAFAXINE HYDROCHLORIDE TABLETS  00093738001
# 16                        WARFARIN SODIUM  00555083102
# 17                        WARFARIN SODIUM  00555092502
# 18           WARFARIN SODIUM TABLETS, USP  00555083102
# 19           WARFARIN SODIUM TABLETS, USP  00555092502

# %%
droplist = ['51285008070']

df = dfn[~dfn.NDC.isin(droplist)]

# %%
df.DRUG[df.NDC == '00093725601'] = 'GLIMEPIRIDE'
df.DRUG[df.NDC == '00591397301'] = 'GLIP/METFORM 5-500MG'
df.DRUG[df.NDC == '50111030801'] = 'HYDROXYZINE HYDROCHLORIDE'
df.DRUG[df.NDC == '00172376160'] = 'LISINOPRIL'
df.DRUG[df.NDC == '00093073301'] = 'METOPROLOL TARTRATE'
df.DRUG[df.NDC == '00093711598'] = 'PAROXETINE'
df.DRUG[df.NDC == '00093075601'] = 'PIROXICAM'
df.DRUG[df.NDC == '00093738001'] = 'VENLAFAXINE HYDROCHLORIDE'
df.DRUG[df.NDC == '00555083102'] = 'WARFARIN 5MG'
df.DRUG[df.NDC == '00555092502'] = 'WARFARIN 3MG'
# Out:
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/pandas/core/generic.py:8765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df
# Out:
#                NDC  IDK                                               FILE  \
# 13491  00093073301    1  PillProjectDisc41/images/BNKJ2ZFS-6P83HH77DMR2...
# 13492  00093073301    1  PillProjectDisc57/images/CAA-RYCU0FPFITZFZ!IM6...
# 13493  00093073301    1  PillProjectDisc69/images/CL4IFYKHKRSB0!O_SV5GS...
# 13494  00093073301    1  PillProjectDisc94/images/M-SZSJZO92GLQRMR-QHBN...
# 13495  00093073301    1  PillProjectDisc100/images/RPG75XXI2E6XU6LE!6SI...
# ...            ...  ...                                                ...
# 90487  50111030801    1  PillProjectDisc64/images/CGKYG74SZNKQKB1S3TH5B...
# 90488  50111030801    1  PillProjectDisc66/images/CIOQZ2-0V9_SH9DGDG!YV...
# 90489  50111030801    1  PillProjectDisc75/images/CRSJ90P072001BHSO16H4...
# 90490  50111030801    1  PillProjectDisc82/images/CXHZWHLU9O5UR6ING-WK1...
# 90491  50111030801    1  PillProjectDisc2/images/-RAT7YDIRVD9PGGNLGM3!F...
#
#                             TYPE                       DRUG  \
# 13491             C3PI_Reference        METOPROLOL TARTRATE
# 13492             C3PI_Reference        METOPROLOL TARTRATE
# 13493             C3PI_Reference        METOPROLOL TARTRATE
# 13494             C3PI_Reference        METOPROLOL TARTRATE
# 13495                  C3PI_Test        METOPROLOL TARTRATE
# ...                          ...                        ...
# 90487  MC_COOKED_CALIBRATED_V1.2  HYDROXYZINE HYDROCHLORIDE
# 90488  MC_COOKED_CALIBRATED_V1.2  HYDROXYZINE HYDROCHLORIDE
# 90489  MC_COOKED_CALIBRATED_V1.2  HYDROXYZINE HYDROCHLORIDE
# 90490  MC_COOKED_CALIBRATED_V1.2  HYDROXYZINE HYDROCHLORIDE
# 90491       MC_SPL_SPLIMAGE_V3.0  HYDROXYZINE HYDROCHLORIDE
#
#               ORIG_FOLDER  IMAGES                             FILENAME  \
# 13491   PillProjectDisc41  images  BNKJ2ZFS-6P83HH77DMR2Y7OY0E-TIK.CR2
# 13492   PillProjectDisc57  images  CAA-RYCU0FPFITZFZ!IM6JNWX15WWGC.CR2
# 13493   PillProjectDisc69  images  CL4IFYKHKRSB0!O_SV5GS!Y14E08F6B.CR2
# 13494   PillProjectDisc94  images   M-SZSJZO92GLQRMR-QHBNN0QK3EGCE.CR2
# 13495  PillProjectDisc100  images   RPG75XXI2E6XU6LE!6SIANAZ-R__KI.JPG
# ...                   ...     ...                                  ...
# 90487   PillProjectDisc64  images  CGKYG74SZNKQKB1S3TH5B!A7IZ7CNXH.PNG
# 90488   PillProjectDisc66  images  CIOQZ2-0V9_SH9DGDG!YVY7UR0CUF8X.PNG
# 90489   PillProjectDisc75  images  CRSJ90P072001BHSO16H4X6-Q3FI9IF.PNG
# 90490   PillProjectDisc82  images  CXHZWHLU9O5UR6ING-WK1GNHKCIUKTN.PNG
# 90491    PillProjectDisc2  images   -RAT7YDIRVD9PGGNLGM3!FNL61PYBE.JPG
#
#       FILETYPE
# 13491     .CR2
# 13492     .CR2
# 13493     .CR2
# 13494     .CR2
# 13495     .JPG
# ...        ...
# 90487     .PNG
# 90488     .PNG
# 90489     .PNG
# 90490     .PNG
# 90491     .JPG
#
# [690 rows x 9 columns]

# %%
df.DRUG.value_counts()
# Out:
# VENLAFAXINE HYDROCHLORIDE    69
# WARFARIN 3MG                 69
# PIROXICAM                    69
# GLIMEPIRIDE                  69
# METOPROLOL TARTRATE          69
# GLIP/METFORM 5-500MG         69
# WARFARIN 5MG                 69
# HYDROXYZINE HYDROCHLORIDE    69
# LISINOPRIL                   69
# PAROXETINE                   69
# Name: DRUG, dtype: int64

# %%
df_a = df.groupby(['DRUG','NDC']).count()
df_a.reset_index(inplace=True)
drug_ndc = df_a[['DRUG','NDC']]
drug_ndc
# Out:
#                         DRUG          NDC
# 0                GLIMEPIRIDE  00093725601
# 1       GLIP/METFORM 5-500MG  00591397301
# 2  HYDROXYZINE HYDROCHLORIDE  50111030801
# 3                 LISINOPRIL  00172376160
# 4        METOPROLOL TARTRATE  00093073301
# 5                 PAROXETINE  00093711598
# 6                  PIROXICAM  00093075601
# 7  VENLAFAXINE HYDROCHLORIDE  00093738001
# 8               WARFARIN 3MG  00555092502
# 9               WARFARIN 5MG  00555083102

# %%
drugsftp = df.FILE.tolist()
drugsftp.sort()
drugsftp[:10]
# Out:
# ['PillProjectDisc1/images/!!SRPQXAASBCQPWTY-1_4ONT78S2KK.JPG',
#  'PillProjectDisc1/images/!99Q2YI6N7XBRNIV521EXYA051ES_E.JPG',
#  'PillProjectDisc1/images/!G2OJPKYTI7ES1-OW251RY6PK6BHU-.JPG',
#  'PillProjectDisc1/images/!L72!LZSGQBPUUDO56-XU6KVC45OKW.JPG',
#  'PillProjectDisc1/images/!UGIF6I_H_5XC6_A916LVOYLST0SAO.CR2',
#  'PillProjectDisc10/images/7135DCC7VXGE3I8F9_QOZ0JWYHZUT4.JPG',
#  'PillProjectDisc10/images/7CBG_85RQOODGTH030MF3UI_3PS21B.PNG',
#  'PillProjectDisc10/images/7EO-XG_FK7T16N7ADOU0CWL1MJT3CX.JPG',
#  'PillProjectDisc100/images/QV3PUW3N2HL6KF8HSXV_1KL7HH98!E.JPG',
#  'PillProjectDisc100/images/QY_4JH6D4YSSXZZHN2L!7LGE08P4QZ.PNG']

# %%
ftpdir = {}
for i in range(0,len(drugsftp)):
    ftpcall = drugsftp[i].split('/')
    ftppath = ftpcall[0]+'/'+ftpcall[1]+ '/'
    ftpfile = ftpcall[-1]
    ftpdir.setdefault(ftppath,[])
    ftpdir[ftppath].append(ftpfile)
len(ftpdir)
# Out:
# 110

# %%
# %cd /content/drive/My Drive/Project: Pill ID/Data
for key in ftpdir.keys():
    #%cd /content/drive/My Drive/Project: Pill ID/Data
    ftp = FTP('lhcftp.nlm.nih.gov')
    ftp.login()
    ftp.cwd('Open-Access-Datasets/Pills//')
    ftp.cwd(key)
    dloaded = os.listdir('/content/drive/My Drive/Project: Pill ID/Data')
    print(key)
    for value in ftpdir[key]:
      if value not in dloaded:
        with open(value, 'wb') as fp:
            ftp.retrbinary('RETR '+ value, fp.write)
    ftp.cwd('..')
    ftp.cwd('..')
