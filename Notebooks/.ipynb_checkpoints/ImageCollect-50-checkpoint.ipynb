# %%
import pandas as pd
import requests
from IPython.display import Image
import time
from ftplib import FTP

from PIL import Image
from PIL import ImageFile
import rawpy
import imageio
ImageFile.LOAD_TRUNCATED_IMAGES = True


import os, shutil

import os
import sys

# %%
imagecount = 50

# %%
typdict = {'NDC':'str'}
df = pd.read_csv('../data/directory_of_images.txt',sep='|', dtype=typdict, names=['NDC','IDK','FILE','TYPE','DRUG'])
df = df.dropna()
df.DRUG = df.DRUG.str.upper()
df[['ORIG_FOLDER','IMAGES','FILENAME']] = df.FILE.str.split('/', expand=True)
df['FILETYPE'] = df.FILENAME.str[-4:]
df = df[df.FILETYPE != '.WMV']

# %%
ndcs = df.NDC.value_counts()
n = ndcs[ndcs == imagecount].index
# #n100 = ndcs[ndcs <= 100].index
# ndcs50100 = list(set(n50) & set(n100))
dfn = df[df.NDC.isin(n)]
dfn
# Out:
#                 NDC  IDK                                               FILE  \
# 1226    00006074554    1  PillProjectDisc24/images/B7VF6YKZAKU7R6RH9PJC6...
# 1227    00006074554    1  PillProjectDisc53/images/BZRBET5WWF01MHM0TS8UA...
# 1228    00006074554    1  PillProjectDisc106/images/W7_68M2JGM2VVC-5BAJU...
# 1229    00006074554    1  PillProjectDisc109/images/ZSLAKUF3PNEZFLJIRVSV...
# 1230    00006074554    1  PillProjectDisc11/images/7RPWFG3ZF3E0LL1L!4TBA...
# ...             ...  ...                                                ...
# 124244  65862019905    1  PillProjectDisc20/images/B48ZJ0_NS_D9U78ON7-GM...
# 124245  65862019905    1  PillProjectDisc53/images/BZ1FSXTOE4T22MSGJXFRT...
# 124246  65862019905    1  PillProjectDisc5/images/1XUYSB3P6Q36KO510FS9BW...
# 124247  65862019905    1  PillProjectDisc66/images/CIHOS-4VFVZT8UTQZ00OY...
# 124248  65862019905    1  PillProjectDisc2/images/-C9U9YVLUDE71T0KQE16CX...
#
#                              TYPE                  DRUG         ORIG_FOLDER  \
# 1226               C3PI_Reference   HYZAAR TAB 100-12.5   PillProjectDisc24
# 1227               C3PI_Reference   HYZAAR TAB 100-12.5   PillProjectDisc53
# 1228                    C3PI_Test   HYZAAR TAB 100-12.5  PillProjectDisc106
# 1229                    C3PI_Test   HYZAAR TAB 100-12.5  PillProjectDisc109
# 1230                    C3PI_Test   HYZAAR TAB 100-12.5   PillProjectDisc11
# ...                           ...                   ...                 ...
# 124244  MC_COOKED_CALIBRATED_V1.2  GABAPENTIN 300MG CAP   PillProjectDisc20
# 124245  MC_COOKED_CALIBRATED_V1.2  GABAPENTIN 300MG CAP   PillProjectDisc53
# 124246  MC_COOKED_CALIBRATED_V1.2  GABAPENTIN 300MG CAP    PillProjectDisc5
# 124247  MC_COOKED_CALIBRATED_V1.2  GABAPENTIN 300MG CAP   PillProjectDisc66
# 124248       MC_SPL_SPLIMAGE_V3.0  GABAPENTIN 300MG CAP    PillProjectDisc2
#
#         IMAGES                             FILENAME FILETYPE
# 1226    images  B7VF6YKZAKU7R6RH9PJC6-Q3QNJYYO4.CR2     .CR2
# 1227    images  BZRBET5WWF01MHM0TS8UAJE_XKVUZV8.CR2     .CR2
# 1228    images   W7_68M2JGM2VVC-5BAJURW0-MELXXR.JPG     .JPG
# 1229    images   ZSLAKUF3PNEZFLJIRVSV6-ZS7V7-QL.JPG     .JPG
# 1230    images   7RPWFG3ZF3E0LL1L!4TBAD7BD_WGWY.JPG     .JPG
# ...        ...                                  ...      ...
# 124244  images  B48ZJ0_NS_D9U78ON7-GM3UGB26UI1W.PNG     .PNG
# 124245  images  BZ1FSXTOE4T22MSGJXFRTL16HYT8GXR.PNG     .PNG
# 124246  images   1XUYSB3P6Q36KO510FS9BWMK5GW_AQ.PNG     .PNG
# 124247  images  CIHOS-4VFVZT8UTQZ00OYFI-M!HB4OW.PNG     .PNG
# 124248  images   -C9U9YVLUDE71T0KQE16CXA5Z1YA39.JPG     .JPG
#
# [750 rows x 9 columns]

# %%
dfn.DRUG.value_counts()
# Out:
# HYDROXYZINE  HCL 10MG TABS    50
# BENZONATATE CAPSULES, USP     50
# IBUPROFEN 600MG TAB           50
# HYZAAR TAB 100-12.5           50
# GLIPIZIDE ER 10MG TAB         50
# HYOMAX-DT 0.375MG TABLET      50
# CLEOCIN 75MG CAPS             50
# CLARITHROMYCIN 250            50
# HCTZ 50MG TABS                50
# FLUOXETINE 40MG CAP           50
# HYOMAX-FT 0.125MG TAB         50
# GABAPENTIN 300MG CAP          50
# INDERAL LA CAP 160MG          50
# OLANZAPINE 2.5MG TAB          33
# INDOMETHACIN CAPSULES USP     33
# INDOMETHACIN CAPSULES, USP    17
# OLANZAPINE TABLETS USP        17
# Name: DRUG, dtype: int64

# %%
drugs = dfn.NDC.value_counts()
drugslist = drugs.index.tolist()
len(dfn.NDC.value_counts()),drugs
# Out:
# (15,
#  00555188302    50
#  24486060310    50
#  00093402901    50
#  65862019905    50
#  00781196160    50
#  23155010501    50
#  24486060490    50
#  55111068305    50
#  00009033102    50
#  00093576756    50
#  00591084510    50
#  65862019430    50
#  24090047988    50
#  64125013010    50
#  00006074554    50
#  Name: NDC, dtype: int64)

# %%
df_a = dfn.groupby(['DRUG','NDC']).count()
df_a.reset_index(inplace=True)
drug_ndc = df_a[['DRUG','NDC']]
drug_ndc
# Out:
#                           DRUG          NDC
# 0    BENZONATATE CAPSULES, USP  00555188302
# 1           CLARITHROMYCIN 250  00781196160
# 2            CLEOCIN 75MG CAPS  00009033102
# 3          FLUOXETINE 40MG CAP  65862019430
# 4         GABAPENTIN 300MG CAP  65862019905
# 5        GLIPIZIDE ER 10MG TAB  00591084510
# 6               HCTZ 50MG TABS  64125013010
# 7   HYDROXYZINE  HCL 10MG TABS  23155010501
# 8     HYOMAX-DT 0.375MG TABLET  24486060490
# 9        HYOMAX-FT 0.125MG TAB  24486060310
# 10         HYZAAR TAB 100-12.5  00006074554
# 11         IBUPROFEN 600MG TAB  55111068305
# 12        INDERAL LA CAP 160MG  24090047988
# 13   INDOMETHACIN CAPSULES USP  00093402901
# 14  INDOMETHACIN CAPSULES, USP  00093402901
# 15        OLANZAPINE 2.5MG TAB  00093576756
# 16      OLANZAPINE TABLETS USP  00093576756

# %%
droplist = []

df = dfn[~dfn.NDC.isin(droplist)]

# %%
df.DRUG[df.NDC == ''] = ''
df.DRUG[df.NDC == ''] = ''
df.DRUG[df.NDC == ''] = ''
df.DRUG[df.NDC == ''] = ''
df.DRUG[df.NDC == ''] = ''
df.DRUG[df.NDC == ''] = ''
df.DRUG[df.NDC == ''] = ''
df.DRUG[df.NDC == ''] = ''
df.DRUG[df.NDC == ''] = ''
df.DRUG[df.NDC == ''] = ''
df.DRUG[df.NDC == ''] = ''
df.DRUG[df.NDC == ''] = ''
df.DRUG[df.NDC == ''] = ''
df.DRUG[df.NDC == ''] = ''
df.DRUG[df.NDC == ''] = ''
df.DRUG[df.NDC == ''] = ''
# Out:
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %%
df
# Out:
#                 NDC  IDK                                               FILE  \
# 1226    00006074554    1  PillProjectDisc24/images/B7VF6YKZAKU7R6RH9PJC6...
# 1227    00006074554    1  PillProjectDisc53/images/BZRBET5WWF01MHM0TS8UA...
# 1228    00006074554    1  PillProjectDisc106/images/W7_68M2JGM2VVC-5BAJU...
# 1229    00006074554    1  PillProjectDisc109/images/ZSLAKUF3PNEZFLJIRVSV...
# 1230    00006074554    1  PillProjectDisc11/images/7RPWFG3ZF3E0LL1L!4TBA...
# ...             ...  ...                                                ...
# 124244  65862019905    1  PillProjectDisc20/images/B48ZJ0_NS_D9U78ON7-GM...
# 124245  65862019905    1  PillProjectDisc53/images/BZ1FSXTOE4T22MSGJXFRT...
# 124246  65862019905    1  PillProjectDisc5/images/1XUYSB3P6Q36KO510FS9BW...
# 124247  65862019905    1  PillProjectDisc66/images/CIHOS-4VFVZT8UTQZ00OY...
# 124248  65862019905    1  PillProjectDisc2/images/-C9U9YVLUDE71T0KQE16CX...
#
#                              TYPE                  DRUG         ORIG_FOLDER  \
# 1226               C3PI_Reference   HYZAAR TAB 100-12.5   PillProjectDisc24
# 1227               C3PI_Reference   HYZAAR TAB 100-12.5   PillProjectDisc53
# 1228                    C3PI_Test   HYZAAR TAB 100-12.5  PillProjectDisc106
# 1229                    C3PI_Test   HYZAAR TAB 100-12.5  PillProjectDisc109
# 1230                    C3PI_Test   HYZAAR TAB 100-12.5   PillProjectDisc11
# ...                           ...                   ...                 ...
# 124244  MC_COOKED_CALIBRATED_V1.2  GABAPENTIN 300MG CAP   PillProjectDisc20
# 124245  MC_COOKED_CALIBRATED_V1.2  GABAPENTIN 300MG CAP   PillProjectDisc53
# 124246  MC_COOKED_CALIBRATED_V1.2  GABAPENTIN 300MG CAP    PillProjectDisc5
# 124247  MC_COOKED_CALIBRATED_V1.2  GABAPENTIN 300MG CAP   PillProjectDisc66
# 124248       MC_SPL_SPLIMAGE_V3.0  GABAPENTIN 300MG CAP    PillProjectDisc2
#
#         IMAGES                             FILENAME FILETYPE
# 1226    images  B7VF6YKZAKU7R6RH9PJC6-Q3QNJYYO4.CR2     .CR2
# 1227    images  BZRBET5WWF01MHM0TS8UAJE_XKVUZV8.CR2     .CR2
# 1228    images   W7_68M2JGM2VVC-5BAJURW0-MELXXR.JPG     .JPG
# 1229    images   ZSLAKUF3PNEZFLJIRVSV6-ZS7V7-QL.JPG     .JPG
# 1230    images   7RPWFG3ZF3E0LL1L!4TBAD7BD_WGWY.JPG     .JPG
# ...        ...                                  ...      ...
# 124244  images  B48ZJ0_NS_D9U78ON7-GM3UGB26UI1W.PNG     .PNG
# 124245  images  BZ1FSXTOE4T22MSGJXFRTL16HYT8GXR.PNG     .PNG
# 124246  images   1XUYSB3P6Q36KO510FS9BWMK5GW_AQ.PNG     .PNG
# 124247  images  CIHOS-4VFVZT8UTQZ00OYFI-M!HB4OW.PNG     .PNG
# 124248  images   -C9U9YVLUDE71T0KQE16CXA5Z1YA39.JPG     .JPG
#
# [750 rows x 9 columns]

# %%
df.DRUG.value_counts()
# Out:
# HYDROXYZINE  HCL 10MG TABS    50
# BENZONATATE CAPSULES, USP     50
# IBUPROFEN 600MG TAB           50
# HYZAAR TAB 100-12.5           50
# GLIPIZIDE ER 10MG TAB         50
# HYOMAX-DT 0.375MG TABLET      50
# CLEOCIN 75MG CAPS             50
# CLARITHROMYCIN 250            50
# HCTZ 50MG TABS                50
# FLUOXETINE 40MG CAP           50
# HYOMAX-FT 0.125MG TAB         50
# GABAPENTIN 300MG CAP          50
# INDERAL LA CAP 160MG          50
# OLANZAPINE 2.5MG TAB          33
# INDOMETHACIN CAPSULES USP     33
# INDOMETHACIN CAPSULES, USP    17
# OLANZAPINE TABLETS USP        17
# Name: DRUG, dtype: int64

# %%
df_a = df.groupby(['DRUG','NDC']).count()
df_a.reset_index(inplace=True)
drug_ndc = df_a[['DRUG','NDC']]
drug_ndc
# Out:
#                           DRUG          NDC
# 0    BENZONATATE CAPSULES, USP  00555188302
# 1           CLARITHROMYCIN 250  00781196160
# 2            CLEOCIN 75MG CAPS  00009033102
# 3          FLUOXETINE 40MG CAP  65862019430
# 4         GABAPENTIN 300MG CAP  65862019905
# 5        GLIPIZIDE ER 10MG TAB  00591084510
# 6               HCTZ 50MG TABS  64125013010
# 7   HYDROXYZINE  HCL 10MG TABS  23155010501
# 8     HYOMAX-DT 0.375MG TABLET  24486060490
# 9        HYOMAX-FT 0.125MG TAB  24486060310
# 10         HYZAAR TAB 100-12.5  00006074554
# 11         IBUPROFEN 600MG TAB  55111068305
# 12        INDERAL LA CAP 160MG  24090047988
# 13   INDOMETHACIN CAPSULES USP  00093402901
# 14  INDOMETHACIN CAPSULES, USP  00093402901
# 15        OLANZAPINE 2.5MG TAB  00093576756
# 16      OLANZAPINE TABLETS USP  00093576756

# %% [markdown]
# ## Sample Batch

# %%
samplesdf = df.groupby(['NDC']).min().reset_index()
samplesdf
# Out:
#             NDC  IDK                                               FILE  \
# 0   00006074554    1  PillProjectDisc106/images/W7_68M2JGM2VVC-5BAJU...
# 1   00009033102    1  PillProjectDisc1/images/!Y7FKLUPG3TK-OZ7A5EVQC...
# 2   00093402901    1  PillProjectDisc1/images/!J0N020HAC1N9IDCYU3QJJ...
# 3   00093576756    1  PillProjectDisc100/images/RH9UF_3Y8IGRT7667NHD...
# 4   00555188302    1  PillProjectDisc10/images/6R66C0USAMBP_!SWRIXWY...
# 5   00591084510    1  PillProjectDisc1/images/!1ECEZFCQZ5I6S0RP6IZ-T...
# 6   00781196160    1  PillProjectDisc10/images/74ICS5KP_V8HXH7E06T5E...
# 7   23155010501    1  PillProjectDisc10/images/6WR1PH9H_A4BS42IDTF_C...
# 8   24090047988    1  PillProjectDisc100/images/QUUWWQHY9--!WSDMSB_8...
# 9   24486060310    1  PillProjectDisc100/images/R05!128RGR-VT4AVU5N2...
# 10  24486060490    1  PillProjectDisc1/images/!GAGH9SEMPWXKDD0B79O2W...
# 11  55111068305    1  PillProjectDisc105/images/VER41AEE7LM-9UCG7ZQ5...
# 12  64125013010    1  PillProjectDisc10/images/6MBF88872OTKN19TLJH!0...
# 13  65862019430    1  PillProjectDisc10/images/6UFKARR8JAS2HO771K5QN...
# 14  65862019905    1  PillProjectDisc105/images/VA_4MYBY5!ICO!P3G1TC...
#
#               TYPE                        DRUG         ORIG_FOLDER  IMAGES  \
# 0   C3PI_Reference         HYZAAR TAB 100-12.5  PillProjectDisc106  images
# 1   C3PI_Reference           CLEOCIN 75MG CAPS    PillProjectDisc1  images
# 2   C3PI_Reference   INDOMETHACIN CAPSULES USP    PillProjectDisc1  images
# 3   C3PI_Reference        OLANZAPINE 2.5MG TAB  PillProjectDisc100  images
# 4   C3PI_Reference   BENZONATATE CAPSULES, USP   PillProjectDisc10  images
# 5   C3PI_Reference       GLIPIZIDE ER 10MG TAB    PillProjectDisc1  images
# 6   C3PI_Reference          CLARITHROMYCIN 250   PillProjectDisc10  images
# 7   C3PI_Reference  HYDROXYZINE  HCL 10MG TABS   PillProjectDisc10  images
# 8   C3PI_Reference        INDERAL LA CAP 160MG  PillProjectDisc100  images
# 9   C3PI_Reference       HYOMAX-FT 0.125MG TAB  PillProjectDisc100  images
# 10  C3PI_Reference    HYOMAX-DT 0.375MG TABLET    PillProjectDisc1  images
# 11  C3PI_Reference         IBUPROFEN 600MG TAB  PillProjectDisc105  images
# 12  C3PI_Reference              HCTZ 50MG TABS   PillProjectDisc10  images
# 13  C3PI_Reference         FLUOXETINE 40MG CAP   PillProjectDisc10  images
# 14  C3PI_Reference        GABAPENTIN 300MG CAP  PillProjectDisc105  images
#
#                               FILENAME FILETYPE
# 0   -8B_LDTUBA2_UTL594TZENV6N_F6E5.JPG     .CR2
# 1   !Y7FKLUPG3TK-OZ7A5EVQCVF420-VJ.PNG     .CR2
# 2   !J0N020HAC1N9IDCYU3QJJN!5YA2A!.PNG     .CR2
# 3   43P7PH4RNUB-ENTSZ08US3!XNVD2MT.JPG     .CR2
# 4   3UL4FEG!R3JTALFY_4YRZEKD0TE86U.PNG     .CR2
# 5   !1ECEZFCQZ5I6S0RP6IZ-T!_6Y2RXW.PNG     .CR2
# 6   2JBEGI_0FCNLS3E-YHL!UZ5HZ94R7F.JPG     .CR2
# 7   07G1RJ_PDELEHJT_O!A1BPV9OLQKOA.JPG     .CR2
# 8   0OQZUFPLJXFJWOUPRLUK3_BV4SFFJ_.JPG     .CR2
# 9   137850DN9BLU3OFJ6X75C!_ZUOXIKM.PNG     .CR2
# 10   !GAGH9SEMPWXKDD0B79O2WDHDYV_3.JPG     .CR2
# 11  2NVF4WOKMJ2O4SPODQZ0P!REZGKZ49.JPG     .CR2
# 12  0E8MPIAD29LQFVEDLWJ644YDH173MN.PNG     .CR2
# 13  -DLJGKYUU6H-8JY-Y1V75GYRG-J-33.JPG     .CR2
# 14  -!JQ8T46SUQ!R41C2!PTHSHNG9O7UT.JPG     .CR2

# %%
sampleslist = samplesdf.FILE.tolist()
sampleslist.sort()
sampleslist
# Out:
# ['PillProjectDisc1/images/!1ECEZFCQZ5I6S0RP6IZ-T!_6Y2RXW.PNG',
#  'PillProjectDisc1/images/!GAGH9SEMPWXKDD0B79O2WDHDYV_3.JPG',
#  'PillProjectDisc1/images/!J0N020HAC1N9IDCYU3QJJN!5YA2A!.PNG',
#  'PillProjectDisc1/images/!Y7FKLUPG3TK-OZ7A5EVQCVF420-VJ.PNG',
#  'PillProjectDisc10/images/6MBF88872OTKN19TLJH!0QLNOED708.JPG',
#  'PillProjectDisc10/images/6R66C0USAMBP_!SWRIXWYLZ15G9RL.PNG',
#  'PillProjectDisc10/images/6UFKARR8JAS2HO771K5QNIB0!_B019.JPG',
#  'PillProjectDisc10/images/6WR1PH9H_A4BS42IDTF_CNXSTS31Y-.JPG',
#  'PillProjectDisc10/images/74ICS5KP_V8HXH7E06T5EIG2X717QB.JPG',
#  'PillProjectDisc100/images/QUUWWQHY9--!WSDMSB_8MJ7WZPJYNB.JPG',
#  'PillProjectDisc100/images/R05!128RGR-VT4AVU5N27CIOWQ6M5D.PNG',
#  'PillProjectDisc100/images/RH9UF_3Y8IGRT7667NHDU_OTBP3NAV.JPG',
#  'PillProjectDisc105/images/VA_4MYBY5!ICO!P3G1TCL9LG182H-C.JPG',
#  'PillProjectDisc105/images/VER41AEE7LM-9UCG7ZQ56QTE_I9S8Z.PNG',
#  'PillProjectDisc106/images/W7_68M2JGM2VVC-5BAJURW0-MELXXR.JPG']

# %%
ftpdir = {}
for i in range(0,len(sampleslist)):
    ftpcall = sampleslist[i].split('/')
    ftppath = ftpcall[0]+'/'+ftpcall[1]+ '/'
    ftpfile = ftpcall[-1]
    ftpdir.setdefault(ftppath,[])
    ftpdir[ftppath].append(ftpfile)
len(ftpdir)
# Out:
# 5

# %%
# %pwd
# Out:
# '/Users/alphonsowoodbury/Projects/Computer_Vision-Medication_Identification/Notebooks'

# %%
# %cd Data
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-27-ffbf46652c5c>", line 1, in <module>
#     get_ipython().run_line_magic('cd', 'Data')
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2317, in run_line_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-92>", line 2, in cd
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/magics/osm.py", line 334, in cd
#     oldcwd = os.getcwd()
# PermissionError: [Errno 1] Operation not permitted
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'PermissionError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1148, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# PermissionError: [Errno 1] Operation not permitted
# ---------------------------------------------------------------------------

# %%
folder = 'img'+str(imagecount)
print(folder)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-25-fa298fd77d51>", line 1, in <module>
#     get_ipython().run_line_magic('cd', 'Projects/Computer_Vision-Medication_Identification/Data')
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2317, in run_line_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-92>", line 2, in cd
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/magics/osm.py", line 334, in cd
#     oldcwd = os.getcwd()
# PermissionError: [Errno 1] Operation not permitted
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'PermissionError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1148, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# PermissionError: [Errno 1] Operation not permitted
# ---------------------------------------------------------------------------

# %%
try:
    os.makedirs(folder)
except:
    print('Folder present')
# %cd $folder
# %pwd
dloaded = os.listdir()
for key in ftpdir.keys():
    ftp = FTP('lhcftp.nlm.nih.gov')
    ftp.login()
    ftp.cwd('Open-Access-Datasets/Pills//')
    ftp.cwd(key)
    for value in ftpdir[key]:
        if value not in dloaded:
            with open(value, 'wb') as fp:
                ftp.retrbinary('RETR '+ value, fp.write)
    ftp.cwd('..')
    ftp.cwd('..')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-23-aa3ee0f8cc2d>", line 1, in <module>
#     get_ipython().run_line_magic('cd', '../Data')
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2317, in run_line_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-92>", line 2, in cd
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/magics/osm.py", line 334, in cd
#     oldcwd = os.getcwd()
# PermissionError: [Errno 1] Operation not permitted
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'PermissionError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1148, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# PermissionError: [Errno 1] Operation not permitted
# ---------------------------------------------------------------------------

# %%
drugsftp = df.FILE.tolist()
drugsftp.sort()
drugsftp[:10]
# Out:
# ['PillProjectDisc1/images/!56HENXQPITL7C!4A52GSM0YNF5KKA.PNG',
#  'PillProjectDisc1/images/!7WF161YS_R5ET9Y!26E6UHXF9HXDU.JPG',
#  'PillProjectDisc1/images/!G_6-MR6ALJIVSJV_FG81XV_T76S5C.JPG',
#  'PillProjectDisc1/images/!KIVP9GRT_9CCE7MKA2-!EUSBJK44B.PNG',
#  'PillProjectDisc1/images/!WT4Y657!VOLO3YRBJ5HS9MSRVMZKE.JPG',
#  'PillProjectDisc10/images/6_6!XJ73P9O12E6LVGBAIIGMNO252A.JPG',
#  'PillProjectDisc10/images/6_6!XJ73P9O12E6LVGBAIIGMNO252A.JPG',
#  'PillProjectDisc10/images/71F0PADPK6212-1HT3-IBI-Y!KK!1B.JPG',
#  'PillProjectDisc10/images/71QVB659EJF7J2UOJAR9107P-CC6GM.JPG',
#  'PillProjectDisc10/images/71QVB659EJF7J2UOJAR9107P-CC6GM.JPG']

# %%
ftpdir = {}
for i in range(0,len(drugsftp)):
    ftpcall = drugsftp[i].split('/')
    ftppath = ftpcall[0]+'/'+ftpcall[1]+ '/'
    ftpfile = ftpcall[-1]
    ftpdir.setdefault(ftppath,[])
    ftpdir[ftppath].append(ftpfile)
len(ftpdir)
# Out:
# 102

# %%
# %cd /content/drive/My Drive/Project: Pill ID/Data
for key in ftpdir.keys():
    #%cd /content/drive/My Drive/Project: Pill ID/Data
    ftp = FTP('lhcftp.nlm.nih.gov')
    ftp.login()
    ftp.cwd('Open-Access-Datasets/Pills//')
    ftp.cwd(key)
    dloaded = os.listdir('/content/drive/My Drive/Project: Pill ID/Data')
    print(key)
    for value in ftpdir[key]:
      if value not in dloaded:
        with open(value, 'wb') as fp:
            ftp.retrbinary('RETR '+ value, fp.write)
    ftp.cwd('..')
    ftp.cwd('..')
