# %% [markdown]
# **Too similar**

# %%
import pandas as pd
import requests
from IPython.display import Image
import time
from ftplib import FTP

from PIL import Image
from PIL import ImageFile
import rawpy
import imageio
ImageFile.LOAD_TRUNCATED_IMAGES = True


import os, shutil

import os
import sys
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
imagecount = 59

# %%
typdict = {'NDC':'str'}
df = pd.read_csv('../data/directory_of_images.txt',sep='|', dtype=typdict, names=['NDC','IDK','FILE','TYPE','DRUG'])
df = df.dropna()
df.DRUG = df.DRUG.str.upper()
df[['ORIG_FOLDER','IMAGES','FILENAME']] = df.FILE.str.split('/', expand=True)
df['FILETYPE'] = df.FILENAME.str[-4:]
df = df[df.FILETYPE != '.WMV']

# %%
ndcs = df.NDC.value_counts()
n = ndcs[ndcs == imagecount].index
# #n100 = ndcs[ndcs <= 100].index
# ndcs50100 = list(set(n50) & set(n100))
dfn = df[df.NDC.isin(n)]
dfn
# Out:
#                 NDC  IDK                                               FILE  \
# 12612   00093030801    1  PillProjectDisc10/images/6J5VWHI0KM5RH90DSQEK_...
# 12613   00093030801    1  PillProjectDisc59/images/CC1B4LSFBV2B9FV23E7V_...
# 12614   00093030801    1  PillProjectDisc8/images/4WO7OJ!T8D6_XN2TRBR49-...
# 12615   00093030801    1  PillProjectDisc92/images/JE5O7WUL29CF8GED5CUJ4...
# 12616   00093030801    1  PillProjectDisc106/images/WR8_Q0__VOFVZQI44H6J...
# ...             ...  ...                                                ...
# 132650  68546014256    1  PillProjectDisc4/images/1B8T6-P5RIL!RNHR0-JFVY...
# 132651  68546014256    1  PillProjectDisc53/images/BZELDHLT14PJE3DN1RR!7...
# 132652  68546014256    1  PillProjectDisc59/images/CCHQJ433ZPEKU_8J5U-10...
# 132653  68546014256    1  PillProjectDisc81/images/CWZF8VC1Z1GQ1U3GRXMDG...
# 132654  68546014256    1  PillProjectDisc20/images/B3W3PIMNZ2_HUA58NMTJ2...
#
#                              TYPE                              DRUG  \
# 12612              C3PI_Reference       CLEMASTINE FUMARATE 2.68 MG
# 12613              C3PI_Reference       CLEMASTINE FUMARATE 2.68 MG
# 12614              C3PI_Reference  CLEMASTINE FUMARATE TABLETS, USP
# 12615              C3PI_Reference  CLEMASTINE FUMARATE TABLETS, USP
# 12616                   C3PI_Test       CLEMASTINE FUMARATE 2.68 MG
# ...                           ...                               ...
# 132650  MC_COOKED_CALIBRATED_V1.2                 AZILECT TAB 0.5MG
# 132651  MC_COOKED_CALIBRATED_V1.2                           AZILECT
# 132652  MC_COOKED_CALIBRATED_V1.2                           AZILECT
# 132653  MC_COOKED_CALIBRATED_V1.2                           AZILECT
# 132654       MC_SPL_SPLIMAGE_V3.0                 AZILECT TAB 0.5MG
#
#                ORIG_FOLDER  IMAGES                             FILENAME  \
# 12612    PillProjectDisc10  images   6J5VWHI0KM5RH90DSQEK_NMZW-WDSR.CR2
# 12613    PillProjectDisc59  images  CC1B4LSFBV2B9FV23E7V_0-5EJAFHOY.CR2
# 12614     PillProjectDisc8  images   4WO7OJ!T8D6_XN2TRBR49-EVB-XAJ4.CR2
# 12615    PillProjectDisc92  images   JE5O7WUL29CF8GED5CUJ44!QBJWAB5.CR2
# 12616   PillProjectDisc106  images   WR8_Q0__VOFVZQI44H6JFR5_EKN9JZ.JPG
# ...                    ...     ...                                  ...
# 132650    PillProjectDisc4  images   1B8T6-P5RIL!RNHR0-JFVY57BSJZCN.PNG
# 132651   PillProjectDisc53  images  BZELDHLT14PJE3DN1RR!7FJUH8-PF3J.PNG
# 132652   PillProjectDisc59  images  CCHQJ433ZPEKU_8J5U-10X!W2K7PC50.PNG
# 132653   PillProjectDisc81  images  CWZF8VC1Z1GQ1U3GRXMDGW!-5AZX_X1.PNG
# 132654   PillProjectDisc20  images  B3W3PIMNZ2_HUA58NMTJ2NR0DZ2H_JJ.JPG
#
#        FILETYPE
# 12612      .CR2
# 12613      .CR2
# 12614      .CR2
# 12615      .CR2
# 12616      .JPG
# ...         ...
# 132650     .PNG
# 132651     .PNG
# 132652     .PNG
# 132653     .PNG
# 132654     .JPG
#
# [885 rows x 9 columns]

# %%
dfn.DRUG.value_counts()
# Out:
# DILTIAZEM HYDROCHLORIDE EXTENDED-RELEASE CAPSULES USP    66
# HALOPERIDOL 0.5MG TAB                                    59
# GABAPENTIN 800MG TABLETS                                 59
# HYDRALAZINE 25MG TAB                                     59
# GLIMEPIRIDE 1MG TAB                                      59
# DICLOXACILLIN SODIUM CAPSULES USP                        34
# AMOXICILLIN AND CLAVULANATE POTASSIUM TABLETS USP        32
# KETOROLAC TROMETHAMINE TABLETS USP                       32
# CLEMASTINE FUMARATE TABLETS, USP                         32
# BUMETANIDE TABLETS USP                                   32
# DANAZOL CAP 100MG                                        30
# MEDROXYPR AC 10MG TAB                                    30
# LOSARTAN POT 25MG TAB                                    30
# AZILECT TAB 0.5MG                                        30
# AZILECT                                                  29
# MEDROXYPROGESTERONE ACETATE TABLETS USP                  29
# DANAZOL CAPSULES, USP                                    29
# LOSARTAN POTASSIUM TABLETS USP                           29
# BUMETANIDE TAB 2MG                                       27
# CLEMASTINE FUMARATE 2.68 MG                              27
# DILTIAZEM CAP XR 240MG                                   27
# AMOXICIL/CLAVULANATE 500/125MG                           27
# KETOROLAC 10MG                                           27
# DICLOXACILLIN SOD 500MG CAPS                             25
# DILTIAZEM ER 180MG CAPSULES                              25
# Name: DRUG, dtype: int64

# %%
drugs = dfn.NDC.value_counts()
drugslist = drugs.index.tolist()
len(dfn.NDC.value_counts()),drugs
# Out:
# (15,
#  68462012705    59
#  00093511798    59
#  00093511898    59
#  00093736498    59
#  00093227434    59
#  00093312501    59
#  68546014256    59
#  00781139101    59
#  00555063402    59
#  00093030801    59
#  55111032001    59
#  00093031401    59
#  00555077902    59
#  31722052010    59
#  00093423401    59
#  Name: NDC, dtype: int64)

# %%
df_a = dfn.groupby(['DRUG','NDC']).count()
df_a.reset_index(inplace=True)
drug_ndc = df_a[['DRUG','NDC']]
drug_ndc
# Out:
#                                                  DRUG          NDC
# 0                      AMOXICIL/CLAVULANATE 500/125MG  00093227434
# 1   AMOXICILLIN AND CLAVULANATE POTASSIUM TABLETS USP  00093227434
# 2                                             AZILECT  68546014256
# 3                                   AZILECT TAB 0.5MG  68546014256
# 4                                  BUMETANIDE TAB 2MG  00093423401
# 5                              BUMETANIDE TABLETS USP  00093423401
# 6                         CLEMASTINE FUMARATE 2.68 MG  00093030801
# 7                    CLEMASTINE FUMARATE TABLETS, USP  00093030801
# 8                                   DANAZOL CAP 100MG  00555063402
# 9                               DANAZOL CAPSULES, USP  00555063402
# 10                       DICLOXACILLIN SOD 500MG CAPS  00093312501
# 11                  DICLOXACILLIN SODIUM CAPSULES USP  00093312501
# 12                             DILTIAZEM CAP XR 240MG  00093511898
# 13                        DILTIAZEM ER 180MG CAPSULES  00093511798
# 14  DILTIAZEM HYDROCHLORIDE EXTENDED-RELEASE CAPSU...  00093511798
# 15  DILTIAZEM HYDROCHLORIDE EXTENDED-RELEASE CAPSU...  00093511898
# 16                           GABAPENTIN 800MG TABLETS  68462012705
# 17                                GLIMEPIRIDE 1MG TAB  55111032001
# 18                              HALOPERIDOL 0.5MG TAB  00781139101
# 19                               HYDRALAZINE 25MG TAB  31722052010
# 20                                     KETOROLAC 10MG  00093031401
# 21                 KETOROLAC TROMETHAMINE TABLETS USP  00093031401
# 22                              LOSARTAN POT 25MG TAB  00093736498
# 23                     LOSARTAN POTASSIUM TABLETS USP  00093736498
# 24                              MEDROXYPR AC 10MG TAB  00555077902
# 25            MEDROXYPROGESTERONE ACETATE TABLETS USP  00555077902

# %%
droplist = ['']

df = dfn[~dfn.NDC.isin(droplist)]

# %%
df.DRUG[df.NDC == '00093227434'] = 'AMOXICIL/CLAVULANATE 500/125MG'
df.DRUG[df.NDC == '68546014256'] = 'AZILECT 0.5MG'
df.DRUG[df.NDC == '00093423401'] = 'BUMETANIDE 2MG'
df.DRUG[df.NDC == '00093030801'] = 'CLEMASTINE FUMARATE 2.68 MG'
df.DRUG[df.NDC == '00555063402'] = 'DANAZOL 100MG'
df.DRUG[df.NDC == '00093312501'] = 'DICLOXACILLIN SOD 500MG'
df.DRUG[df.NDC == '00093511898'] = 'DILTIAZEM XR 240MG'
df.DRUG[df.NDC == '00093511798'] = 'DILTIAZEM ER 180MG'
df.DRUG[df.NDC == '68462012705'] = 'GABAPENTIN 800MG'
df.DRUG[df.NDC == '55111032001'] = 'GLIMEPIRIDE 1MG'
df.DRUG[df.NDC == '00781139101'] = 'HALOPERIDOL 0.5MG'
df.DRUG[df.NDC == '31722052010'] = 'HYDRALAZINE 25MG'
df.DRUG[df.NDC == '00093031401'] = 'KETOROLAC 10MG'
df.DRUG[df.NDC == '00093736498'] = 'LOSARTAN 25MG'
df.DRUG[df.NDC == '00555077902'] = 'MEDROXYPROGESTERONE'
# Out:
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
df
# Out:
#                 NDC  IDK                                               FILE  \
# 12612   00093030801    1  PillProjectDisc10/images/6J5VWHI0KM5RH90DSQEK_...
# 12613   00093030801    1  PillProjectDisc59/images/CC1B4LSFBV2B9FV23E7V_...
# 12614   00093030801    1  PillProjectDisc8/images/4WO7OJ!T8D6_XN2TRBR49-...
# 12615   00093030801    1  PillProjectDisc92/images/JE5O7WUL29CF8GED5CUJ4...
# 12616   00093030801    1  PillProjectDisc106/images/WR8_Q0__VOFVZQI44H6J...
# ...             ...  ...                                                ...
# 132650  68546014256    1  PillProjectDisc4/images/1B8T6-P5RIL!RNHR0-JFVY...
# 132651  68546014256    1  PillProjectDisc53/images/BZELDHLT14PJE3DN1RR!7...
# 132652  68546014256    1  PillProjectDisc59/images/CCHQJ433ZPEKU_8J5U-10...
# 132653  68546014256    1  PillProjectDisc81/images/CWZF8VC1Z1GQ1U3GRXMDG...
# 132654  68546014256    1  PillProjectDisc20/images/B3W3PIMNZ2_HUA58NMTJ2...
#
#                              TYPE                         DRUG  \
# 12612              C3PI_Reference  CLEMASTINE FUMARATE 2.68 MG
# 12613              C3PI_Reference  CLEMASTINE FUMARATE 2.68 MG
# 12614              C3PI_Reference  CLEMASTINE FUMARATE 2.68 MG
# 12615              C3PI_Reference  CLEMASTINE FUMARATE 2.68 MG
# 12616                   C3PI_Test  CLEMASTINE FUMARATE 2.68 MG
# ...                           ...                          ...
# 132650  MC_COOKED_CALIBRATED_V1.2                AZILECT 0.5MG
# 132651  MC_COOKED_CALIBRATED_V1.2                AZILECT 0.5MG
# 132652  MC_COOKED_CALIBRATED_V1.2                AZILECT 0.5MG
# 132653  MC_COOKED_CALIBRATED_V1.2                AZILECT 0.5MG
# 132654       MC_SPL_SPLIMAGE_V3.0                AZILECT 0.5MG
#
#                ORIG_FOLDER  IMAGES                             FILENAME  \
# 12612    PillProjectDisc10  images   6J5VWHI0KM5RH90DSQEK_NMZW-WDSR.CR2
# 12613    PillProjectDisc59  images  CC1B4LSFBV2B9FV23E7V_0-5EJAFHOY.CR2
# 12614     PillProjectDisc8  images   4WO7OJ!T8D6_XN2TRBR49-EVB-XAJ4.CR2
# 12615    PillProjectDisc92  images   JE5O7WUL29CF8GED5CUJ44!QBJWAB5.CR2
# 12616   PillProjectDisc106  images   WR8_Q0__VOFVZQI44H6JFR5_EKN9JZ.JPG
# ...                    ...     ...                                  ...
# 132650    PillProjectDisc4  images   1B8T6-P5RIL!RNHR0-JFVY57BSJZCN.PNG
# 132651   PillProjectDisc53  images  BZELDHLT14PJE3DN1RR!7FJUH8-PF3J.PNG
# 132652   PillProjectDisc59  images  CCHQJ433ZPEKU_8J5U-10X!W2K7PC50.PNG
# 132653   PillProjectDisc81  images  CWZF8VC1Z1GQ1U3GRXMDGW!-5AZX_X1.PNG
# 132654   PillProjectDisc20  images  B3W3PIMNZ2_HUA58NMTJ2NR0DZ2H_JJ.JPG
#
#        FILETYPE
# 12612      .CR2
# 12613      .CR2
# 12614      .CR2
# 12615      .CR2
# 12616      .JPG
# ...         ...
# 132650     .PNG
# 132651     .PNG
# 132652     .PNG
# 132653     .PNG
# 132654     .JPG
#
# [885 rows x 9 columns]

# %%
df.DRUG.value_counts()
# Out:
# HYDRALAZINE 25MG                  59
# LOSARTAN 25MG                     59
# KETOROLAC 10MG                    59
# GLIMEPIRIDE 1MG                   59
# GABAPENTIN 800MG                  59
# CLEMASTINE FUMARATE 2.68 MG       59
# DILTIAZEM XR 240MG                59
# AZILECT 0.5MG                     59
# BUMETANIDE 2MG                    59
# MEDROXYPROGESTERONE               59
# DICLOXACILLIN SOD 500MG           59
# AMOXICIL/CLAVULANATE 500/125MG    59
# DANAZOL 100MG                     59
# DILTIAZEM ER 180MG                59
# HALOPERIDOL 0.5MG                 59
# Name: DRUG, dtype: int64

# %%
df_a = df.groupby(['DRUG','NDC']).count()
df_a.reset_index(inplace=True)
drug_ndc = df_a[['DRUG','NDC']]
drug_ndc
# Out:
#                               DRUG          NDC
# 0   AMOXICIL/CLAVULANATE 500/125MG  00093227434
# 1                    AZILECT 0.5MG  68546014256
# 2                   BUMETANIDE 2MG  00093423401
# 3      CLEMASTINE FUMARATE 2.68 MG  00093030801
# 4                    DANAZOL 100MG  00555063402
# 5          DICLOXACILLIN SOD 500MG  00093312501
# 6               DILTIAZEM ER 180MG  00093511798
# 7               DILTIAZEM XR 240MG  00093511898
# 8                 GABAPENTIN 800MG  68462012705
# 9                  GLIMEPIRIDE 1MG  55111032001
# 10               HALOPERIDOL 0.5MG  00781139101
# 11                HYDRALAZINE 25MG  31722052010
# 12                  KETOROLAC 10MG  00093031401
# 13                   LOSARTAN 25MG  00093736498
# 14             MEDROXYPROGESTERONE  00555077902

# %% [markdown]
# ## Sample Batch

# %%
samplesdf = df.groupby(['NDC']).min().reset_index()
samplesdf
# Out:
#             NDC  IDK                                               FILE  \
# 0   00093030801    1  PillProjectDisc1/images/!NEJH6TAJSKWP5Z0!LBS6S...
# 1   00093031401    1  PillProjectDisc100/images/RF31T_NNE6IXD!J_P154...
# 2   00093227434    1  PillProjectDisc10/images/6ZOQQ9V5PG!BDGE-LSQRA...
# 3   00093312501    1  PillProjectDisc10/images/79P07GX0O6V4D2RRQE-60...
# 4   00093423401    1  PillProjectDisc10/images/6SIDFOK-OR_3AP_T1U8Q2...
# 5   00093511798    1  PillProjectDisc1/images/!J8EE24EA4ZUEKUCYCAD7H...
# 6   00093511898    1  PillProjectDisc1/images/!KX0PO73H16FLWYK!1O6OD...
# 7   00093736498    1  PillProjectDisc1/images/!XDU64VXKTOQC51P8031Y6...
# 8   00555063402    1  PillProjectDisc103/images/TRBREX4HHVCLFPZD91WM...
# 9   00555077902    1  PillProjectDisc102/images/SPJEJUJFF!T6!TF2K_9D...
# 10  00781139101    1  PillProjectDisc1/images/!HV5AFD2JG7NHOMJOEAV_K...
# 11  31722052010    1  PillProjectDisc10/images/738C2CIVM-BWNJU7TO566...
# 12  55111032001    1  PillProjectDisc1/images/!12_QTB!JWB4KJ8-SEK_DQ...
# 13  68462012705    1  PillProjectDisc1/images/!-TBVJT83I7!0B-7LV0VRM...
# 14  68546014256    1  PillProjectDisc1/images/!6N156Y3HC5GQM8NK3-J-1...
#
#               TYPE                            DRUG         ORIG_FOLDER  \
# 0   C3PI_Reference     CLEMASTINE FUMARATE 2.68 MG    PillProjectDisc1
# 1   C3PI_Reference                  KETOROLAC 10MG  PillProjectDisc100
# 2   C3PI_Reference  AMOXICIL/CLAVULANATE 500/125MG   PillProjectDisc10
# 3   C3PI_Reference         DICLOXACILLIN SOD 500MG   PillProjectDisc10
# 4   C3PI_Reference                  BUMETANIDE 2MG   PillProjectDisc10
# 5   C3PI_Reference              DILTIAZEM ER 180MG    PillProjectDisc1
# 6   C3PI_Reference              DILTIAZEM XR 240MG    PillProjectDisc1
# 7   C3PI_Reference                   LOSARTAN 25MG    PillProjectDisc1
# 8   C3PI_Reference                   DANAZOL 100MG  PillProjectDisc103
# 9   C3PI_Reference             MEDROXYPROGESTERONE  PillProjectDisc102
# 10  C3PI_Reference               HALOPERIDOL 0.5MG    PillProjectDisc1
# 11  C3PI_Reference                HYDRALAZINE 25MG   PillProjectDisc10
# 12  C3PI_Reference                 GLIMEPIRIDE 1MG    PillProjectDisc1
# 13  C3PI_Reference                GABAPENTIN 800MG    PillProjectDisc1
# 14  C3PI_Reference                   AZILECT 0.5MG    PillProjectDisc1
#
#     IMAGES                            FILENAME FILETYPE
# 0   images  !NEJH6TAJSKWP5Z0!LBS6SSZ0VT!68.JPG     .CR2
# 1   images  02B64EC03U6TJ27MGBBK7NE_7STG-2.JPG     .CR2
# 2   images  3REUHHP7LMV0BH3JQ3P1C3XU3NQSY7.JPG     .CR2
# 3   images  -NWW3MUS!GWVDQZXMPXNAGJREJ64LV.JPG     .CR2
# 4   images  09--!ZMZUP5RE4RK2QCO1KGUWNKY9_.JPG     .CR2
# 5   images  !J8EE24EA4ZUEKUCYCAD7H2_2L4XQ4.PNG     .CR2
# 6   images  !KX0PO73H16FLWYK!1O6ODAE74EYC1.JPG     .CR2
# 7   images  !XDU64VXKTOQC51P8031Y6YDVDIJHC.JPG     .CR2
# 8   images  2!K1EZBY3LHFSST775LYINFGYABYFG.JPG     .CR2
# 9   images  -8X6ZSTRZ8MNYR3-X1O1EX-MMJP8X8.PNG     .CR2
# 10  images  !HV5AFD2JG7NHOMJOEAV_KK9VOH7R3.JPG     .CR2
# 11  images  0B2SV8HTVA!8WV84NFG2I-YT5VOHBU.JPG     .CR2
# 12  images  !12_QTB!JWB4KJ8-SEK_DQYRS5Y_FJ.JPG     .CR2
# 13  images  !-TBVJT83I7!0B-7LV0VRMAX97IRTW.JPG     .CR2
# 14  images  !6N156Y3HC5GQM8NK3-J-1TS!0G1HT.JPG     .CR2

# %%
sampleslist = samplesdf.FILE.tolist()
sampleslist.sort()
sampleslist
# Out:
# ['PillProjectDisc1/images/!-TBVJT83I7!0B-7LV0VRMAX97IRTW.JPG',
#  'PillProjectDisc1/images/!12_QTB!JWB4KJ8-SEK_DQYRS5Y_FJ.JPG',
#  'PillProjectDisc1/images/!6N156Y3HC5GQM8NK3-J-1TS!0G1HT.JPG',
#  'PillProjectDisc1/images/!HV5AFD2JG7NHOMJOEAV_KK9VOH7R3.JPG',
#  'PillProjectDisc1/images/!J8EE24EA4ZUEKUCYCAD7H2_2L4XQ4.PNG',
#  'PillProjectDisc1/images/!KX0PO73H16FLWYK!1O6ODAE74EYC1.JPG',
#  'PillProjectDisc1/images/!NEJH6TAJSKWP5Z0!LBS6SSZ0VT!68.JPG',
#  'PillProjectDisc1/images/!XDU64VXKTOQC51P8031Y6YDVDIJHC.JPG',
#  'PillProjectDisc10/images/6SIDFOK-OR_3AP_T1U8Q27W!Q166-W.JPG',
#  'PillProjectDisc10/images/6ZOQQ9V5PG!BDGE-LSQRAWDE5-E80O.PNG',
#  'PillProjectDisc10/images/738C2CIVM-BWNJU7TO566EOHUBSA2Z.PNG',
#  'PillProjectDisc10/images/79P07GX0O6V4D2RRQE-60BCOB785!Q.PNG',
#  'PillProjectDisc100/images/RF31T_NNE6IXD!J_P154ZFRGMQFT8O.JPG',
#  'PillProjectDisc102/images/SPJEJUJFF!T6!TF2K_9D19XQME13KC.JPG',
#  'PillProjectDisc103/images/TRBREX4HHVCLFPZD91WMWG6C91INY.CR2']

# %%
ftpdir = {}
for i in range(0,len(sampleslist)):
    ftpcall = sampleslist[i].split('/')
    ftppath = ftpcall[0]+'/'+ftpcall[1]+ '/'
    ftpfile = ftpcall[-1]
    ftpdir.setdefault(ftppath,[])
    ftpdir[ftppath].append(ftpfile)
len(ftpdir)
# Out:
# 5

# %%
# %cd /Users/alphonsowoodbury/Projects/Computer_Vision-Medication_Identification/Data

folder = 'img'+str(imagecount)
paths = folder + '/' + folder
print(folder, paths)

try:
    os.makedirs(paths)
except:
    print('Folder present')

# %cd $folder
# %pwd
dloaded = os.listdir()
for key in ftpdir.keys():
    ftp = FTP('lhcftp.nlm.nih.gov')
    ftp.login()
    ftp.cwd('Open-Access-Datasets/Pills//')
    ftp.cwd(key)
    for value in ftpdir[key]:
        if value not in dloaded:
            with open(value, 'wb') as fp:
                ftp.retrbinary('RETR '+ value, fp.write)
    ftp.cwd('..')
    ftp.cwd('..')

! cd ..
# Out:
# /Users/alphonsowoodbury/Projects/Computer_Vision-Medication_Identification/Data
# img59 img59/img59
# /Users/alphonsowoodbury/Projects/Computer_Vision-Medication_Identification/Data/img59

# %%
# %pwd
# Out:
# '/Users/alphonsowoodbury/Projects/Computer_Vision-Medication_Identification/Data/img59'

# %%
for filename in os.listdir():
    if filename.endswith(".PNG") or filename.endswith(".JPG"): 
        im1 = Image.open(r'{}'.format(filename))
        rgb_im = im1.convert('RGB')
        rgb_im.save(r'{}/{}.JPG'.format(folder,filename[:-4]))
        continue
    elif filename.endswith(".CR2") and os.path.getsize(filename) > 0:
        print(filename)
        raw = rawpy.imread('{}'.format(filename))
        rgb = raw.postprocess()
        imageio.imsave('{}/{}.JPG'.format(folder,filename[:-4]), rgb)
        print(filename)
        continue
# Out:
# TRBREX4HHVCLFPZD91WMWG6C91INY.CR2
# TRBREX4HHVCLFPZD91WMWG6C91INY.CR2

# %%
# %cd $folder

images = os.listdir()
def process(filename):
    image = mpimg.imread(filename)
    plt.figure()
    plt.imshow(image)

for file in images:
    process(file)
# Out:
# /Users/alphonsowoodbury/Projects/Computer_Vision-Medication_Identification/Data/img59/img59

# %%
drugsftp = df.FILE.tolist()
drugsftp.sort()
drugsftp[:10]
# Out:
# ['PillProjectDisc1/images/!!SRPQXAASBCQPWTY-1_4ONT78S2KK.JPG',
#  'PillProjectDisc1/images/!99Q2YI6N7XBRNIV521EXYA051ES_E.JPG',
#  'PillProjectDisc1/images/!G2OJPKYTI7ES1-OW251RY6PK6BHU-.JPG',
#  'PillProjectDisc1/images/!L72!LZSGQBPUUDO56-XU6KVC45OKW.JPG',
#  'PillProjectDisc1/images/!UGIF6I_H_5XC6_A916LVOYLST0SAO.CR2',
#  'PillProjectDisc10/images/7135DCC7VXGE3I8F9_QOZ0JWYHZUT4.JPG',
#  'PillProjectDisc10/images/7CBG_85RQOODGTH030MF3UI_3PS21B.PNG',
#  'PillProjectDisc10/images/7EO-XG_FK7T16N7ADOU0CWL1MJT3CX.JPG',
#  'PillProjectDisc100/images/QV3PUW3N2HL6KF8HSXV_1KL7HH98!E.JPG',
#  'PillProjectDisc100/images/QY_4JH6D4YSSXZZHN2L!7LGE08P4QZ.PNG']

# %%
ftpdir = {}
for i in range(0,len(drugsftp)):
    ftpcall = drugsftp[i].split('/')
    ftppath = ftpcall[0]+'/'+ftpcall[1]+ '/'
    ftpfile = ftpcall[-1]
    ftpdir.setdefault(ftppath,[])
    ftpdir[ftppath].append(ftpfile)
len(ftpdir)
# Out:
# 110

# %%
# %cd /content/drive/My Drive/Project: Pill ID/Data
for key in ftpdir.keys():
    #%cd /content/drive/My Drive/Project: Pill ID/Data
    ftp = FTP('lhcftp.nlm.nih.gov')
    ftp.login()
    ftp.cwd('Open-Access-Datasets/Pills//')
    ftp.cwd(key)
    dloaded = os.listdir('/content/drive/My Drive/Project: Pill ID/Data')
    print(key)
    for value in ftpdir[key]:
      if value not in dloaded:
        with open(value, 'wb') as fp:
            ftp.retrbinary('RETR '+ value, fp.write)
    ftp.cwd('..')
    ftp.cwd('..')
