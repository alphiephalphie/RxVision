# %%
import pandas as pd
import requests
from IPython.display import Image
import time
from ftplib import FTP

from PIL import Image
from PIL import ImageFile
import rawpy
import imageio
ImageFile.LOAD_TRUNCATED_IMAGES = True


import os, shutil

import os
import sys
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
imagecount = 67

# %%
typdict = {'NDC':'str'}
df = pd.read_csv('../data/directory_of_images.txt',sep='|', dtype=typdict, names=['NDC','IDK','FILE','TYPE','DRUG'])
df = df.dropna()
df.DRUG = df.DRUG.str.upper()
df[['ORIG_FOLDER','IMAGES','FILENAME']] = df.FILE.str.split('/', expand=True)
df['FILETYPE'] = df.FILENAME.str[-4:]
df = df[df.FILETYPE != '.WMV']

# %%
ndcs = df.NDC.value_counts()
n = ndcs[ndcs == imagecount].index
# #n100 = ndcs[ndcs <= 100].index
# ndcs50100 = list(set(n50) & set(n100))
dfn = df[df.NDC.isin(n)]
dfn
# Out:
#                NDC  IDK                                               FILE  \
# 12300  00093019901    1  PillProjectDisc20/images/B3YL6NA3N32_P5PLS8RMN...
# 12301  00093019901    1  PillProjectDisc36/images/BJ02FD1MH6JO6-1NGG9JZ...
# 12302  00093019901    1  PillProjectDisc76/images/CSCD_Z4Z25VYWE-HKCIR7...
# 12303  00093019901    1  PillProjectDisc91/images/IR-D8SX42OCUDA2N7MGYH...
# 12305  00093019901    1  PillProjectDisc104/images/U_52ZDM5K4E72NGZRRGU...
# ...            ...  ...                                                ...
# 92121  50111085201    1  PillProjectDisc79/images/CUQ6V!2XRG0HIK7V6A54W...
# 92122  50111085201    1  PillProjectDisc82/images/CXAEO6IAR3NL6LM6ASYY7...
# 92123  50111085201    1  PillProjectDisc87/images/F3P-3_5VT2O04PZ-JLP6X...
# 92124  50111085201    1  PillProjectDisc92/images/JEZTD9F-87FY2JSU747QC...
# 92125  50111085201    1  PillProjectDisc35/images/BITC_T_!K6-R5WC!WG9SK...
#
#                             TYPE                               DRUG  \
# 12300             C3PI_Reference          VENLAFAXINE HYDROCHLORIDE
# 12301             C3PI_Reference  VENLAFAXINE HYDROCHLORIDE TABLETS
# 12302             C3PI_Reference  VENLAFAXINE HYDROCHLORIDE TABLETS
# 12303             C3PI_Reference          VENLAFAXINE HYDROCHLORIDE
# 12305                  C3PI_Test          VENLAFAXINE HYDROCHLORIDE
# ...                          ...                                ...
# 92121  MC_COOKED_CALIBRATED_V1.2                      VALPROIC ACID
# 92122  MC_COOKED_CALIBRATED_V1.2        VALPROIC ACID CAPSULES, USP
# 92123  MC_COOKED_CALIBRATED_V1.2        VALPROIC ACID CAPSULES, USP
# 92124  MC_COOKED_CALIBRATED_V1.2                      VALPROIC ACID
# 92125       MC_SPL_SPLIMAGE_V3.0        VALPROIC ACID CAPSULES, USP
#
#               ORIG_FOLDER  IMAGES                             FILENAME  \
# 12300   PillProjectDisc20  images  B3YL6NA3N32_P5PLS8RMND-P8-469NA.CR2
# 12301   PillProjectDisc36  images  BJ02FD1MH6JO6-1NGG9JZ!-ENTP791I.CR2
# 12302   PillProjectDisc76  images  CSCD_Z4Z25VYWE-HKCIR7ZXPE949MW8.CR2
# 12303   PillProjectDisc91  images   IR-D8SX42OCUDA2N7MGYH_8HO1NLER.CR2
# 12305  PillProjectDisc104  images   U_52ZDM5K4E72NGZRRGU1PUGJ-2D5M.JPG
# ...                   ...     ...                                  ...
# 92121   PillProjectDisc79  images  CUQ6V!2XRG0HIK7V6A54WTW6X6CWNOF.PNG
# 92122   PillProjectDisc82  images  CXAEO6IAR3NL6LM6ASYY7I980DQ1BVM.PNG
# 92123   PillProjectDisc87  images   F3P-3_5VT2O04PZ-JLP6X4CY-Y4RHY.PNG
# 92124   PillProjectDisc92  images   JEZTD9F-87FY2JSU747QC713S3BWQ9.PNG
# 92125   PillProjectDisc35  images  BITC_T_!K6-R5WC!WG9SKZ-1I4Y1KFF.JPG
#
#       FILETYPE
# 12300     .CR2
# 12301     .CR2
# 12302     .CR2
# 12303     .CR2
# 12305     .JPG
# ...        ...
# 92121     .PNG
# 92122     .PNG
# 92123     .PNG
# 92124     .PNG
# 92125     .JPG
#
# [804 rows x 9 columns]

# %%
dfn.DRUG.value_counts()
# Out:
# WARFARIN SODIUM                                         68
# WARFARIN SODIUM TABLETS, USP                            66
# BENAZEPRIL HYDROCHLORIDE                                36
# VENLAFAXINE HYDROCHLORIDE                               36
# LISINOPRIL TABLETS USP                                  36
# HYDRALAZINE HYDROCHLORIDE                               36
# OLANZAPINE 20MG TAB                                     36
# VALPROIC ACID CAPSULES, USP                             36
# CYCLOBENZAPRINE HCL                                     34
# NADOLOL TABLETS USP                                     34
# VERAPAMIL HYDROCHLORIDE                                 34
# METFORMIN HYDROCHLORIDE                                 34
# CYCLOBENZAPRINE HYDROCHLORIDE TABLETS USP               33
# METFORMIN HYDROCHLORIDE EXTENDED-RELEASE TABLETS USP    33
# VERAPAMIL HCL EXTENDED-RELEASE TABLETS USP              33
# NADOLOL                                                 33
# OLANZAPINE TABLETS USP                                  31
# HYDRALAZINE HYDROCHLORIDE TABLETS USP                   31
# LISINOPRIL                                              31
# BENAZEPRIL HYDROCHLORIDE TABLETS USP                    31
# VENLAFAXINE HYDROCHLORIDE TABLETS                       31
# VALPROIC ACID                                           31
# Name: DRUG, dtype: int64

# %%
drugs = dfn.NDC.value_counts()
drugslist = drugs.index.tolist()
len(dfn.NDC.value_counts()),drugs
# Out:
# (12,
#  50111056301    67
#  00093512701    67
#  00093423601    67
#  50111039701    67
#  00555083202    67
#  00555083502    67
#  00172428060    67
#  00093721201    67
#  00172376260    67
#  00093510556    67
#  50111085201    67
#  00093019901    67
#  Name: NDC, dtype: int64)

# %%
df_a = dfn.groupby(['DRUG','NDC']).count()
df_a.reset_index(inplace=True)
drug_ndc = df_a[['DRUG','NDC']]
drug_ndc
# Out:
#                                                  DRUG          NDC
# 0                            BENAZEPRIL HYDROCHLORIDE  00093512701
# 1                BENAZEPRIL HYDROCHLORIDE TABLETS USP  00093512701
# 2                                 CYCLOBENZAPRINE HCL  50111056301
# 3           CYCLOBENZAPRINE HYDROCHLORIDE TABLETS USP  50111056301
# 4                           HYDRALAZINE HYDROCHLORIDE  50111039701
# 5               HYDRALAZINE HYDROCHLORIDE TABLETS USP  50111039701
# 6                                          LISINOPRIL  00172376260
# 7                              LISINOPRIL TABLETS USP  00172376260
# 8                             METFORMIN HYDROCHLORIDE  00093721201
# 9   METFORMIN HYDROCHLORIDE EXTENDED-RELEASE TABLE...  00093721201
# 10                                            NADOLOL  00093423601
# 11                                NADOLOL TABLETS USP  00093423601
# 12                                OLANZAPINE 20MG TAB  00093510556
# 13                             OLANZAPINE TABLETS USP  00093510556
# 14                                      VALPROIC ACID  50111085201
# 15                        VALPROIC ACID CAPSULES, USP  50111085201
# 16                          VENLAFAXINE HYDROCHLORIDE  00093019901
# 17                  VENLAFAXINE HYDROCHLORIDE TABLETS  00093019901
# 18         VERAPAMIL HCL EXTENDED-RELEASE TABLETS USP  00172428060
# 19                            VERAPAMIL HYDROCHLORIDE  00172428060
# 20                                    WARFARIN SODIUM  00555083202
# 21                                    WARFARIN SODIUM  00555083502
# 22                       WARFARIN SODIUM TABLETS, USP  00555083202
# 23                       WARFARIN SODIUM TABLETS, USP  00555083502

# %%
droplist = ['']

df = dfn[~dfn.NDC.isin(droplist)]

# %%
df.DRUG[df.NDC == '00093512701'] = 'BENAZEPRIL'
df.DRUG[df.NDC == '50111056301'] = 'CYCLOBENZAPRINE'
df.DRUG[df.NDC == '50111039701'] = 'HYDRALAZINE'
df.DRUG[df.NDC == '00172376260'] = 'LISINOPRIL'
df.DRUG[df.NDC == '00093721201'] = 'METFORMIN'
df.DRUG[df.NDC == '00093423601'] = 'NADOLOL'
df.DRUG[df.NDC == '00093510556'] = 'OLANZAPINE'
df.DRUG[df.NDC == '50111085201'] = 'VALPROIC ACID'
df.DRUG[df.NDC == '00093019901'] = 'VENLAFAXINE'
df.DRUG[df.NDC == '00172428060'] = 'VERAPAMIL HCL EXTENDED-RELEASE TABLETS'
df.DRUG[df.NDC == '00555083202'] = 'WARFARIN 2.5MG'
df.DRUG[df.NDC == '00555083502'] = 'WARFARIN 10MG'
# Out:
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/alphonsowoodbury/.conda/envs/aw0520/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
df
# Out:
#                NDC  IDK                                               FILE  \
# 12300  00093019901    1  PillProjectDisc20/images/B3YL6NA3N32_P5PLS8RMN...
# 12301  00093019901    1  PillProjectDisc36/images/BJ02FD1MH6JO6-1NGG9JZ...
# 12302  00093019901    1  PillProjectDisc76/images/CSCD_Z4Z25VYWE-HKCIR7...
# 12303  00093019901    1  PillProjectDisc91/images/IR-D8SX42OCUDA2N7MGYH...
# 12305  00093019901    1  PillProjectDisc104/images/U_52ZDM5K4E72NGZRRGU...
# ...            ...  ...                                                ...
# 92121  50111085201    1  PillProjectDisc79/images/CUQ6V!2XRG0HIK7V6A54W...
# 92122  50111085201    1  PillProjectDisc82/images/CXAEO6IAR3NL6LM6ASYY7...
# 92123  50111085201    1  PillProjectDisc87/images/F3P-3_5VT2O04PZ-JLP6X...
# 92124  50111085201    1  PillProjectDisc92/images/JEZTD9F-87FY2JSU747QC...
# 92125  50111085201    1  PillProjectDisc35/images/BITC_T_!K6-R5WC!WG9SK...
#
#                             TYPE           DRUG         ORIG_FOLDER  IMAGES  \
# 12300             C3PI_Reference    VENLAFAXINE   PillProjectDisc20  images
# 12301             C3PI_Reference    VENLAFAXINE   PillProjectDisc36  images
# 12302             C3PI_Reference    VENLAFAXINE   PillProjectDisc76  images
# 12303             C3PI_Reference    VENLAFAXINE   PillProjectDisc91  images
# 12305                  C3PI_Test    VENLAFAXINE  PillProjectDisc104  images
# ...                          ...            ...                 ...     ...
# 92121  MC_COOKED_CALIBRATED_V1.2  VALPROIC ACID   PillProjectDisc79  images
# 92122  MC_COOKED_CALIBRATED_V1.2  VALPROIC ACID   PillProjectDisc82  images
# 92123  MC_COOKED_CALIBRATED_V1.2  VALPROIC ACID   PillProjectDisc87  images
# 92124  MC_COOKED_CALIBRATED_V1.2  VALPROIC ACID   PillProjectDisc92  images
# 92125       MC_SPL_SPLIMAGE_V3.0  VALPROIC ACID   PillProjectDisc35  images
#
#                                   FILENAME FILETYPE
# 12300  B3YL6NA3N32_P5PLS8RMND-P8-469NA.CR2     .CR2
# 12301  BJ02FD1MH6JO6-1NGG9JZ!-ENTP791I.CR2     .CR2
# 12302  CSCD_Z4Z25VYWE-HKCIR7ZXPE949MW8.CR2     .CR2
# 12303   IR-D8SX42OCUDA2N7MGYH_8HO1NLER.CR2     .CR2
# 12305   U_52ZDM5K4E72NGZRRGU1PUGJ-2D5M.JPG     .JPG
# ...                                    ...      ...
# 92121  CUQ6V!2XRG0HIK7V6A54WTW6X6CWNOF.PNG     .PNG
# 92122  CXAEO6IAR3NL6LM6ASYY7I980DQ1BVM.PNG     .PNG
# 92123   F3P-3_5VT2O04PZ-JLP6X4CY-Y4RHY.PNG     .PNG
# 92124   JEZTD9F-87FY2JSU747QC713S3BWQ9.PNG     .PNG
# 92125  BITC_T_!K6-R5WC!WG9SKZ-1I4Y1KFF.JPG     .JPG
#
# [804 rows x 9 columns]

# %%
df.DRUG.value_counts()
# Out:
# METFORMIN                                 67
# NADOLOL                                   67
# OLANZAPINE                                67
# LISINOPRIL                                67
# BENAZEPRIL                                67
# WARFARIN 2.5MG                            67
# HYDRALAZINE                               67
# VALPROIC ACID                             67
# CYCLOBENZAPRINE                           67
# WARFARIN 10MG                             67
# VENLAFAXINE                               67
# VERAPAMIL HCL EXTENDED-RELEASE TABLETS    67
# Name: DRUG, dtype: int64

# %%
df_a = df.groupby(['DRUG','NDC']).count()
df_a.reset_index(inplace=True)
drug_ndc = df_a[['DRUG','NDC']]
drug_ndc
# Out:
#                                       DRUG          NDC
# 0                               BENAZEPRIL  00093512701
# 1                          CYCLOBENZAPRINE  50111056301
# 2                              HYDRALAZINE  50111039701
# 3                               LISINOPRIL  00172376260
# 4                                METFORMIN  00093721201
# 5                                  NADOLOL  00093423601
# 6                               OLANZAPINE  00093510556
# 7                            VALPROIC ACID  50111085201
# 8                              VENLAFAXINE  00093019901
# 9   VERAPAMIL HCL EXTENDED-RELEASE TABLETS  00172428060
# 10                           WARFARIN 10MG  00555083502
# 11                          WARFARIN 2.5MG  00555083202

# %% [markdown]
# ## Sample Batch

# %%
samplesdf = df.groupby(['NDC']).min().reset_index()
samplesdf
# Out:
#             NDC  IDK                                               FILE  \
# 0   00093019901    1  PillProjectDisc1/images/!!_ZD8_HSDUZKL2DNZR0BF...
# 1   00093423601    1  PillProjectDisc1/images/!KHTRKMSDLR5U5-3689LM_...
# 2   00093510556    1  PillProjectDisc10/images/7!XZGFAQRVHH3BNEP232Q...
# 3   00093512701    1  PillProjectDisc100/images/RCT2QON433J8DLNS_C7I...
# 4   00093721201    1  PillProjectDisc10/images/7CWXIM0JW7K2CVJNZY867...
# 5   00172376260    1  PillProjectDisc1/images/!!EWJN4BQWYUSOQJ6GY4!O...
# 6   00172428060    1  PillProjectDisc1/images/!VIIPWAVW6!NQES_CIYUES...
# 7   00555083202    1  PillProjectDisc1/images/!MOADXG470L!UBLN20KONW...
# 8   00555083502    1  PillProjectDisc1/images/!2KR5JKA!_8ZAB59!WJNF0...
# 9   50111039701    1  PillProjectDisc101/images/RZX81YZ0TYIDNU6ACYS_...
# 10  50111056301    1  PillProjectDisc101/images/S-5F!CTQAKA3MBNDXYFH...
# 11  50111085201    1  PillProjectDisc1/images/!M1WIQW_QNW0GB8J3YCU1D...
#
#               TYPE                                    DRUG  \
# 0   C3PI_Reference                             VENLAFAXINE
# 1   C3PI_Reference                                 NADOLOL
# 2   C3PI_Reference                              OLANZAPINE
# 3   C3PI_Reference                              BENAZEPRIL
# 4   C3PI_Reference                               METFORMIN
# 5   C3PI_Reference                              LISINOPRIL
# 6   C3PI_Reference  VERAPAMIL HCL EXTENDED-RELEASE TABLETS
# 7   C3PI_Reference                          WARFARIN 2.5MG
# 8   C3PI_Reference                           WARFARIN 10MG
# 9   C3PI_Reference                             HYDRALAZINE
# 10  C3PI_Reference                         CYCLOBENZAPRINE
# 11  C3PI_Reference                           VALPROIC ACID
#
#            ORIG_FOLDER  IMAGES                            FILENAME FILETYPE
# 0     PillProjectDisc1  images  !!_ZD8_HSDUZKL2DNZR0BFANTHXZT_.PNG     .CR2
# 1     PillProjectDisc1  images   !KHTRKMSDLR5U5-3689LM_IB2UCCF.JPG     .CR2
# 2    PillProjectDisc10  images   -F1G0S93BUWX1ABRAKWTBXWS5Y7IJ.PNG     .CR2
# 3   PillProjectDisc100  images  12YB7RO6WY!-EE6PJKQ-8M2MKNYDA6.JPG     .CR2
# 4    PillProjectDisc10  images  -1MU7551EEC17V8NS2F10AP-F4!FL9.CR2     .CR2
# 5     PillProjectDisc1  images  !!EWJN4BQWYUSOQJ6GY4!O58AQS6_I.PNG     .CR2
# 6     PillProjectDisc1  images  !VIIPWAVW6!NQES_CIYUESEHTG3!6Z.PNG     .CR2
# 7     PillProjectDisc1  images  !MOADXG470L!UBLN20KONWGQWB8HFW.PNG     .CR2
# 8     PillProjectDisc1  images  !2KR5JKA!_8ZAB59!WJNF00MV!UE1I.CR2     .CR2
# 9   PillProjectDisc101  images  1JY42MLCDVPZNVGJJEI0TV06AMLL7B.JPG     .CR2
# 10  PillProjectDisc101  images  38BRA!XRISL2VUKQOI_8YJ74S1RPGM.PNG     .CR2
# 11    PillProjectDisc1  images  !M1WIQW_QNW0GB8J3YCU1DU15GIEOW.JPG     .CR2

# %%
sampleslist = samplesdf.FILE.tolist()
sampleslist.sort()
sampleslist
# Out:
# ['PillProjectDisc1/images/!!EWJN4BQWYUSOQJ6GY4!O58AQS6_I.PNG',
#  'PillProjectDisc1/images/!!_ZD8_HSDUZKL2DNZR0BFANTHXZT_.PNG',
#  'PillProjectDisc1/images/!2KR5JKA!_8ZAB59!WJNF00MV!UE1I.CR2',
#  'PillProjectDisc1/images/!KHTRKMSDLR5U5-3689LM_IB2UCCF.JPG',
#  'PillProjectDisc1/images/!M1WIQW_QNW0GB8J3YCU1DU15GIEOW.JPG',
#  'PillProjectDisc1/images/!MOADXG470L!UBLN20KONWGQWB8HFW.PNG',
#  'PillProjectDisc1/images/!VIIPWAVW6!NQES_CIYUESEHTG3!6Z.PNG',
#  'PillProjectDisc10/images/7!XZGFAQRVHH3BNEP232QGG-KJ-W8.JPG',
#  'PillProjectDisc10/images/7CWXIM0JW7K2CVJNZY867PL3ZT-7DR.JPG',
#  'PillProjectDisc100/images/RCT2QON433J8DLNS_C7ID4XY_0XO4T.PNG',
#  'PillProjectDisc101/images/RZX81YZ0TYIDNU6ACYS_JHP1W_ZIS1.CR2',
#  'PillProjectDisc101/images/S-5F!CTQAKA3MBNDXYFHOOWNIJ87E8.JPG']

# %%
ftpdir = {}
for i in range(0,len(sampleslist)):
    ftpcall = sampleslist[i].split('/')
    ftppath = ftpcall[0]+'/'+ftpcall[1]+ '/'
    ftpfile = ftpcall[-1]
    ftpdir.setdefault(ftppath,[])
    ftpdir[ftppath].append(ftpfile)
len(ftpdir)
# Out:
# 4

# %%
# %cd /Users/alphonsowoodbury/Projects/Computer_Vision-Medication_Identification/Data

folder = 'img'+str(imagecount)
paths = folder + '/' + folder
print(folder, paths)

try:
    os.makedirs(paths)
except:
    print('Folder present')

# %cd $folder
# %pwd
dloaded = os.listdir()
for key in ftpdir.keys():
    ftp = FTP('lhcftp.nlm.nih.gov')
    ftp.login()
    ftp.cwd('Open-Access-Datasets/Pills//')
    ftp.cwd(key)
    for value in ftpdir[key]:
        if value not in dloaded:
            with open(value, 'wb') as fp:
                ftp.retrbinary('RETR '+ value, fp.write)
    ftp.cwd('..')
    ftp.cwd('..')

! cd ..

# %%
# %pwd
# Out:
# '/Users/alphonsowoodbury/Projects/Computer_Vision-Medication_Identification/Data/img67'

# %%
for filename in os.listdir():
    if filename.endswith(".PNG") or filename.endswith(".JPG"): 
        im1 = Image.open(r'{}'.format(filename))
        rgb_im = im1.convert('RGB')
        rgb_im.save(r'{}/{}.JPG'.format(folder,filename[:-4]))
        continue
    elif filename.endswith(".CR2") and os.path.getsize(filename) > 0:
        print(filename)
        raw = rawpy.imread('{}'.format(filename))
        rgb = raw.postprocess()
        imageio.imsave('{}/{}.JPG'.format(folder,filename[:-4]), rgb)
        print(filename)
        continue
# Out:
# RZX81YZ0TYIDNU6ACYS_JHP1W_ZIS1.CR2
# RZX81YZ0TYIDNU6ACYS_JHP1W_ZIS1.CR2
# !2KR5JKA!_8ZAB59!WJNF00MV!UE1I.CR2
# !2KR5JKA!_8ZAB59!WJNF00MV!UE1I.CR2

# %%
# %cd $folder

images = os.listdir()
def process(filename):
    image = mpimg.imread(filename)
    plt.figure()
    plt.imshow(image)

for file in images:
    process(file)
# Out:
# /Users/alphonsowoodbury/Projects/Computer_Vision-Medication_Identification/Data/img67/img67

# %%
drugsftp = df.FILE.tolist()
drugsftp.sort()
drugsftp[:10]
# Out:
# ['PillProjectDisc1/images/!!SRPQXAASBCQPWTY-1_4ONT78S2KK.JPG',
#  'PillProjectDisc1/images/!99Q2YI6N7XBRNIV521EXYA051ES_E.JPG',
#  'PillProjectDisc1/images/!G2OJPKYTI7ES1-OW251RY6PK6BHU-.JPG',
#  'PillProjectDisc1/images/!L72!LZSGQBPUUDO56-XU6KVC45OKW.JPG',
#  'PillProjectDisc1/images/!UGIF6I_H_5XC6_A916LVOYLST0SAO.CR2',
#  'PillProjectDisc10/images/7135DCC7VXGE3I8F9_QOZ0JWYHZUT4.JPG',
#  'PillProjectDisc10/images/7CBG_85RQOODGTH030MF3UI_3PS21B.PNG',
#  'PillProjectDisc10/images/7EO-XG_FK7T16N7ADOU0CWL1MJT3CX.JPG',
#  'PillProjectDisc100/images/QV3PUW3N2HL6KF8HSXV_1KL7HH98!E.JPG',
#  'PillProjectDisc100/images/QY_4JH6D4YSSXZZHN2L!7LGE08P4QZ.PNG']

# %%
ftpdir = {}
for i in range(0,len(drugsftp)):
    ftpcall = drugsftp[i].split('/')
    ftppath = ftpcall[0]+'/'+ftpcall[1]+ '/'
    ftpfile = ftpcall[-1]
    ftpdir.setdefault(ftppath,[])
    ftpdir[ftppath].append(ftpfile)
len(ftpdir)
# Out:
# 110

# %%
# %cd /content/drive/My Drive/Project: Pill ID/Data
for key in ftpdir.keys():
    #%cd /content/drive/My Drive/Project: Pill ID/Data
    ftp = FTP('lhcftp.nlm.nih.gov')
    ftp.login()
    ftp.cwd('Open-Access-Datasets/Pills//')
    ftp.cwd(key)
    dloaded = os.listdir('/content/drive/My Drive/Project: Pill ID/Data')
    print(key)
    for value in ftpdir[key]:
      if value not in dloaded:
        with open(value, 'wb') as fp:
            ftp.retrbinary('RETR '+ value, fp.write)
    ftp.cwd('..')
    ftp.cwd('..')
